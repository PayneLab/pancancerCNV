# %% [markdown]
# # Trans effects enrichment: Enrichr and g:Profiler

# %%
import cnvutils
import os

# %%
params = cnvutils.load_params(os.path.join("..", "data", "params.json"))
CHROMOSOME = params["CHROMOSOME"]
ARM = params["ARM"]
CIS_OR_TRANS = "trans"

# %% [markdown]
# ## Enrichr
#
# We will use Enrichr to look for pathways enriched for proteins that came up across multiple cancers in the cis effects analysis.

# %%
cnvutils.run_enrichr(os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_common_diff.tsv"))
# Out:
# INFO:gseapy:Connecting to Enrichr Server to get latest library names
# INFO:gseapy:Analysis name: test_name, Enrichr Library: GO_Biological_Process_2018
#                         Gene_set  \
# 0     GO_Biological_Process_2018
# 1     GO_Biological_Process_2018
# 2     GO_Biological_Process_2018
# 3     GO_Biological_Process_2018
# 4     GO_Biological_Process_2018
# 5     GO_Biological_Process_2018
# 6     GO_Biological_Process_2018
# 7     GO_Biological_Process_2018
# 8     GO_Biological_Process_2018
# 9     GO_Biological_Process_2018
# 10    GO_Biological_Process_2018
# 11    GO_Biological_Process_2018
# 12    GO_Biological_Process_2018
# 13    GO_Biological_Process_2018
# 14    GO_Biological_Process_2018
# 15    GO_Biological_Process_2018
# 16    GO_Biological_Process_2018
# 17    GO_Biological_Process_2018
# 18    GO_Biological_Process_2018
# 19    GO_Biological_Process_2018
# 20    GO_Biological_Process_2018
# 21    GO_Biological_Process_2018
# 22    GO_Biological_Process_2018
# ...

# %% [markdown]
# ## g:Profiler
#
# We will now use the [g:Profiler tool](https://biit.cs.ut.ee/gprofiler/gost) to look for pathways enriched for proteins that came up across multiple cancers in the cis effects analysis.

# %%
cnvutils.run_gprofiler(os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_common_diff.tsv"))
# Out:
#     source              native  \
# 0    GO:BP          GO:0140053
# 1    GO:BP          GO:0032543
# 2    GO:BP          GO:0070125
# 3    GO:BP          GO:0070126
# 4     REAC  REAC:R-HSA-5389840
# 5     REAC  REAC:R-HSA-5368286
# 6     REAC  REAC:R-HSA-5419276
# 7     REAC  REAC:R-HSA-5368287
# 8    GO:BP          GO:0006415
# 9    GO:BP          GO:0071840
# 10   GO:BP          GO:0043933
# 11   GO:BP          GO:0042254
# 12   GO:BP          GO:0006414
# 13   GO:BP          GO:0022613
# 14   GO:BP          GO:0044085
# 15    REAC    REAC:R-HSA-72766
# 16   GO:BP          GO:0006364
# 17   GO:BP          GO:0043624
# 18   GO:BP          GO:0016043
# 19   GO:BP          GO:0016072
# 20   GO:BP          GO:0033554
# 21    KEGG          KEGG:04141
# 22   GO:BP          GO:0065003
# 23   GO:BP          GO:0044267
# 24   GO:BP          GO:0034660
# 25   GO:BP          GO:0001775
# 26   GO:BP          GO:0044237
# 27   GO:BP          GO:0051641
# 28   GO:BP          GO:0032984
# ...
