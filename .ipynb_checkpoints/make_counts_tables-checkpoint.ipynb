# %%
import pandas as pd
import numpy as np
import cptac
import pyensembl
ensembl = pyensembl.EnsemblRelease()

# %%
cptac.download(dataset="endometrial")
cptac.download(dataset="brca")
cptac.download(dataset="ccrcc")
cptac.download(dataset="gbm")
cptac.download(dataset="hnscc")
cptac.download(dataset="luad")
cptac.download(dataset="ovarian")
cptac.download(dataset="colon")
cptac.download(dataset="lscc")
# Out:
# ---------------------------------------------------------------------------
# NoInternetError                           Traceback (most recent call last)
# <ipython-input-2-ca7065a67193> in <module>
# ----> 1 cptac.download(dataset="endometrial")
#       2 cptac.download(dataset="brca")
#       3 cptac.download(dataset="ccrcc")
#       4 cptac.download(dataset="gbm")
#       5 cptac.download(dataset="hnscc")
#
# ~\anaconda3\lib\site-packages\cptac\file_download.py in download(dataset, version, redownload)
#      54
#      55     # Update the index
# ---> 56     update_index(dataset)
#      57
#      58     # Load the index
#
# ~\anaconda3\lib\site-packages\cptac\file_download.py in update_index(dataset)
#     146     print(checking_msg, end='\r')
#     147     try:
# --> 148         server_index_hash = download_text(index_hash_url)
#     149     finally:
#     150         print(" " * len(checking_msg), end='\r') # Erase the checking message, even if there was an internet error
#
# ~\anaconda3\lib\site-packages\cptac\file_download.py in download_text(url)
#     180         response.raise_for_status() # Raises a requests HTTPError if the response code was unsuccessful
#     181     except requests.RequestException: # Parent class for all exceptions in the requests module
# --> 182         raise NoInternetError("Insufficient internet. Check your internet connection.") from None
#     183
#     184     text = response.text.strip()
#
# NoInternetError: Insufficient internet. Check your internet connection.

# %%
en = cptac.Endometrial()
brca = cptac.Brca()
ccrcc = cptac.Ccrcc()
gbm = cptac.Gbm()
hnscc = cptac.Hnscc()
luad = cptac.Luad()
ovarian = cptac.Ovarian()
colon = cptac.Colon()
lscc = cptac.Lscc()
# Out:
# Formatting dataframes...
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# Checking that hnscc index is up-to-date...
# cptac warning: The GBM dataset is under publication embargo until March 01, 2021. CPTAC is a community resource project and data are made available rapidly after generation for community research use. The embargo allows exploring and utilizing the data, but analysis may not be published until after the embargo date. Please see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details. (C:\Users\chels\anaconda3\lib\site-packages\ipykernel_launcher.py, line 4)
# Checking that luad index is up-to-date...
# cptac warning: The HNSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (C:\Users\chels\anaconda3\lib\site-packages\ipykernel_launcher.py, line 5)
# version 3scc v3.2.......
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (C:\Users\chels\anaconda3\lib\site-packages\ipykernel_launcher.py, line 9)

# %%
en_cnv = en.get_CNV()
brca_cnv = brca.get_CNV()
ccrcc_cnv = ccrcc.get_CNV()
gbm_cnv = gbm.get_CNV()
hnscc_cnv = hnscc.get_CNV()
luad_cnv = luad.get_CNV()
ovarian_cnv = ovarian.get_CNV()
colon_cnv = colon.get_CNV()
lscc_cnv = lscc.get_CNV()

# %%
ccrcc_cnv
# Out:
# Name                      A1BG               A1CF                A2M  \
# Database_ID ENSG00000121410.11 ENSG00000148584.14 ENSG00000175899.14
# Patient_ID
# C3L-00004             0.020366           0.013001           0.015820
# C3L-00010             0.027739           0.019186           0.019790
# C3L-00011             0.089568           0.121480           0.134582
# C3L-00026            -0.021259          -0.021430          -0.015553
# C3L-00079             0.061714           0.123367          -0.048778
# ...                        ...                ...                ...
# C3N-01646             0.026528           0.065469           0.074286
# C3N-01648             0.003589          -0.017667          -0.009598
# C3N-01649             0.017956           0.019480           0.026971
# C3N-01651             0.163116          -0.331378           0.140222
# C3N-01808            -0.025767          -0.022834          -0.019618
#
# Name                     A2ML1           A3GALT2             A4GALT  \
# Database_ID ENSG00000166535.19 ENSG00000184389.9 ENSG00000128274.15
# Patient_ID
# C3L-00004             0.015820          0.013783           0.016040
# C3L-00010             0.019790          0.021678           0.022887
# C3L-00011             0.134582          0.104257           0.066205
# C3L-00026            -0.015553         -0.020833          -0.116570
# C3L-00079            -0.048778          0.048854          -0.178020
# ...                        ...               ...                ...
# C3N-01646             0.074286          0.031000           0.031598
# C3N-01648            -0.009598         -0.003569          -0.000926
# C3N-01649             0.026971          0.017902           0.020458
# C3N-01651             0.140222         -0.055388          -0.049226
# C3N-01808            -0.019618         -0.026103          -0.023638
#
# Name                    A4GNT               AAAS               AACS  \
# Database_ID ENSG00000118017.3 ENSG00000094914.12 ENSG00000081760.16
# Patient_ID
# C3L-00004            0.012262           0.015433           0.015433
# C3L-00010            0.019669           0.022677           0.022677
# C3L-00011            0.125552           0.126908           0.091427
# C3L-00026           -0.024959          -0.018876          -0.018876
# C3L-00079            0.160586          -0.062128          -0.062128
# ...                       ...                ...                ...
# C3N-01646            0.288325           0.062137           0.063978
# C3N-01648           -0.009770          -0.004919          -0.004919
# C3N-01649            0.020200           0.028800           0.028800
# C3N-01651            0.134608           0.142253           0.142253
# C3N-01808            0.382217          -0.019048          -0.019048
#
# Name                     AADAC  ...             ZWILCH              ZWINT  \
# Database_ID ENSG00000114771.13  ... ENSG00000174442.11 ENSG00000122952.16
# Patient_ID                      ...
# C3L-00004             0.012262  ...           0.016381           0.013001
# C3L-00010             0.019669  ...           0.022946           0.019186
# C3L-00011             0.125552  ...           0.121135           0.121480
# C3L-00026            -0.024959  ...          -0.021340          -0.021430
# C3L-00079             0.160586  ...           0.041436           0.123367
# ...                        ...  ...                ...                ...
# C3N-01646             0.288325  ...           0.033744           0.030586
# C3N-01648            -0.009770  ...          -0.007744          -0.008758
# C3N-01649             0.020200  ...           0.017537           0.019480
# C3N-01651             0.134608  ...          -0.315716          -0.321503
# C3N-01808             0.382012  ...          -0.024736          -0.022834
#
# Name                     ZXDA              ZXDB               ZXDC  \
# Database_ID ENSG00000198205.6 ENSG00000198455.4 ENSG00000070476.14
# Patient_ID
# C3L-00004            0.013331          0.013331           0.012262
# C3L-00010            0.011710          0.011710           0.019669
# C3L-00011           -0.470122         -0.470122           0.125552
# C3L-00026           -0.550917         -0.550917          -0.026006
# C3L-00079            0.086172          0.086172           0.160586
# ...                       ...               ...                ...
# C3N-01646            0.027502          0.027502           0.288325
# C3N-01648           -0.009086         -0.009086          -0.009770
# C3N-01649            0.020941          0.020941           0.020200
# C3N-01651            0.114801          0.114801           0.134608
# C3N-01808           -0.027958         -0.027958          -0.593051
#
# Name                   ZYG11A             ZYG11B                ZYX  \
# Database_ID ENSG00000203995.9 ENSG00000162378.12 ENSG00000159840.15
# Patient_ID
# C3L-00004            0.013783           0.013783           0.022275
# C3L-00010            0.021678           0.021678           0.021366
# C3L-00011            0.104257           0.104257           0.116052
# C3L-00026           -0.020833          -0.020833           0.394042
# C3L-00079            0.048854           0.048854           0.049045
# ...                       ...                ...                ...
# C3N-01646            0.031000           0.031000           0.033042
# C3N-01648           -0.003569          -0.003569          -0.014371
# C3N-01649            0.017902           0.017902           0.328963
# C3N-01651           -0.055388          -0.055388           0.145273
# C3N-01808           -0.026103          -0.026103           0.380146
#
# Name                     ZZEF1               ZZZ3
# Database_ID ENSG00000074755.14 ENSG00000036549.12
# Patient_ID
# C3L-00004             0.020393           0.013783
# C3L-00010             0.025461           0.021678
# C3L-00011            -0.488441           0.131674
# C3L-00026            -0.017815          -0.020833
# C3L-00079            -0.033958           0.039913
# ...                        ...                ...
# C3N-01646             0.024613           0.031000
# C3N-01648             0.003618          -0.003569
# C3N-01649             0.021064           0.017902
# C3N-01651            -0.051065          -0.078956
# C3N-01808            -0.023639          -0.026103
#
# [110 rows x 19285 columns]

# %%
def separate(gain, loss, data):
  """
  Counts the Number of patients with high and low values for each gene.
  """
  sepDict = dict()
  for column in data:
    numGain = 0
    numLoss = 0
    numNeu = 0
    for i in data[column]:
        if i >= gain:
            numGain += 1
        elif i <= loss:
            numLoss += 1
        else:
            numNeu += 1 
    sepDict[column] = [numGain, numNeu, numLoss]
  return sepDict

# %%
def get_counts_and_average(data):
  """
  Takes a CNV dataframe and generates a dataframe with the counts of gains, losses and neutral values
  """
  df = pd.DataFrame(data = separate(.2,-.2,data), index = ["gain", "neutral", "loss"])
  return df.transpose()

# %%
def add_chromo_and_loc(my_dict):
    chromo = list()
    locations = list()
    not_found = list()
    count = 0
    for gene in list(my_dict.index.get_level_values(0)):
        count += 1
        try:
            e_gene = ensembl.genes_by_name(gene)
            chromo.append(int(e_gene[0].contig))
            locations.append((e_gene[0].start + e_gene[0].end)/2)
        except:
            not_found.append(gene)
            chromo.append(None)
            locations.append(None)
    my_dict['chromo'] = chromo
    my_dict['location'] = locations
    print(len(not_found)/count)
    return my_dict

# %%
en_counts = get_counts_and_average(en_cnv)
gbm_counts = get_counts_and_average(gbm_cnv)
brca_counts = get_counts_and_average(brca_cnv)
hnscc_counts = get_counts_and_average(hnscc_cnv)
luad_counts = get_counts_and_average(luad_cnv)
ovarian_counts = get_counts_and_average(ovarian_cnv)
ccrcc_counts = get_counts_and_average(ccrcc_cnv)
colon_counts = get_counts_and_average(colon_cnv)
lscc_counts = get_counts_and_average(lscc_cnv)

# %%
add_chromo_and_loc(en_counts)
# Out:
# 0.09352389777952026
#           gain  neutral  loss chromo     location
# A1BG         4       85     6     19   58349335.0
# A1BG-AS1     4       85     6     19   58351586.5
# A1CF        17       75     3     10   50842542.0
# A2M          7       87     1     12    9091946.5
# A2M-AS1      7       87     1     12    9066926.0
# ...        ...      ...   ...    ...          ...
# ZYG11A       3       90     2      1   52868754.5
# ZYG11B       3       90     2      1   52776894.5
# ZYX         12       81     2      7  143386203.0
# ZZEF1        3       82    10     17    4073737.5
# ZZZ3         4       89     2   None          NaN
#
# [28057 rows x 5 columns]

# %%
en_counts = add_chromo_and_loc(en_counts)
gbm_counts = add_chromo_and_loc(gbm_counts)
brca_counts = add_chromo_and_loc(brca_counts)
hnscc_counts = add_chromo_and_loc(hnscc_counts)
luad_counts = add_chromo_and_loc(luad_counts)
ovarian_counts = add_chromo_and_loc(ovarian_counts)
ccrcc_counts = add_chromo_and_loc(ccrcc_counts)
colon_counts = add_chromo_and_loc(colon_counts)
lscc_counts = add_chromo_and_loc(lscc_counts)
# Out:
# 0.09352389777952026
# 0.016476616265635204
# 0.09678372446395407
# 0.019470286208123633
# 0.037577204546634144
# 0.05881324318022849
# 0.03754213119004408
# 0.1250645174097749
# 0.1323070139986038

# %%
en_counts.reset_index(inplace=True)
gbm_counts.reset_index(inplace=True)
brca_counts.reset_index(inplace=True)
hnscc_counts.reset_index(inplace=True)
luad_counts.reset_index(inplace=True)
ovarian_counts.reset_index(inplace=True)
ccrcc_counts.reset_index(inplace=True)
colon_counts.reset_index(inplace=True)
lscc_counts.reset_index(inplace=True)

# %%
en_counts.to_csv("data/endo_counts.csv")
gbm_counts.to_csv("data/gbm_counts.csv")
brca_counts.to_csv("data/brca_counts.csv")
hnscc_counts.to_csv("data/hnscc_counts.csv")
luad_counts.to_csv("data/luad_counts.csv")
ovarian_counts.to_csv("data/ovarian_counts.csv")
ccrcc_counts.to_csv("data/ccrcc_counts.csv")
colon_counts.to_csv("data/colon_counts.csv")
lscc_counts.to_csv("data/lscc_counts.csv")

# %%
brca_counts
# Out:
#         level_0            level_1  gain  neutral  loss chromo  location
# 0           7SK  ENSG00000232512.2    15       89    18   None       NaN
# 1           7SK  ENSG00000249352.3    11       80    31   None       NaN
# 2           7SK  ENSG00000254144.2    66       49     7   None       NaN
# 3           7SK  ENSG00000260682.2     9       50    63   None       NaN
# 4           7SK  ENSG00000271765.1    13       86    23   None       NaN
# ...         ...                ...   ...      ...   ...    ...       ...
# 23687     snoZ6  ENSG00000252200.1    12       93    17   None       NaN
# 23688     snoZ6  ENSG00000253067.1     9       89    24   None       NaN
# 23689     snoZ6  ENSG00000264452.1    21       86    15   None       NaN
# 23690     snoZ6  ENSG00000266692.1    21       86    15   None       NaN
# 23691  snosnR66  ENSG00000212397.1     5       69    48   None       NaN
#
# [23692 rows x 7 columns]
