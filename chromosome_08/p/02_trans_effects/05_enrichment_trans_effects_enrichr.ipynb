# %% [markdown]
# # Trans effects enrichment - Enrichr
#
# This notebook will use Enrichr to look for pathways enriched for proteins that came up across multiple cancers in the trans effects analysis.

# %%
import cnvutils
import os

# %%
params = cnvutils.load_params(os.path.join("..", "data", "params.json"))
CHROMOSOME = params["CHROMOSOME"]
ARM = params["ARM"]
CIS_OR_TRANS = "trans"

# %% [markdown]
# ### 8q trans effects in BRCA

# %%
cnvutils.run_enrichr(
    os.path.join("..", "data", f"common_summary_{CHROMOSOME}{ARM}_{CIS_OR_TRANS}.tsv"), 
    cancer_type="brca",
    gene_set_source="reactome",
)
# Out:
# INFO:gseapy:User Defined gene sets is given: /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/cnvutils/gene_set_libraries/ReactomePathways.gmt
# INFO:gseapy:Connecting to Enrichr Server to get latest library names
# INFO:gseapy:using all annotated genes with GO_ID as background genes
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:gseapy:Background: found 19041 genes
#                  Gene_set                                               Term  \
# 21  CUSTOM140414592098384  TP53 regulates transcription of additional cel...
# 16  CUSTOM140414592098384  ROS and RNS production in phagocytes (R-HSA-12...
# 3   CUSTOM140414592098384               Deadenylation of mRNA (R-HSA-429947)
# 13  CUSTOM140414592098384  Negative regulation of activity of TFAP2 (AP-2...
# 24  CUSTOM140414592098384  Transferrin endocytosis and recycling (R-HSA-9...
# 23  CUSTOM140414592098384  Transcriptional regulation by the AP-2 (TFAP2)...
# ...

# %%
cnvutils.run_enrichr_go(
    "pancancer_summary_8q_trans.tsv", 
    cancer_type="brca"
)
# Out:
#                         Gene_set  \
# 0     GO_Biological_Process_2018
# 1     GO_Biological_Process_2018
# 2     GO_Biological_Process_2018
# 3     GO_Biological_Process_2018
# 4     GO_Biological_Process_2018
# 5     GO_Biological_Process_2018
# 6     GO_Biological_Process_2018
# 7     GO_Biological_Process_2018
# 8     GO_Biological_Process_2018
# 9     GO_Biological_Process_2018
# 10    GO_Biological_Process_2018
# 11    GO_Biological_Process_2018
# 12    GO_Biological_Process_2018
# 13    GO_Biological_Process_2018
# 14    GO_Biological_Process_2018
# 15    GO_Biological_Process_2018
# 16    GO_Biological_Process_2018
# 17    GO_Biological_Process_2018
# 18    GO_Biological_Process_2018
# 19    GO_Biological_Process_2018
# 20    GO_Biological_Process_2018
# 21    GO_Biological_Process_2018
# 22    GO_Biological_Process_2018
# 23    GO_Biological_Process_2018
# 24    GO_Biological_Process_2018
# 25    GO_Biological_Process_2018
# 26    GO_Biological_Process_2018
# ...
