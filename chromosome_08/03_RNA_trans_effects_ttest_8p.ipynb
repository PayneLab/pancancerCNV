# %% [markdown]
# # RNA trans-effects with t tests for 8p
#
# Here we look for genes OUTSIDE the event discussed that are affected by the arm-level event. We will find these effects by performing a series of t-tests comparing the transcriptomics values of the patients with the event against those without the event.

# %% [markdown]
# ## Setup (Install necessary packages)
#
# We will start by importing necessary packages and collecting all of the transcriptomics data we will need to run the tests. The cancer types analyzed should have been determined in 01_event_basic_info where we determine which types of cancer seem to have the event we are looking at.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cptac
from scipy import stats
import cnvutils
import cptac.utils

# %%
# These variables specify which chromosome and arm we're working on, and whether to do cis or trans
CHROMOSOME = '8'
ARM = 'p'
CIS_OR_TRANS = "trans"

# %%
if ARM == "p":
    EVENT_COLUMN = "loss_event"
    EXCLUDE_COLUMN = "gain_event"
    EVENT_START = 0
    EVENT_END = 30794385
    
elif ARM == "q":
    EVENT_COLUMN = "gain_event"
    EXCLUDE_COLUMN = "loss_event"
    EVENT_START = 80794385
    EVENT_END = 130794385

else:
    raise ValueError("Invalid value for ARM variable.")

# %%
cancer_types = {
    "brca": cptac.Brca,
    "colon": cptac.Colon,
    "hnscc": cptac.Hnscc,
    "lscc": cptac.Lscc,
    "luad": cptac.Luad,
    "ovarian": cptac.Ovarian
}

# %% [markdown]
# ## Select the RNAs we're interested in
#
# If we're looking at cis effects, we select RNAs within the event. If we're looking at trans effects, we select RNAs outside of the event.

# %%
selected_genes = cnvutils.\
get_event_genes(
    chrm=CHROMOSOME,
    event_start=EVENT_START,
    event_end=EVENT_END,
    cis_or_trans=CIS_OR_TRANS
)["Name"].\
drop_duplicates(keep="first")

def load_transcriptomics_tumor(dataset_func):
    return dataset_func().get_transcriptomics(tissue_type="tumor")

transcriptomics = {}

for cancer_type in cancer_types.keys():
    df = load_transcriptomics_tumor(cancer_types[cancer_type]).transpose()

    if df.index.nlevels == 1:
        df = df[df.index.isin(selected_genes)]
    else:
        df = df[df.index.isin(selected_genes, level="Name")]

    transcriptomics[cancer_type] = df
# Out:
# Checking that luad index is up-to-date...
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 11)

# %% [markdown]
# ## Append Event Data
#
# We now append the data from the event table that should have been created in a previous notebook.

# %%
has_event = dict()
for cancer_type in transcriptomics.keys():
    df = transcriptomics[cancer_type]
    df = df.transpose()
    event = pd.read_csv(f'{cancer_type}_has_event.tsv', sep='\t', index_col=0)
    if EXCLUDE_COLUMN:
        event.drop(EXCLUDE_COLUMN, axis=1, inplace=True)
    event.index.rename('Name')
    df = df.join(event)
    df = df.dropna(subset=[EVENT_COLUMN])
    has_event[cancer_type] = df[EVENT_COLUMN]
    transcriptomics[cancer_type] = df

# %% [markdown]
# ## Run T-Tests

# %%
results_df = None
for cancer_type in transcriptomics.keys():
    prot_df = transcriptomics[cancer_type]
    results = cptac.utils.wrap_ttest(
        df=prot_df, 
        label_column=EVENT_COLUMN,
        correction_method="fdr_bh",
        return_all=True,
        quiet=True
    )   
    results.set_index('Comparison', inplace=True)
    if isinstance(results.index[0], tuple):
        results[['Name', f'{cancer_type}_Database_ID']] = pd.DataFrame(
            results.index.values.tolist(),
            index=results.index
        )
        results.set_index(['Name', f'{cancer_type}_Database_ID'], inplace=True)
    else:
        results.index.name='Name'
    results.rename(columns={'P_Value': f'{cancer_type}_pvalue'}, inplace=True)
    if results_df is None:
        results_df = results
    else:
        results_df = results_df.join(results)

# %% [markdown]
# ## Append Difference Data
#
# We want to collect one more piece of information about the data. We want to find the difference between the averages of the two groups. This will tell us if there is a positive or negative coorelation between the event and the proteomic data and can give us some indication of the strength of the coorelation.

# %%
def get_diff(col, event):
    has_event = col[event]
    invert_list = [not x for x in event]
    no_event = col[invert_list]
    event_avg = has_event.mean()
    no_event_avg = no_event.mean()
    return event_avg - no_event_avg

# %%
diff_df = None
for cancer_type in transcriptomics.keys():
    df = transcriptomics[cancer_type]
    df = df.drop(EVENT_COLUMN, axis=1)
    results = df.apply(lambda x: get_diff(x, has_event[cancer_type]))
    df = pd.DataFrame(results)
    if isinstance(df.index[0], tuple):
        df[['Name', f'{cancer_type}_Database_ID']] = pd.DataFrame(df.index.values.tolist(), index=df.index)
        df.set_index(['Name', f'{cancer_type}_Database_ID'], inplace=True)
    else:
        df.index.name='Name'
    df.rename(columns={0: f'{cancer_type}_diff'}, inplace=True)
    if diff_df is None:
        diff_df = df
    else:
        diff_df = diff_df.join(df)

# %% [markdown]
# ## Join the tables and save
#
# We now join the difference table and the results table together. We also save the table to a tsv for use in future analyses.

# %%
results_df = results_df.join(diff_df)

# %%
results_df
# Out:
#               brca_pvalue  colon_pvalue  hnscc_pvalue  lscc_pvalue  \
# Name
# TMEM66           0.073995           NaN           NaN          NaN
# TMEM194A         0.184416           NaN           NaN          NaN
# KIAA1456         0.184416           NaN           NaN          NaN
# MSI1             0.620970           NaN      0.870952     0.277659
# ANXA10           0.639024           NaN      0.588226     0.423607
# PTBP3            0.639024      0.511987      0.510254     0.359842
# PON3             0.639024      0.394197      0.896673     0.127005
# ERCC4            0.639024      0.219330      0.490639     0.801132
# LOC100287015     0.639024           NaN      0.164928     0.008672
# SGK223           0.639024           NaN           NaN          NaN
# HEXB             0.639024      0.651519      0.794878     0.047058
# PTPN1            0.639024      0.077286      0.800445     0.033450
# LOC100132111     0.639024           NaN      0.617930          NaN
# LOC644961        0.639024           NaN           NaN          NaN
# NENF             0.639024      0.380228      0.859498     0.033175
# ENHO             0.639024           NaN      0.757436     0.091786
# EMC7             0.639024      0.037716      0.374579     0.508278
# STRBP            0.639024      0.718564      0.863917     0.162069
# BAG1             0.639024      0.897397      0.927203     0.724736
# LYPLAL1          0.639024      0.771271      0.714161     0.252827
# SVIP             0.639024      0.088961      0.234429     0.363556
# SNORD16          0.639024           NaN      0.925225          NaN
# E2F1             0.639024      0.173441      0.176999     0.082754
# PMPCB            0.639024      0.893301      0.545178     0.056979
# ZNF132           0.639024           NaN      0.388725     0.004921
# ANTXRL           0.639024           NaN      0.563744     0.401838
# NDUFS2           0.639024      0.261410      0.138325     0.222891
# PMP2             0.639024           NaN      0.262393     0.652307
# ZHX2             0.639024      0.951333      0.769248     0.324487
# ATP12A           0.639024           NaN      0.938950     0.595795
# ...                   ...           ...           ...          ...
# CMC2             0.999808      0.602244      0.579662     0.530331
# PSMA1            0.999808      0.297462      0.862103     0.424506
# CHRNA1           0.999808           NaN      0.801112     0.116407
# ZNF33B           0.999808      0.733815      0.118188     0.745965
# INHA             0.999808           NaN      0.197087     0.572843
# XAF1             0.999808      0.473396      0.903617     0.005302
# SCAMP2           0.999808      0.981403      0.981728     0.466133
# CXCR6            0.999808      0.278056      0.138818     0.000697
# ENO2             0.999808      0.357631      0.337578     0.817367
# CASC18           0.999808           NaN      0.883210     0.300880
# LRCH1            0.999808      0.694016      0.670422     0.003955
# KLHL20           0.999808      0.298835      0.961520     0.824857
# DDAH2            0.999808      0.006286      0.106411     0.649935
# SEC31A           0.999808      0.984576      0.938220     0.082868
# POLR2J           0.999808      0.752283      0.926678     0.003048
# C6orf89          0.999808      0.075666      0.761474     0.306880
# ULK4P3           0.999808           NaN      0.353557     0.211155
# TUBBP5           0.999808           NaN      0.932869          NaN
# TRERNA1          0.999827           NaN      0.962813          NaN
# LINC00937        0.999827           NaN      0.316488     0.035084
# RABL6            0.999827      0.162897      0.708528     0.689041
# RPUSD3           0.999827      0.558629      0.890898     0.620284
# COX8C            0.999827           NaN      0.441610     0.258421
# LOC341056        0.999827           NaN      0.616998          NaN
# TPCN2            0.999827      0.257523      0.431735     0.992405
# UGT2B10          0.999827           NaN      0.524896          NaN
# GART             0.999947      0.731880      0.915737     0.079621
# ZNF616           0.999947      0.106157      0.644244     0.945734
# EXOSC7           0.999947      0.238322      0.913287     0.449318
# SLC2A12          0.999958      0.180620      0.624629     0.175793
#
#               luad_pvalue  ovarian_pvalue  brca_diff  colon_diff  hnscc_diff  \
# Name
# TMEM66                NaN        0.001842  -0.835266         NaN         NaN
# TMEM194A              NaN        0.965478   0.495719         NaN         NaN
# KIAA1456         0.046410        0.853380  -2.101978         NaN         NaN
# MSI1             0.776088        0.858042   2.503890         NaN    0.156655
# ANXA10           0.518842        0.935797   1.666500         NaN    0.473657
# PTBP3            0.989547             NaN   0.492958    0.084598    0.122482
# PON3             0.767607        0.853380  -2.308519   -0.526424   -0.166076
# ERCC4            0.140900        0.853380   0.494796    0.150253    0.090918
# LOC100287015          NaN        0.857316  -0.743183         NaN   -0.262722
# SGK223                NaN        0.853380  -0.851773         NaN         NaN
# HEXB             0.724463        0.918939  -0.363199   -0.074180    0.063409
# PTPN1            0.563843        0.947698   0.601799    0.275505    0.056826
# LOC100132111          NaN        0.916622  -0.900755         NaN   -0.289937
# LOC644961             NaN             NaN   1.101864         NaN         NaN
# NENF             0.790816        0.904681  -0.618865   -0.153015    0.048029
#               lscc_diff  luad_diff  ovarian_diff
# Name
# TMEM66              NaN        NaN    -47.290683
# TMEM194A            NaN        NaN      0.172719
# KIAA1456            NaN  -0.760896     -0.702905
# MSI1           0.556859  -0.304827      0.709845
# ANXA10         0.670099  -0.615328     -0.206282
# PTBP3         -0.116764  -0.004644           NaN
# PON3          -0.591266   0.205674      3.159712
# ERCC4         -0.032012   0.230339      0.236728
# LOC100287015  -0.421057        NaN     -0.214738
# SGK223              NaN        NaN     -0.886434
# HEXB          -0.216085  -0.076004      2.458741
# PTPN1         -0.232969  -0.151598     -0.375020
# LOC100132111        NaN        NaN      0.137050
# LOC644961           NaN        NaN           NaN
# NENF           0.264537   0.063090     -2.689715
# ENHO           0.757055   0.181041      1.415735
# EMC7          -0.071201  -0.059007     -0.028197
# STRBP          0.295612  -0.127831           NaN
# BAG1           0.078766  -0.376638     -4.100574
# LYPLAL1        0.203808   0.071429      3.240160
# SVIP          -0.273642  -0.024492      3.159820
# SNORD16             NaN        NaN           NaN
# E2F1           0.362840   0.040990           NaN
# PMPCB          0.179820   0.010417      2.678510
# ZNF132        -0.742267   0.118424     -0.153048
# ANTXRL         0.317105   0.792951      0.174560
# NDUFS2         0.126468  -0.022207           NaN
# PMP2           0.433487   1.109676     -0.002836
# ZHX2          -0.184300  -0.192274     -0.776593
# ATP12A        -0.440354  -0.843971      0.013539
# ...                 ...        ...           ...
# CMC2           0.076037  -0.029336      0.567199
# PSMA1         -0.120239   0.089468           NaN
# CHRNA1        -0.625898  -0.216364      0.271058
# ZNF33B         0.055691   0.058324     -0.378385
# INHA           0.207816  -0.410417      0.239488
# XAF1          -0.728933   0.103564           NaN
# SCAMP2        -0.084269  -0.018400      4.126775
# CXCR6         -0.879887  -0.158039      0.418653
# ENO2           0.081797   0.032230     -1.794219
# CASC18        -0.415450        NaN     -0.006484
# LRCH1         -0.333940  -0.223912     -0.443194
# KLHL20        -0.022545   0.025532      0.003567
# DDAH2         -0.100656  -0.029295      0.000000
# SEC31A        -0.168827   0.105912           NaN
# POLR2J         0.357039   0.204356           NaN
# C6orf89       -0.102268   0.095100      0.982163
# ULK4P3         0.581818        NaN           NaN
# TUBBP5              NaN        NaN      0.299724
# TRERNA1             NaN        NaN      0.002707
# LINC00937     -0.516423        NaN     -0.366584
# RABL6          0.059495  -0.082656      1.141830
# RPUSD3         0.062964   0.057278      0.820415
# COX8C          0.517151   0.148142           NaN
# LOC341056           NaN        NaN      0.485689
# TPCN2         -0.002691   0.010955     -0.068985
# UGT2B10             NaN        NaN      0.000000
# GART           0.189898   0.129597     -0.055005
# ZNF616         0.011834   0.103094           NaN
# EXOSC7         0.093318  -0.155049           NaN
# SLC2A12        0.576951   0.472098      0.329791
#
# [20856 rows x 12 columns]

# %%
# This will save the resulting table in the same directory as this notebook.
# Modify if you would like to save to a different location.
results_df.to_csv(f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}RNAeffects_ttest.tsv", sep='\t')
