# %% [markdown]
# # Cis effects dotplot

# %% [markdown]
# ## Load input files

# %%
import cnvutils as ut
import pandas as pd
import numpy as np
import altair as alt
import os
from toolz.curried import pipe

# %%
# Altair options
alt.data_transformers.disable_max_rows()

# def json_dir(data, data_dir):
#     os.makedirs(data_dir, exist_ok=True)
#     return pipe(data, alt.to_json(filename=os.path.join(data_dir, "{prefix}-{hash}.{extension}")) )

# alt.data_transformers.register("json_dir", json_dir)
# alt.data_transformers.enable("json_dir", data_dir="plot_data")
# Out:
# DataTransformerRegistry.enable('default')

# %%
CHROMOSOME = "8"
TRANS_OR_CIS = "cis"

cancer_types = [
    "brca",
    "colon",
    "hnscc",
    "lscc",
    "luad",
    "ovarian"
]

# %% [markdown]
# ### Get t test proteomics results

# %%
p = ut.\
get_reshaped_ttest_results(CHROMOSOME, "p", TRANS_OR_CIS).\
drop(columns="Database_ID").\
assign(cnv_event="8p_loss")

q = ut.\
get_reshaped_ttest_results(CHROMOSOME, "q", TRANS_OR_CIS).\
drop(columns="Database_ID").\
assign(cnv_event="8q_gain")

prot = p.append(q).reset_index(drop=True)

prot
# Out:
#     cancer_type   protein         adj_p    change cnv_event
# 0          brca  ADAMDEC1  6.978531e-01 -0.298616   8p_loss
# 1          brca    AGPAT5  2.144297e-03 -0.849746   8p_loss
# 2          brca    ANGPT2  5.032264e-01  0.258756   8p_loss
# 3          brca  ARHGEF10  4.226186e-04 -0.728021   8p_loss
# 4          brca     ASAH1  2.771828e-02 -0.711515   8p_loss
# 5          brca  ATP6V1B2  1.433931e-04 -0.408102   8p_loss
# 6          brca      BIN3  3.055856e-02 -0.556700   8p_loss
# 7          brca       BLK  1.155079e-01  0.441371   8p_loss
# 8          brca      BMP1  1.624506e-01 -0.489983   8p_loss
# 9          brca    BNIP3L  1.985276e-02 -0.891026   8p_loss
# 10         brca     CDCA2  4.767438e-03 -1.091624   8p_loss
# 11         brca     CHMP7  3.019346e-10 -0.837215   8p_loss
# 12         brca       CLU  2.479576e-01 -0.504037   8p_loss
# 13         brca     CNOT7  3.966029e-03 -0.380232   8p_loss
# 14         brca      CTSB  3.399792e-01 -0.232382   8p_loss
# 15         brca     DCTN6  7.915616e-01 -0.040318   8p_loss
# 16         brca     DEFA3  8.361348e-01  0.135719   8p_loss
# 17         brca     DEFA4  4.100993e-01  0.477351   8p_loss
# 18         brca      DLC1  3.083942e-01 -0.348202   8p_loss
# 19         brca     DOCK5  5.516873e-05 -0.758086   8p_loss
# 20         brca      DOK2  4.298197e-01  0.260439   8p_loss
# 21         brca     DUSP4  4.095565e-01 -0.505099   8p_loss
# 22         brca      ERI1  5.900741e-06 -0.938963   8p_loss
# 23         brca    ERICH1  2.311901e-03 -0.759474   8p_loss
# 24         brca  FAM160B2  1.128806e-07 -1.060229   8p_loss
# 25         brca     FDFT1  1.202859e-02 -1.077669   8p_loss
# 26         brca       GSR  1.975415e-01 -0.386012   8p_loss
# 27         brca    GTF2E2  1.026565e-02 -0.411149   8p_loss
# 28         brca    HMBOX1  2.544025e-03 -0.638265   8p_loss
# 29         brca   KBTBD11  7.297365e-01 -0.097163   8p_loss
# ..          ...       ...           ...       ...       ...
# 867     ovarian     RIPK2  1.604380e-01  0.144530   8q_gain
# 868     ovarian     RMDN1  4.160149e-03  0.410246   8q_gain
# 869     ovarian    RNF139  7.989970e-02  0.315017   8q_gain
# 870     ovarian     RPL30  8.746887e-01 -0.020191   8q_gain
# 871     ovarian     RRM2B  1.597774e-01  0.173724   8q_gain
# 872     ovarian    SAMD12  1.827454e-01  0.355569   8q_gain
# 873     ovarian      SDC2  1.061582e-01  0.280739   8q_gain
# 874     ovarian  SLC25A32  3.357916e-01  0.136920   8q_gain
# 875     ovarian     SNTB1  5.375115e-02  0.324545   8q_gain
# 876     ovarian     SNX16  1.778949e-01  0.179731   8q_gain
# 877     ovarian     SPAG1  7.430188e-02  0.374982   8q_gain
# 878     ovarian      SQLE  7.430188e-02  0.306125   8q_gain
# 879     ovarian      STK3  8.234350e-03  0.240087   8q_gain
# 880     ovarian      SYBU  7.536144e-01  0.128215   8q_gain
# 881     ovarian      TAF2  3.025737e-01  0.121151   8q_gain
# 882     ovarian    TATDN1  1.061582e-01  0.244207   8q_gain
# 883     ovarian    TATDN1  1.449791e-01  0.227106   8q_gain
# 884     ovarian    TMEM65  4.160149e-03  0.469312   8q_gain
# 885     ovarian     TRPS1  1.711511e-02  0.372982   8q_gain
# 886     ovarian    TSPYL5  6.672297e-01  0.140233   8q_gain
# 887     ovarian      UBR5  9.150376e-01  0.010222   8q_gain
# 888     ovarian     UQCRB  7.536144e-01  0.065211   8q_gain
# 889     ovarian     UTP23  7.400008e-01  0.058124   8q_gain
# 890     ovarian    VPS13B  9.803842e-01 -0.008326   8q_gain
# 891     ovarian    WDYHV1  9.945359e-01 -0.005800   8q_gain
# 892     ovarian     YWHAZ  1.678163e-04  0.386049   8q_gain
# 893     ovarian    ZFAND1  1.484664e-03  0.436016   8q_gain
# 894     ovarian      ZHX1  1.066853e-01  0.190470   8q_gain
# 895     ovarian      ZHX2  7.238860e-01  0.053651   8q_gain
# 896     ovarian    ZNF706  3.018671e-02  0.286417   8q_gain
#
# [897 rows x 5 columns]

# %% [markdown]
# ### Add locations

# %%
locs = ut.\
get_gene_locations().\
reset_index().\
drop(columns="Database_ID").\
dropna(how="any").\
drop_duplicates(keep="first").\
sort_values(by="Name")

locs
# Out:
#                Name chromosome     start_bp       end_bp arm
# 25370          A1BG         19   58345178.0   58353492.0   q
# 71458      A1BG-AS1         19   58347718.0   58355455.0   q
# 49644          A1CF         10   50799409.0   50885675.0   q
# 2990            A2M         12    9067664.0    9116229.0   p
# 52644       A2M-AS1         12    9065163.0    9068689.0   p
# 14408         A2ML1         12    8822621.0    8887001.0   p
# 88822     A2ML1-AS1         12    8776219.0    8830947.0   p
# 76697     A2ML1-AS2         12    8819816.0    8820713.0   p
# 29096         A2MP1         12    9228533.0    9275817.0   p
# 9213        A3GALT2          1   33306766.0   33321098.0   p
# 45833        A4GALT         22   42692121.0   42721298.0   q
# 71649         A4GNT          3  138123713.0  138132390.0   q
# 18378          AAAS         12   53307456.0   53324864.0   q
# 3765           AACS         12  125065434.0  125143333.0   q
# 41894        AACSP1          5  178764861.0  178818435.0   q
# 9342          AADAC          3  151814073.0  151828488.0   q
# 61659       AADACL2          3  151733916.0  151761339.0   q
# 30241   AADACL2-AS1          3  151751443.0  151928175.0   q
# 4153        AADACL3          1   12716110.0   12728760.0   p
# 47236       AADACL4          1   12644547.0   12667086.0   p
# 31624       AADACP1          3  151770428.0  151784894.0   q
# 1767          AADAT          4  170060222.0  170091699.0   q
# 6768          AAGAB         15   67200667.0   67255195.0   q
# 22917          AAK1          2   69457997.0   69674349.0   p
# 50446         AAMDC         11   77821109.0   77918432.0   q
# 59624          AAMP          2  218264123.0  218270257.0   q
# 38768         AANAT         17   76453351.0   76470117.0   q
# 6192           AAR2         20   36236459.0   36270918.0   q
# 92440          AARD          8  116938207.0  116944487.0   q
# 8352          AARS2          6   44298731.0   44313347.0   p
# ...             ...        ...          ...          ...  ..
# 42940       ZSCAN5C         19   56202301.0   56209452.0   q
# 77619      ZSCAN5DP         19   56244043.0   56247482.0   q
# 13378        ZSCAN9          6   28224886.0   28233482.0   p
# 80591        ZSWIM1         20   45881227.0   45885266.0   q
# 40819        ZSWIM2          2  186827475.0  186849208.0   q
# 13276        ZSWIM3         20   45857614.0   45879122.0   q
# 24906        ZSWIM5          1   45016399.0   45306209.0   p
# 67979      ZSWIM5P1         17   15768717.0   15771426.0   p
# 70612      ZSWIM5P2         17   20583758.0   20591180.0   p
# 98770      ZSWIM5P3          4  129135926.0  129139740.0   q
# 21524        ZSWIM6          5   61332258.0   61546172.0   q
# 49492        ZSWIM7         17   15976560.0   15999717.0   p
# 4159         ZSWIM8         10   73785582.0   73801797.0   q
# 51717    ZSWIM8-AS1         10   73796514.0   73801399.0   q
# 25769        ZSWIM9         19   48170680.0   48197620.0   q
# 68246          ZUP1          6  116635618.0  116668794.0   q
# 1476           ZW10         11  113733187.0  113773735.0   q
# 58764        ZWILCH         15   66504959.0   66550130.0   q
# 15688         ZWINT         10   56357227.0   56361273.0   q
# 2196           ZXDA          X   57906708.0   57910820.0   p
# 44406          ZXDB          X   57591652.0   57597545.0   p
# 86866          ZXDC          3  126437601.0  126475891.0   q
# 33088        ZYG11A          1   52842511.0   52894998.0   p
# 75065      ZYG11AP1          9  102611162.0  102612155.0   q
# 4507         ZYG11B          1   52726453.0   52827336.0   p
# 3731            ZYX          7  143381295.0  143391111.0   q
# 68417         ZYXP1          8  137424904.0  137425021.0   q
# 77200         ZZEF1         17    4004445.0    4143030.0   p
# 56272  hsa-mir-1253         17    2748078.0    2748182.0   p
# 59789   hsa-mir-423         17   30117079.0   30117172.0   q
#
# [57366 rows x 5 columns]

# %%
prot = prot.merge(
    right=locs,
    how="inner",
    left_on=["protein"],
    right_on=["Name"]
).sort_values(by=["cancer_type", "chromosome", "arm", "start_bp"])

prot = prot.assign(chromosome="chr" + prot["chromosome"])

# %%
prot
# Out:
#     cancer_type   protein     adj_p    change cnv_event      Name chromosome  \
# 343        brca      TDRP  0.556640 -0.210114   8p_loss      TDRP       chr8
# 123        brca    ERICH1  0.002312 -0.759474   8p_loss    ERICH1       chr8
# 17         brca  ARHGEF10  0.000423 -0.728021   8p_loss  ARHGEF10       chr8
# 151        brca   KBTBD11  0.729737 -0.097163   8p_loss   KBTBD11       chr8
# 213        brca     MYOM2  0.096691 -1.938151   8p_loss     MYOM2       chr8
# 12         brca    ANGPT2  0.503226  0.258756   8p_loss    ANGPT2       chr8
# 6          brca    AGPAT5  0.002144 -0.849746   8p_loss    AGPAT5       chr8
# 94         brca     DEFA4  0.410099  0.477351   8p_loss     DEFA4       chr8
# 89         brca     DEFA3  0.836135  0.135719   8p_loss     DEFA3       chr8
# 185        brca    MFHAS1  0.316798  0.274803   8p_loss    MFHAS1       chr8
# 117        brca      ERI1  0.000006 -0.938963   8p_loss      ERI1       chr8
# 348        brca      TNKS  0.023016 -0.453753   8p_loss      TNKS       chr8
# 196        brca      MSRA  0.047172 -0.501198   8p_loss      MSRA       chr8
# 260        brca     PINX1  0.012342 -0.710316   8p_loss     PINX1       chr8
# 205        brca     MTMR9  0.000124 -0.604383   8p_loss     MTMR9       chr8
# 41         brca       BLK  0.115508  0.441371   8p_loss       BLK       chr8
# 227        brca     NEIL2  0.000054 -1.139554   8p_loss     NEIL2       chr8
# 133        brca     FDFT1  0.012029 -1.077669   8p_loss     FDFT1       chr8
# 77         brca      CTSB  0.339979 -0.232382   8p_loss      CTSB       chr8
# 99         brca      DLC1  0.308394 -0.348202   8p_loss      DLC1       chr8
# 190        brca      MSR1  0.556640 -0.155235   8p_loss      MSR1       chr8
# 71         brca     CNOT7  0.003966 -0.380232   8p_loss     CNOT7       chr8
# 353        brca    VPS37A  0.000423 -0.462302   8p_loss    VPS37A       chr8
# 202        brca     MTMR7  0.017136 -0.700970   8p_loss     MTMR7       chr8
# 329        brca    SLC7A2  0.001270 -1.858824   8p_loss    SLC7A2       chr8
# 245        brca    PDGFRL  0.400447 -0.397252   8p_loss    PDGFRL       chr8
# 211        brca     MTUS1  0.000175 -1.146884   8p_loss     MTUS1       chr8
# 212        brca     MTUS1  0.043723 -1.102746   8p_loss     MTUS1       chr8
# 23         brca     ASAH1  0.027718 -0.711515   8p_loss     ASAH1       chr8
# 216        brca      NAT1  0.025426 -1.473198   8p_loss      NAT1       chr8
# ..          ...       ...       ...       ...       ...       ...        ...
# 628     ovarian    NUDCD1  0.074302  0.218123   8q_gain    NUDCD1       chr8
# 505     ovarian      ENY2  0.832290  0.031422   8q_gain      ENY2       chr8
# 488     ovarian     EBAG9  0.111626  0.254629   8q_gain     EBAG9       chr8
# 786     ovarian      SYBU  0.753614  0.128215   8q_gain      SYBU       chr8
# 806     ovarian     TRPS1  0.017115  0.372982   8q_gain     TRPS1       chr8
# 829     ovarian     UTP23  0.740001  0.058124   8q_gain     UTP23       chr8
# 685     ovarian     RAD21  0.832290  0.020082   8q_gain     RAD21       chr8
# 568     ovarian     MED30  0.284379  0.111350   8q_gain     MED30       chr8
# 510     ovarian      EXT1  0.160438  0.288114   8q_gain      EXT1       chr8
# 499     ovarian     ENPP2  0.753614 -0.076658   8q_gain     ENPP2       chr8
# 791     ovarian      TAF2  0.302574  0.121151   8q_gain      TAF2       chr8
# 480     ovarian     DSCC1  0.250402  0.194812   8q_gain     DSCC1       chr8
# 464     ovarian    DEPTOR  0.777434  0.054003   8q_gain    DEPTOR       chr8
# 423     ovarian   COL14A1  0.959554  0.031190   8q_gain   COL14A1       chr8
# 574     ovarian    MRPL13  0.410312  0.087558   8q_gain    MRPL13       chr8
# 756     ovarian     SNTB1  0.053751  0.324545   8q_gain     SNTB1       chr8
# 867     ovarian      ZHX2  0.723886  0.053651   8q_gain      ZHX2       chr8
# 470     ovarian     DERL1  0.087539  0.356945   8q_gain     DERL1       chr8
# 861     ovarian      ZHX1  0.106685  0.190470   8q_gain      ZHX1       chr8
# 385     ovarian     ATAD2  0.748641  0.073793   8q_gain     ATAD2       chr8
# 839     ovarian    WDYHV1  0.994536 -0.005800   8q_gain    WDYHV1       chr8
# 528     ovarian   FAM91A1  0.250402  0.092972   8q_gain   FAM91A1       chr8
# 801     ovarian    TMEM65  0.004160  0.469312   8q_gain    TMEM65       chr8
# 726     ovarian    RNF139  0.079900  0.315017   8q_gain    RNF139       chr8
# 878     ovarian    TATDN1  0.106158  0.244207   8q_gain    TATDN1       chr8
# 879     ovarian    TATDN1  0.144979  0.227106   8q_gain    TATDN1       chr8
# 616     ovarian    NDUFB9  0.498362  0.089144   8q_gain    NDUFB9       chr8
# 592     ovarian     MTSS1  0.616765  0.113151   8q_gain     MTSS1       chr8
# 774     ovarian      SQLE  0.074302  0.306125   8q_gain      SQLE       chr8
# 622     ovarian    NSMCE2  0.929217 -0.016360   8q_gain    NSMCE2       chr8
#
#         start_bp       end_bp arm
# 343     489792.0     545781.0   p
# 123     614746.0     738106.0   p
# 17     1823926.0    1958641.0   p
# 151    1973677.0    2006936.0   p
# 213    2045046.0    2165552.0   p
# 12     6499651.0    6563409.0   p
# 6      6708642.0    6761503.0   p
# 94     6935820.0    6938306.0   p
# 89     7015869.0    7018297.0   p
# 185    8783354.0    8893630.0   p
# 117    9002147.0    9116746.0   p
# 348    9555912.0    9782346.0   p
# 196   10054292.0   10428891.0   p
# 260   10725399.0   10839847.0   p
# 205   11284816.0   11328146.0   p
# 41    11486894.0   11564599.0   p
# 227   11769639.0   11787345.0   p
# 133   11795573.0   11839304.0   p
# 77    11842524.0   11869448.0   p
# 99    13083361.0   13604610.0   p
# 190   16107878.0   16567490.0   p
# 71    17224966.0   17246878.0   p
# 353   17246931.0   17302427.0   p
# 202   17296794.0   17413528.0   p
# 329   17497088.0   17570573.0   p
# 245   17576433.0   17644071.0   p
# 211   17643795.0   17800917.0   p
# 212   17643795.0   17800917.0   p
# 23    18055992.0   18084998.0   p
# 216   18170477.0   18223689.0   p
# ..           ...          ...  ..
# 628  109240919.0  109334118.0   q
# 505  109334324.0  109345954.0   q
# 488  109539711.0  109565996.0   q
# 786  109573978.0  109691791.0   q
# 806  115408496.0  115809673.0   q
# 829  116766505.0  116849463.0   q
# 685  116845934.0  116874776.0   q
# 568  117520713.0  117540262.0   q
# 510  117794490.0  118111853.0   q
# 499  119557086.0  119673453.0   q
# 791  119730774.0  119832841.0   q
# 480  119833976.0  119855894.0   q
# 464  119873717.0  120050918.0   q
# 423  120059780.0  120373573.0   q
# 574  120380761.0  120445402.0   q
# 756  120535745.0  120813273.0   q
# 867  122781655.0  122974510.0   q
# 470  123013170.0  123042302.0   q
# 861  123248451.0  123275541.0   q
# 385  123319850.0  123416350.0   q
# 839  123416726.0  123470028.0   q
# 528  123768439.0  123815452.0   q
# 801  124306189.0  124372692.0   q
# 726  124474738.0  124487914.0   q
# 878  124488485.0  124539458.0   q
# 879  124488485.0  124539458.0   q
# 616  124539101.0  124580648.0   q
# 592  124550790.0  124728429.0   q
# 774  124998497.0  125022283.0   q
# 622  125091679.0  125367120.0   q
#
# [880 rows x 10 columns]

# %%
summ = prot.groupby(["cancer_type", "cnv_event"]).agg(
    sig_ct=("adj_p", lambda x: (x <= 0.05).sum()),
    tot_ct=("adj_p", lambda x: x.size)
)

summ = summ.assign(sig_prop=summ["sig_ct"] / summ["tot_ct"])
summ
# Out:
#                        sig_ct  tot_ct  sig_prop
# cancer_type cnv_event
# brca        8p_loss      38.0    70.0  0.542857
#             8q_gain      45.0    91.0  0.494505
# colon       8p_loss      21.0    46.0  0.456522
#             8q_gain      28.0    68.0  0.411765
# hnscc       8p_loss      27.0    65.0  0.415385
#             8q_gain      27.0    83.0  0.325301
# lscc        8p_loss      30.0    67.0  0.447761
#             8q_gain      30.0    89.0  0.337079
# luad        8p_loss      40.0    64.0  0.625000
#             8q_gain      37.0    89.0  0.415730
# ovarian     8p_loss      29.0    63.0  0.460317
#             8q_gain      21.0    85.0  0.247059

# %%
(prot[(prot["cancer_type"] == "hnscc") & (prot["cnv_event"] == "8p_loss")]["adj_p"] <= 0.05).sum()
# Out:
# 27

# %%
(prot[(prot["cancer_type"] == "hnscc") & (prot["cnv_event"] == "8q_gain")]["adj_p"] <= 0.05).sum()
# Out:
# 27

# %% [markdown]
# ## Make plot

# %%
prot
# Out:
#     cancer_type   protein     adj_p    change cnv_event      Name chromosome  \
# 343        brca      TDRP  0.556640 -0.210114   8p_loss      TDRP       chr8
# 123        brca    ERICH1  0.002312 -0.759474   8p_loss    ERICH1       chr8
# 17         brca  ARHGEF10  0.000423 -0.728021   8p_loss  ARHGEF10       chr8
# 151        brca   KBTBD11  0.729737 -0.097163   8p_loss   KBTBD11       chr8
# 213        brca     MYOM2  0.096691 -1.938151   8p_loss     MYOM2       chr8
# 12         brca    ANGPT2  0.503226  0.258756   8p_loss    ANGPT2       chr8
# 6          brca    AGPAT5  0.002144 -0.849746   8p_loss    AGPAT5       chr8
# 94         brca     DEFA4  0.410099  0.477351   8p_loss     DEFA4       chr8
# 89         brca     DEFA3  0.836135  0.135719   8p_loss     DEFA3       chr8
# 185        brca    MFHAS1  0.316798  0.274803   8p_loss    MFHAS1       chr8
# 117        brca      ERI1  0.000006 -0.938963   8p_loss      ERI1       chr8
# 348        brca      TNKS  0.023016 -0.453753   8p_loss      TNKS       chr8
# 196        brca      MSRA  0.047172 -0.501198   8p_loss      MSRA       chr8
# 260        brca     PINX1  0.012342 -0.710316   8p_loss     PINX1       chr8
# 205        brca     MTMR9  0.000124 -0.604383   8p_loss     MTMR9       chr8
# 41         brca       BLK  0.115508  0.441371   8p_loss       BLK       chr8
# 227        brca     NEIL2  0.000054 -1.139554   8p_loss     NEIL2       chr8
# 133        brca     FDFT1  0.012029 -1.077669   8p_loss     FDFT1       chr8
# 77         brca      CTSB  0.339979 -0.232382   8p_loss      CTSB       chr8
# 99         brca      DLC1  0.308394 -0.348202   8p_loss      DLC1       chr8
# 190        brca      MSR1  0.556640 -0.155235   8p_loss      MSR1       chr8
# 71         brca     CNOT7  0.003966 -0.380232   8p_loss     CNOT7       chr8
# 353        brca    VPS37A  0.000423 -0.462302   8p_loss    VPS37A       chr8
# 202        brca     MTMR7  0.017136 -0.700970   8p_loss     MTMR7       chr8
# 329        brca    SLC7A2  0.001270 -1.858824   8p_loss    SLC7A2       chr8
# 245        brca    PDGFRL  0.400447 -0.397252   8p_loss    PDGFRL       chr8
# 211        brca     MTUS1  0.000175 -1.146884   8p_loss     MTUS1       chr8
# 212        brca     MTUS1  0.043723 -1.102746   8p_loss     MTUS1       chr8
# 23         brca     ASAH1  0.027718 -0.711515   8p_loss     ASAH1       chr8
# 216        brca      NAT1  0.025426 -1.473198   8p_loss      NAT1       chr8
# ..          ...       ...       ...       ...       ...       ...        ...
# 628     ovarian    NUDCD1  0.074302  0.218123   8q_gain    NUDCD1       chr8
# 505     ovarian      ENY2  0.832290  0.031422   8q_gain      ENY2       chr8
# 488     ovarian     EBAG9  0.111626  0.254629   8q_gain     EBAG9       chr8
# 786     ovarian      SYBU  0.753614  0.128215   8q_gain      SYBU       chr8
# 806     ovarian     TRPS1  0.017115  0.372982   8q_gain     TRPS1       chr8
# 829     ovarian     UTP23  0.740001  0.058124   8q_gain     UTP23       chr8
# 685     ovarian     RAD21  0.832290  0.020082   8q_gain     RAD21       chr8
# 568     ovarian     MED30  0.284379  0.111350   8q_gain     MED30       chr8
# 510     ovarian      EXT1  0.160438  0.288114   8q_gain      EXT1       chr8
# 499     ovarian     ENPP2  0.753614 -0.076658   8q_gain     ENPP2       chr8
# 791     ovarian      TAF2  0.302574  0.121151   8q_gain      TAF2       chr8
# 480     ovarian     DSCC1  0.250402  0.194812   8q_gain     DSCC1       chr8
# 464     ovarian    DEPTOR  0.777434  0.054003   8q_gain    DEPTOR       chr8
# 423     ovarian   COL14A1  0.959554  0.031190   8q_gain   COL14A1       chr8
# 574     ovarian    MRPL13  0.410312  0.087558   8q_gain    MRPL13       chr8
# 756     ovarian     SNTB1  0.053751  0.324545   8q_gain     SNTB1       chr8
# 867     ovarian      ZHX2  0.723886  0.053651   8q_gain      ZHX2       chr8
# 470     ovarian     DERL1  0.087539  0.356945   8q_gain     DERL1       chr8
# 861     ovarian      ZHX1  0.106685  0.190470   8q_gain      ZHX1       chr8
# 385     ovarian     ATAD2  0.748641  0.073793   8q_gain     ATAD2       chr8
# 839     ovarian    WDYHV1  0.994536 -0.005800   8q_gain    WDYHV1       chr8
# 528     ovarian   FAM91A1  0.250402  0.092972   8q_gain   FAM91A1       chr8
# 801     ovarian    TMEM65  0.004160  0.469312   8q_gain    TMEM65       chr8
# 726     ovarian    RNF139  0.079900  0.315017   8q_gain    RNF139       chr8
# 878     ovarian    TATDN1  0.106158  0.244207   8q_gain    TATDN1       chr8
# 879     ovarian    TATDN1  0.144979  0.227106   8q_gain    TATDN1       chr8
# 616     ovarian    NDUFB9  0.498362  0.089144   8q_gain    NDUFB9       chr8
# 592     ovarian     MTSS1  0.616765  0.113151   8q_gain     MTSS1       chr8
# 774     ovarian      SQLE  0.074302  0.306125   8q_gain      SQLE       chr8
# 622     ovarian    NSMCE2  0.929217 -0.016360   8q_gain    NSMCE2       chr8
#
#         start_bp       end_bp arm
# 343     489792.0     545781.0   p
# 123     614746.0     738106.0   p
# 17     1823926.0    1958641.0   p
# 151    1973677.0    2006936.0   p
# 213    2045046.0    2165552.0   p
# 12     6499651.0    6563409.0   p
# 6      6708642.0    6761503.0   p
# 94     6935820.0    6938306.0   p
# 89     7015869.0    7018297.0   p
# 185    8783354.0    8893630.0   p
# 117    9002147.0    9116746.0   p
# 348    9555912.0    9782346.0   p
# 196   10054292.0   10428891.0   p
# 260   10725399.0   10839847.0   p
# 205   11284816.0   11328146.0   p
# 41    11486894.0   11564599.0   p
# 227   11769639.0   11787345.0   p
# 133   11795573.0   11839304.0   p
# 77    11842524.0   11869448.0   p
# 99    13083361.0   13604610.0   p
# 190   16107878.0   16567490.0   p
# 71    17224966.0   17246878.0   p
# 353   17246931.0   17302427.0   p
# 202   17296794.0   17413528.0   p
# 329   17497088.0   17570573.0   p
# 245   17576433.0   17644071.0   p
# 211   17643795.0   17800917.0   p
# 212   17643795.0   17800917.0   p
# 23    18055992.0   18084998.0   p
# 216   18170477.0   18223689.0   p
# ..           ...          ...  ..
# 628  109240919.0  109334118.0   q
# 505  109334324.0  109345954.0   q
# 488  109539711.0  109565996.0   q
# 786  109573978.0  109691791.0   q
# 806  115408496.0  115809673.0   q
# 829  116766505.0  116849463.0   q
# 685  116845934.0  116874776.0   q
# 568  117520713.0  117540262.0   q
# 510  117794490.0  118111853.0   q
# 499  119557086.0  119673453.0   q
# 791  119730774.0  119832841.0   q
# 480  119833976.0  119855894.0   q
# 464  119873717.0  120050918.0   q
# 423  120059780.0  120373573.0   q
# 574  120380761.0  120445402.0   q
# 756  120535745.0  120813273.0   q
# 867  122781655.0  122974510.0   q
# 470  123013170.0  123042302.0   q
# 861  123248451.0  123275541.0   q
# 385  123319850.0  123416350.0   q
# 839  123416726.0  123470028.0   q
# 528  123768439.0  123815452.0   q
# 801  124306189.0  124372692.0   q
# 726  124474738.0  124487914.0   q
# 878  124488485.0  124539458.0   q
# 879  124488485.0  124539458.0   q
# 616  124539101.0  124580648.0   q
# 592  124550790.0  124728429.0   q
# 774  124998497.0  125022283.0   q
# 622  125091679.0  125367120.0   q
#
# [880 rows x 10 columns]

# %%
def pval_plot(df, title, group_col, val_col, color_col, dx, y=True, sig=0.05):
    
    df = df.sort_values(by=[
        "chromosome",
        "arm",
        "start_bp",
        "end_bp"
    ])
    
    val_log_col = "neg_log_p"
    log_cutoff = -np.log10(sig)
    df = df.assign(**{val_log_col: - np.log10(df[val_col])})
    
    if y:
        chart_y = alt.Y(
            val_log_col,
            title=val_log_col
        )
        
    else:
        chart_y = alt.Y(
            val_log_col,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=None
            )
        )
        
    chart = alt.Chart(df).mark_point().encode(
        x=alt.X(
            group_col,
            title="Protein",
            sort=df["Name"].tolist()
        ),
        y=chart_y,
        color=color_col
    )
    
    line = alt.Chart(pd.DataFrame({
        'y': [log_cutoff],
        "label": [f"-log({sig})"]
    })).mark_rule(color="crimson").encode(
        y="y"
    )

    text = line.mark_text(
        align="right",
        dx=dx
    ).encode(
        text="label"
    )

    if y:
        return (chart + line + text).properties(title=title)
    else:
        return (chart + line).properties(title=title)

alt.vconcat(
    pval_plot(prot[prot["cnv_event"] == "8p_loss"], "8p loss", "Name", "adj_p", "cancer_type", -755),
    pval_plot(prot[prot["cnv_event"] == "8q_gain"], "8q gain", "Name", "adj_p", "cancer_type", -955)
).resolve_scale(y="shared").configure_title(anchor="start", dx=70)
# Out:
# alt.VConcatChart(...)
