# %% [markdown]
# # Check the location of proteins that pass as equivalently expressed between samples with and without the event
#
# If they're close to each other, that may indicate regulation of transcription to ameliorate the effects of CNVs.

# %%
import pandas as pd
import numpy as np
import altair as alt
import cnvutils as ut

# %%
CHROMOSOME = "8"
ARM = "p"
CIS_OR_TRANS = "cis"

# %%
equiv = pd.read_csv(f"pancancer_summary_equiv_{CHROMOSOME}{ARM}_{CIS_OR_TRANS}.tsv", sep="\t")

# %%
equiv
# Out:
#      protein                             cancers  num_cancers
# 0       MSR1  brca_colon_hnscc_lscc_luad_ovarian            6
# 1   ADAMDEC1               brca_colon_hnscc_lscc            4
# 2        CLU               brca_colon_hnscc_lscc            4
# 3       DOK2             brca_colon_lscc_ovarian            4
# 4      LZTS1             brca_hnscc_lscc_ovarian            4
# 5      DEFA4                    brca_colon_hnscc            3
# 6      LOXL2                     brca_colon_lscc            3
# 7     POLR3D                     brca_colon_luad            3
# 8     ANGPT2                     brca_hnscc_lscc            3
# 9       CTSB                     brca_hnscc_lscc            3
# 10       LPL                     brca_hnscc_lscc            3
# 11     RBPMS                     brca_hnscc_lscc            3
# 12     DCTN6                   brca_lscc_ovarian            3
# 13    PDGFRL                   brca_lscc_ovarian            3
# ...

# %%
ut.make_chromosome_plot(
    chromo="8",
    arm="p",
    genes=equiv["protein"]
)
# Out:
# <module 'matplotlib.pyplot' from '/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/matplotlib/pyplot.py'>
