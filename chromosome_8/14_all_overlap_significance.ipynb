# %% [markdown]
# # Assign overlap p values to individual proteins and perform multiple testing correction

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest

# %%
CHROMOSOMES = ["8"]
ARMS = ["p", "q"]
TRANS_OR_CIS_OPTS = ["cis", "trans"]

# %% [markdown]
# ## Load files

# %%
all_overlaps = pd.DataFrame()
all_pvals = pd.DataFrame()

for CHROMOSOME in CHROMOSOMES:
    for ARM in ARMS:
        for TRANS_OR_CIS in TRANS_OR_CIS_OPTS:
            
            overlaps = pd.\
            read_csv(f"pancancer_summary_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            pvals = pd.\
            read_csv(f"overlap_pvals_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            all_overlaps = all_overlaps.append(overlaps)
            all_pvals = all_pvals.append(pvals)

# %% [markdown]
# ## Merge in the _p_ values for each protein
#
# We will exclude proteins that were only different in one cancer type (no overlap).

# %%
all_overlaps = all_overlaps[all_overlaps["num_cancers"] > 1].\
merge(
    right=all_pvals,
    left_on=["num_cancers", "group"],
    right_on=["overlap_size", "group"],
    how="inner"
)

# %% [markdown]
# ## Apply multiple testing correction

# %%
reject, adj_pvals, alpha_sidak, alpha_bonf = statsmodels.stats.multitest.multipletests(
    pvals=all_overlaps["pvals"], 
    alpha=0.05, 
    method="fdr_bh"
)

all_overlaps = all_overlaps.\
assign(adj_p=adj_pvals)

all_overlaps = all_overlaps[all_overlaps["adj_p"] <= 0.05].\
sort_values(by=["adj_p", "protein", "group"])

# %% [markdown]
# ## Split table by protein group

# %%
groups = { group:df.reset_index(drop=True) for group, df in all_overlaps.groupby("group")}
pd.options.display.max_rows = None

# %% [markdown]
# ## Print results

# %%
groups["8p_cis"]
# Out:
#     protein                             cancers  mean_simp_change  \
# 0    AGPAT5  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 1  ATP6V1B2  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 2     CHMP7  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 3      ERI1  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 4    KIF13B  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 5      MSRA  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 6   PPP2R2A  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 7    VPS37A  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 8      XPO7  brca_colon_hnscc_lscc_luad_ovarian              -1.0
#
#    num_cancers   group  overlap_size     pvals     adj_p
# 0            6  8p_cis             6  0.005844  0.036096
# 1            6  8p_cis             6  0.005844  0.036096
# 2            6  8p_cis             6  0.005844  0.036096
# 3            6  8p_cis             6  0.005844  0.036096
# 4            6  8p_cis             6  0.005844  0.036096
# 5            6  8p_cis             6  0.005844  0.036096
# 6            6  8p_cis             6  0.005844  0.036096
# 7            6  8p_cis             6  0.005844  0.036096
# 8            6  8p_cis             6  0.005844  0.036096

# %%
groups["8p_trans"]
# Out:
#      protein          cancers  mean_simp_change  num_cancers     group  \
# 0   ATP6V1E1  colon_lscc_luad              -1.0            3  8p_trans
# 1    ATP6V1H  colon_lscc_luad              -1.0            3  8p_trans
# 2      CNOT8   brca_lscc_luad               1.0            3  8p_trans
# 3    ATP6V1A       colon_luad              -1.0            2  8p_trans
# 4   ATP6V1G1       colon_lscc              -1.0            2  8p_trans
# 5     CRELD2       colon_lscc              -1.0            2  8p_trans
# 6     CYB5R4        lscc_luad              -1.0            2  8p_trans
# 7     CYP7B1       hnscc_lscc              -1.0            2  8p_trans
# 8    DNAJC19       colon_lscc               1.0            2  8p_trans
# 9   HIST1H1D       hnscc_luad              -1.0            2  8p_trans
# 10     MTMR6        lscc_luad              -1.0            2  8p_trans
# 11      PPIB        lscc_luad              -1.0            2  8p_trans
# 12     PRKCB        lscc_luad              -1.0            2  8p_trans
# 13     SMAP2       hnscc_lscc              -1.0            2  8p_trans
#
#     overlap_size     pvals     adj_p
# 0              3  0.000019  0.000565
# 1              3  0.000019  0.000565
# 2              3  0.000019  0.000565
# 3              2  0.006707  0.036096
# 4              2  0.006707  0.036096
# 5              2  0.006707  0.036096
# 6              2  0.006707  0.036096
# 7              2  0.006707  0.036096
# 8              2  0.006707  0.036096
# 9              2  0.006707  0.036096
# 10             2  0.006707  0.036096
# 11             2  0.006707  0.036096
# 12             2  0.006707  0.036096
# 13             2  0.006707  0.036096

# %%
groups["8q_cis"]
# Out:
#   protein                             cancers  mean_simp_change  num_cancers  \
# 0   CPNE3  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 1  NUDCD1  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 2  OTUD6B  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 3    POP1  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 4    RIDA  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 5   RMDN1  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 6    STK3  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 7   YWHAZ  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
#
#     group  overlap_size     pvals     adj_p
# 0  8q_cis             6  0.004409  0.036096
# 1  8q_cis             6  0.004409  0.036096
# 2  8q_cis             6  0.004409  0.036096
# 3  8q_cis             6  0.004409  0.036096
# 4  8q_cis             6  0.004409  0.036096
# 5  8q_cis             6  0.004409  0.036096
# 6  8q_cis             6  0.004409  0.036096
# 7  8q_cis             6  0.004409  0.036096

# %%
groups["8q_trans"]
# Out:
#     protein                     cancers  mean_simp_change  num_cancers  \
# 0     STAU2  brca_colon_hnscc_lscc_luad               1.0            5
# 1    YTHDF3  brca_colon_hnscc_lscc_luad               1.0            5
# 2   ARFGEF1       brca_colon_hnscc_luad               1.0            4
# 3      CYC1        brca_colon_lscc_luad               1.0            4
# 4      HGH1       brca_colon_hnscc_luad               1.0            4
# 5      HSF1        brca_hnscc_lscc_luad               1.0            4
# 6     MTFR1        brca_hnscc_lscc_luad               1.0            4
# 7      AGO2             brca_colon_luad               1.0            3
# 8    ANKFY1             brca_colon_lscc              -1.0            3
# 9      BOP1             brca_colon_lscc               1.0            3
# 10      GGH             brca_colon_lscc               1.0            3
# 11   MRPL15            brca_colon_hnscc               1.0            3
# 12   MRPL39            brca_colon_hnscc               1.0            3
# 13   MRPL45            brca_colon_hnscc               1.0            3
# 14    NCOA2              brca_lscc_luad               1.0            3
# 15  PHF20L1              brca_lscc_luad               1.0            3
# 16    PRKDC             brca_colon_lscc               1.0            3
# 17     PTK2             brca_colon_luad               1.0            3
# 18    RDH10             brca_colon_lscc               1.0            3
# 19   TMEM70             brca_colon_luad               1.0            3
# 20    UQCC2             brca_colon_luad               1.0            3
# 21   UQCR10             brca_colon_lscc               1.0            3
# 22    UQCRH             brca_colon_luad               1.0            3
# 23   ZBTB10           brca_luad_ovarian               1.0            3
#
#        group  overlap_size     pvals     adj_p
# 0   8q_trans             5  0.000000  0.000000
# 1   8q_trans             5  0.000000  0.000000
# 2   8q_trans             4  0.000009  0.000367
# 3   8q_trans             4  0.000009  0.000367
# 4   8q_trans             4  0.000009  0.000367
# 5   8q_trans             4  0.000009  0.000367
# 6   8q_trans             4  0.000009  0.000367
# 7   8q_trans             3  0.001316  0.014431
# 8   8q_trans             3  0.001316  0.014431
# 9   8q_trans             3  0.001316  0.014431
# 10  8q_trans             3  0.001316  0.014431
# 11  8q_trans             3  0.001316  0.014431
# 12  8q_trans             3  0.001316  0.014431
# 13  8q_trans             3  0.001316  0.014431
# 14  8q_trans             3  0.001316  0.014431
# 15  8q_trans             3  0.001316  0.014431
# 16  8q_trans             3  0.001316  0.014431
# 17  8q_trans             3  0.001316  0.014431
# 18  8q_trans             3  0.001316  0.014431
# 19  8q_trans             3  0.001316  0.014431
# 20  8q_trans             3  0.001316  0.014431
# 21  8q_trans             3  0.001316  0.014431
# 22  8q_trans             3  0.001316  0.014431
# 23  8q_trans             3  0.001316  0.014431

# %% [markdown]
# ## Save results

# %%
all_overlaps.to_csv("sig_diff_all_overlaps.tsv", sep="\t", index=False)
