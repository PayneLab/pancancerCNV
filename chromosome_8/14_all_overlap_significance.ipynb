# %% [markdown]
# # Assign overlap p values to individual proteins and perform multiple testing correction

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest

# %%
CHROMOSOMES = ["8"]
ARMS = ["p", "q"]
TRANS_OR_CIS_OPTS = ["cis", "trans"]

# %% [markdown]
# ## Load files

# %%
all_overlaps = pd.DataFrame()
all_pvals = pd.DataFrame()

for CHROMOSOME in CHROMOSOMES:
    for ARM in ARMS:
        for TRANS_OR_CIS in TRANS_OR_CIS_OPTS:
            
            overlaps = pd.\
            read_csv(f"pancancer_summary_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            pvals = pd.\
            read_csv(f"overlap_pvals_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            all_overlaps = all_overlaps.append(overlaps)
            all_pvals = all_pvals.append(pvals)

# %% [markdown]
# ## Merge in the _p_ values for each protein
#
# We will exclude proteins that were only different in one cancer type (no overlap).

# %%
all_overlaps = all_overlaps[all_overlaps["num_cancers"] > 1].\
merge(
    right=all_pvals,
    left_on=["num_cancers", "group"],
    right_on=["overlap_size", "group"],
    how="inner"
)

# %% [markdown]
# ## Apply multiple testing correction

# %%
reject, adj_pvals, alpha_sidak, alpha_bonf = statsmodels.stats.multitest.multipletests(
    pvals=all_overlaps["pvals"], 
    alpha=0.05, 
    method="fdr_bh"
)

all_overlaps = all_overlaps.\
assign(adj_p=adj_pvals)

all_overlaps = all_overlaps[all_overlaps["adj_p"] <= 0.05].\
sort_values(by=["adj_p", "protein", "group"])

# %% [markdown]
# ## Split table by protein group

# %%
groups = { group:df.reset_index(drop=True) for group, df in all_overlaps.groupby("group")}
pd.options.display.max_rows = None

# %% [markdown]
# ## Print results

# %%
groups["8p_cis"]
# Out:
#     protein                             cancers  mean_simp_change  \
# 0    AGPAT5  brca_colon_hnscc_lscc_luad_ovarian                -1
# 1  ATP6V1B2  brca_colon_hnscc_lscc_luad_ovarian                -1
# 2     CHMP7  brca_colon_hnscc_lscc_luad_ovarian                -1
# 3      ERI1  brca_colon_hnscc_lscc_luad_ovarian                -1
# 4    PPP2CB  brca_colon_hnscc_lscc_luad_ovarian                -1
# 5   PPP2R2A  brca_colon_hnscc_lscc_luad_ovarian                -1
# 6     SARAF  brca_colon_hnscc_lscc_luad_ovarian                -1
# 7    VPS37A  brca_colon_hnscc_lscc_luad_ovarian                -1
# 8      XPO7  brca_colon_hnscc_lscc_luad_ovarian                -1
#
#    num_cancers   group  overlap_size     pvals     adj_p
# 0            6  8p_cis             6  0.006474  0.029644
# 1            6  8p_cis             6  0.006474  0.029644
# 2            6  8p_cis             6  0.006474  0.029644
# 3            6  8p_cis             6  0.006474  0.029644
# 4            6  8p_cis             6  0.006474  0.029644
# 5            6  8p_cis             6  0.006474  0.029644
# 6            6  8p_cis             6  0.006474  0.029644
# 7            6  8p_cis             6  0.006474  0.029644
# 8            6  8p_cis             6  0.006474  0.029644

# %%
groups["8p_trans"]
# Out:
#     protein     cancers  mean_simp_change  num_cancers     group  \
# 0   ATP6V1A  colon_luad                -1            2  8p_trans
# 1  ATP6V1E1  colon_luad                -1            2  8p_trans
# 2   ATP6V1H  colon_luad                -1            2  8p_trans
# 3     CNOT8   brca_luad                 1            2  8p_trans
# 4  HIST1H1D  hnscc_luad                -1            2  8p_trans
#
#    overlap_size     pvals     adj_p
# 0             2  0.001777  0.014728
# 1             2  0.001777  0.014728
# 2             2  0.001777  0.014728
# 3             2  0.001777  0.014728
# 4             2  0.001777  0.014728

# %%
groups["8q_cis"]
# Out:
#     protein                             cancers  mean_simp_change  \
# 0     CPNE3  brca_colon_hnscc_lscc_luad_ovarian                 1
# 1    NUDCD1  brca_colon_hnscc_lscc_luad_ovarian                 1
# 2    OTUD6B  brca_colon_hnscc_lscc_luad_ovarian                 1
# 3      POP1  brca_colon_hnscc_lscc_luad_ovarian                 1
# 4      RIDA  brca_colon_hnscc_lscc_luad_ovarian                 1
# 5     RMDN1  brca_colon_hnscc_lscc_luad_ovarian                 1
# 6      STK3  brca_colon_hnscc_lscc_luad_ovarian                 1
# 7     YWHAZ  brca_colon_hnscc_lscc_luad_ovarian                 1
# 8     EBAG9       brca_colon_hnscc_luad_ovarian                 1
# 9   FAM91A1          brca_colon_hnscc_lscc_luad                 1
# 10     MTDH       brca_colon_hnscc_lscc_ovarian                 1
# 11    SPAG1       brca_colon_hnscc_luad_ovarian                 1
# 12     SQLE          brca_colon_hnscc_lscc_luad                 1
#
#     num_cancers   group  overlap_size     pvals     adj_p
# 0             6  8q_cis             6  0.002510  0.015060
# 1             6  8q_cis             6  0.002510  0.015060
# 2             6  8q_cis             6  0.002510  0.015060
# 3             6  8q_cis             6  0.002510  0.015060
# 4             6  8q_cis             6  0.002510  0.015060
# 5             6  8q_cis             6  0.002510  0.015060
# 6             6  8q_cis             6  0.002510  0.015060
# 7             6  8q_cis             6  0.002510  0.015060
# 8             5  8q_cis             5  0.028758  0.046766
# 9             5  8q_cis             5  0.028758  0.046766
# 10            5  8q_cis             5  0.028758  0.046766
# 11            5  8q_cis             5  0.028758  0.046766
# 12            5  8q_cis             5  0.028758  0.046766

# %%
groups["8q_trans"]
# Out:
#      protein                cancers  mean_simp_change  num_cancers     group  \
# 0    ARFGEF1  brca_colon_hnscc_luad                 1            4  8q_trans
# 1       HGH1  brca_colon_hnscc_luad                 1            4  8q_trans
# 2      STAU2  brca_colon_hnscc_luad                 1            4  8q_trans
# 3     YTHDF3  brca_colon_hnscc_luad                 1            4  8q_trans
# 4       AGO2        brca_colon_luad                 1            3  8q_trans
# 5       CYC1        brca_colon_luad                 1            3  8q_trans
# 6       HSF1        brca_hnscc_luad                 1            3  8q_trans
# 7     MRPL15       brca_colon_hnscc                 1            3  8q_trans
# 8     MRPL39       brca_colon_hnscc                 1            3  8q_trans
# 9     MRPL45       brca_colon_hnscc                 1            3  8q_trans
# 10     MTFR1        brca_hnscc_luad                 1            3  8q_trans
# 11      PTK2        brca_colon_luad                 1            3  8q_trans
# 12    TMEM70        brca_colon_luad                 1            3  8q_trans
# 13     UQCC2        brca_colon_luad                 1            3  8q_trans
# 14     UQCRH        brca_colon_luad                 1            3  8q_trans
# 15    ZBTB10      brca_luad_ovarian                 1            3  8q_trans
# 16     AKAP1             brca_colon                 1            2  8q_trans
# 17    ANKFY1             brca_colon                -1            2  8q_trans
# 18      BOP1             brca_colon                 1            2  8q_trans
# 19   C8orf82             brca_colon                 1            2  8q_trans
# 20    CHRAC1              brca_luad                 1            2  8q_trans
# 21  COL4A3BP             brca_colon                -1            2  8q_trans
# 22     COQ8A             brca_colon                 1            2  8q_trans
# 23      DAP3             brca_colon                 1            2  8q_trans
# 24     DDX27             brca_colon                 1            2  8q_trans
# 25     DDX28             brca_hnscc                 1            2  8q_trans
# 26   DNAJC19             brca_colon                 1            2  8q_trans
# 27    FAM84B             colon_luad                 1            2  8q_trans
# 28       FBL             brca_colon                 1            2  8q_trans
# 29      GGCT              brca_luad                 0            2  8q_trans
# 30       GGH             brca_colon                 1            2  8q_trans
# 31     HSPD1             brca_colon                 1            2  8q_trans
# 32     HSPE1             brca_colon                 1            2  8q_trans
# 33    LACTB2             brca_hnscc                 1            2  8q_trans
# 34    LRPPRC             brca_colon                 1            2  8q_trans
# 35     LYRM4             brca_colon                 1            2  8q_trans
# 36    MALSU1             brca_colon                 1            2  8q_trans
# 37  MAPKAPK2             brca_hnscc                -1            2  8q_trans
# 38    MRPL10             brca_colon                 1            2  8q_trans
# 39    MRPL17             brca_colon                 1            2  8q_trans
# 40    MRPL19             brca_colon                 1            2  8q_trans
# 41     MRPL3             brca_colon                 1            2  8q_trans
# 42     MRPL4             brca_colon                 1            2  8q_trans
# 43    MRPL44             brca_colon                 1            2  8q_trans
# 44    MRPL47             brca_colon                 1            2  8q_trans
# 45    MRPL49             brca_colon                 1            2  8q_trans
# 46    MRPL53             brca_colon                 1            2  8q_trans
# 47   MRPS18A             brca_colon                 1            2  8q_trans
# 48    MRPS27             brca_colon                 1            2  8q_trans
# 49    MRPS31             brca_colon                 1            2  8q_trans
# 50     MRPS6             brca_colon                 1            2  8q_trans
# 51     MRPS7             brca_colon                 1            2  8q_trans
# 52     NCOA2              brca_luad                 1            2  8q_trans
# 53   NDUFAF4             brca_colon                 1            2  8q_trans
# 54   PHF20L1              brca_luad                 1            2  8q_trans
# 55     PNPT1             brca_colon                 1            2  8q_trans
# 56     PRKDC             brca_colon                 1            2  8q_trans
# 57     PRR15             brca_colon                 0            2  8q_trans
# 58     PTCD3             brca_colon                 1            2  8q_trans
# 59     PYCRL             brca_colon                 1            2  8q_trans
# 60    RB1CC1              brca_luad                 1            2  8q_trans
# 61     RDH10             brca_colon                 1            2  8q_trans
# 62     REXO4              brca_luad                 1            2  8q_trans
# 63      RRS1             brca_colon                 1            2  8q_trans
# 64     SMC1A             brca_colon                 1            2  8q_trans
# 65      SMC3             brca_colon                 1            2  8q_trans
# 66     THEM6             colon_luad                 1            2  8q_trans
# 67     THOC1              brca_luad                 1            2  8q_trans
# 68     THOC5              brca_luad                 1            2  8q_trans
# 69     THOC7              brca_luad                 1            2  8q_trans
# 70    TIMM13             brca_colon                 1            2  8q_trans
# 71    TIMM8A             brca_colon                 1            2  8q_trans
# 72    TOMM22              brca_luad                 1            2  8q_trans
# 73    TOMM70             brca_colon                 1            2  8q_trans
# 74     UBE2W              brca_luad                 1            2  8q_trans
# 75     UQCC1             colon_luad                 1            2  8q_trans
# 76     UQCC3             brca_hnscc                 1            2  8q_trans
# 77    UQCR10             brca_colon                 1            2  8q_trans
# 78    VCPIP1             brca_colon                 1            2  8q_trans
