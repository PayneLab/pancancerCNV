# %% [markdown]
# # Assign overlap p values to individual proteins and perform multiple testing correction

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest

# %%
CHROMOSOME = "8"
ARM = "q"
TRANS_OR_CIS = "trans"

# %%
overlaps = pd.read_csv(f"pancancer_summary_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t")
pvals = pd.read_csv(f"overlap_pvals_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t")

# %% [markdown]
# ## Merge in the _p_ values for each protein
#
# We will exclude proteins that were only different in one cancer type (no overlap).

# %%
overlaps = overlaps[overlaps["num_cancers"] > 1].\
merge(
    right=pvals,
    left_on="num_cancers",
    right_on="overlap_size",
    how="inner"
)

# %% [markdown]
# ## Apply multiple testing correction

# %%
reject, adj_pvals, alpha_sidak, alpha_bonf = statsmodels.stats.multitest.multipletests(
    pvals=overlaps["pvals"], 
    alpha=0.05, 
    method="fdr_bh"
)

overlaps = overlaps.assign(
    adj_p=adj_pvals
)

# %%
pd.options.display.max_rows = None
overlaps
# Out:
#      protein                cancers  mean_simp_change  num_cancers  \
# 0    ARFGEF1  brca_colon_hnscc_luad                 1            4
# 1       HGH1  brca_colon_hnscc_luad                 1            4
# 2      STAU2  brca_colon_hnscc_luad                 1            4
# 3     YTHDF3  brca_colon_hnscc_luad                 1            4
# 4     MRPL15       brca_colon_hnscc                 1            3
# 5     MRPL39       brca_colon_hnscc                 1            3
# 6     MRPL45       brca_colon_hnscc                 1            3
# 7       AGO2        brca_colon_luad                 1            3
# 8       CYC1        brca_colon_luad                 1            3
# 9       PTK2        brca_colon_luad                 1            3
# 10    TMEM70        brca_colon_luad                 1            3
# 11     UQCC2        brca_colon_luad                 1            3
# 12     UQCRH        brca_colon_luad                 1            3
# 13      HSF1        brca_hnscc_luad                 1            3
# 14     MTFR1        brca_hnscc_luad                 1            3
# 15    ZBTB10      brca_luad_ovarian                 1            3
# 16     AKAP1             brca_colon                 1            2
# 17    ANKFY1             brca_colon                -1            2
# 18      BOP1             brca_colon                 1            2
# 19   C8orf82             brca_colon                 1            2
# 20  COL4A3BP             brca_colon                -1            2
# 21     COQ8A             brca_colon                 1            2
# 22      DAP3             brca_colon                 1            2
# 23     DDX27             brca_colon                 1            2
# 24   DNAJC19             brca_colon                 1            2
# 25       FBL             brca_colon                 1            2
# 26       GGH             brca_colon                 1            2
# 27     HSPD1             brca_colon                 1            2
# 28     HSPE1             brca_colon                 1            2
# 29    LRPPRC             brca_colon                 1            2
# 30     LYRM4             brca_colon                 1            2
# 31    MALSU1             brca_colon                 1            2
# 32    MRPL10             brca_colon                 1            2
# 33    MRPL17             brca_colon                 1            2
# 34    MRPL19             brca_colon                 1            2
# 35     MRPL3             brca_colon                 1            2
# 36     MRPL4             brca_colon                 1            2
# 37    MRPL44             brca_colon                 1            2
# 38    MRPL47             brca_colon                 1            2
# 39    MRPL49             brca_colon                 1            2
# 40    MRPL53             brca_colon                 1            2
# 41   MRPS18A             brca_colon                 1            2
# 42    MRPS27             brca_colon                 1            2
# 43    MRPS31             brca_colon                 1            2
# 44     MRPS6             brca_colon                 1            2
# 45     MRPS7             brca_colon                 1            2
# 46   NDUFAF4             brca_colon                 1            2
# 47     PNPT1             brca_colon                 1            2
# 48     PRKDC             brca_colon                 1            2
# 49     PRR15             brca_colon                 0            2
# 50     PTCD3             brca_colon                 1            2
# 51     PYCRL             brca_colon                 1            2
# 52     RDH10             brca_colon                 1            2
# 53      RRS1             brca_colon                 1            2
# 54     SMC1A             brca_colon                 1            2
# 55      SMC3             brca_colon                 1            2
# 56    TIMM13             brca_colon                 1            2
# 57    TIMM8A             brca_colon                 1            2
# 58    TOMM70             brca_colon                 1            2
# 59    UQCR10             brca_colon                 1            2
# 60    VCPIP1             brca_colon                 1            2
# 61   XPNPEP1             brca_colon                -1            2
# 62     DDX28             brca_hnscc                 1            2
# 63    LACTB2             brca_hnscc                 1            2
# 64  MAPKAPK2             brca_hnscc                -1            2
# 65     UQCC3             brca_hnscc                 1            2
# 66    CHRAC1              brca_luad                 1            2
# 67      GGCT              brca_luad                 0            2
# 68     NCOA2              brca_luad                 1            2
# 69   PHF20L1              brca_luad                 1            2
# 70    RB1CC1              brca_luad                 1            2
# 71     REXO4              brca_luad                 1            2
# 72     THOC1              brca_luad                 1            2
# 73     THOC5              brca_luad                 1            2
# 74     THOC7              brca_luad                 1            2
# 75    TOMM22              brca_luad                 1            2
# 76     UBE2W              brca_luad                 1            2
# 77    FAM84B             colon_luad                 1            2
# 78     THEM6             colon_luad                 1            2
# 79     UQCC1             colon_luad                 1            2
#
#     overlap_size         pvals     adj_p
# 0              4  6.371091e-07  0.000013
# 1              4  6.371091e-07  0.000013
# 2              4  6.371091e-07  0.000013
# 3              4  6.371091e-07  0.000013
# 4              3  1.586402e-04  0.000793
# 5              3  1.586402e-04  0.000793
# 6              3  1.586402e-04  0.000793
# 7              3  1.586402e-04  0.000793
# 8              3  1.586402e-04  0.000793
# 9              3  1.586402e-04  0.000793
# 10             3  1.586402e-04  0.000793
# 11             3  1.586402e-04  0.000793
# 12             3  1.586402e-04  0.000793
# 13             3  1.586402e-04  0.000793
# 14             3  1.586402e-04  0.000793
# 15             3  1.586402e-04  0.000793
