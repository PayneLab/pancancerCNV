# %% [markdown]
# # Correlation between CNV event and mutation status of frequently mutated genes

# %%
import pandas as pd
import numpy as np
import os
import cptac
import cptac.utils as ut
import altair as alt
import scipy.stats
import statsmodels.stats.multitest

# %%
dss = {
    "brca": cptac.Brca,
#     "ccrcc": cptac.Ccrcc,
    "colon": cptac.Colon,
#     "endometrial": cptac.Endometrial,
#     "gbm": cptac.Gbm,
    "hnscc": cptac.Hnscc,
    "lscc": cptac.Lscc,
    "luad": cptac.Luad,
    "ovarian": cptac.Ovarian
}

# %%
def test_freq_mut_cnv_correlation(
    cancer_type,
    dss,
    mut_freq_cutoff=0.1
):
    # Load the dataset
    ds = dss[cancer_type]()
    
    # Run freq_mut, and get all genes with mutation frequency above cutoff
    freqs = ut.get_frequently_mutated(ds, cutoff=mut_freq_cutoff)
    freq_mut_genes = freqs["Gene"]
    
    # Get the mutations table, in a format that will be easy to join to
    mut = ds.join_metadata_to_mutations(
        metadata_df_name="clinical",
        mutations_genes=freq_mut_genes,
        metadata_cols=[], # This will format the table in the way we want
        mutations_filter=[],
        how="right",
        quiet=True,
        tissue_type="tumor"
    )
    
    # Get just the mutation status columns, and create a binarized version of them
    mut_status = mut.loc[:, mut.columns.isin([gene + "_Mutation_Status" for gene in freq_mut_genes])]
    mut_binary = pd.DataFrame(index=mut_status.index.copy())
    
    for col in mut_status:
        assert not pd.isnull(mut_status[col]).any()
        mut_binary = mut_binary.assign(**{col: np.where(mut_status[col] == "Wildtype_Tumor", False, True)})
        
    # Get the event table
    event = pd.\
    read_csv(f"{cancer_type}_has_event.tsv", sep="\t", index_col=0).\
    rename(columns={"gain_event": "8q_gain", "loss_event": "8p_loss"})
    
    pvals = []
    gene_col = []

    for cnv_col in event.columns:
        for mut_col in mut_binary.columns:

            # Create contingency table
            contingency_table = pd.crosstab(event[cnv_col], mut_binary[mut_col])

            # Run test
            chi2, p, dof, exp_freq = scipy.stats.chi2_contingency(contingency_table)
            
            gene_col.append(mut_col)

            # Check assumptions: No group has expected value < 1, and no more than
            # 20% of groups have expected frequency < 5.
            exp_freq = pd.DataFrame(exp_freq)

            if (exp_freq < 1).any().any():
                pvals.append("Not all expected frequencies were > 1.")
            elif (exp_freq < 5).sum().sum() > 0.2 * exp_freq.shape[0] * exp_freq.shape[1]:
                pvals.append("More than 20% of groups had expected frequency < 5.")
            else:
                pvals.append(p)
        
    pvals = pd.DataFrame({
        "cancer_type": cancer_type,
        "cnv_event": cnv_col,
        "gene": gene_col,
        "pval": pvals
    })
    
    return pvals

# %%
all_results = pd.DataFrame()

for cancer_type in dss.keys():
    cancer_res = test_freq_mut_cnv_correlation(cancer_type=cancer_type, dss=dss)
    all_results = all_results.append(cancer_res)
# Out:
# cptac warning: The HNSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 7)
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 7)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)
# cptac warning: Unknown mutation type RNA. Assigned lowest priority in filtering. (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 21)

# %%
all_results
# Out:
#     cancer_type cnv_event                           gene  \
# 0          brca   8p_loss         ABCA13_Mutation_Status
# 1          brca   8p_loss          AHNAK_Mutation_Status
# 2          brca   8p_loss         AHNAK2_Mutation_Status
# 3          brca   8p_loss           ANK2_Mutation_Status
# 4          brca   8p_loss         ARID1B_Mutation_Status
# 5          brca   8p_loss          ASH1L_Mutation_Status
# 6          brca   8p_loss         BOD1L1_Mutation_Status
# 7          brca   8p_loss           CDH1_Mutation_Status
# 8          brca   8p_loss         DNAH11_Mutation_Status
# 9          brca   8p_loss          DNAH7_Mutation_Status
# 10         brca   8p_loss           EDC4_Mutation_Status
# 11         brca   8p_loss           FAT3_Mutation_Status
# 12         brca   8p_loss            FLG_Mutation_Status
# 13         brca   8p_loss          FREM2_Mutation_Status
# 14         brca   8p_loss           FRG1_Mutation_Status
# 15         brca   8p_loss          FSIP2_Mutation_Status
# 16         brca   8p_loss          GATA3_Mutation_Status
# 17         brca   8p_loss          GPR98_Mutation_Status
# 18         brca   8p_loss          HMCN1_Mutation_Status
# 19         brca   8p_loss          HYDIN_Mutation_Status
# 20         brca   8p_loss           IL16_Mutation_Status
# 21         brca   8p_loss       KIAA1109_Mutation_Status
# 22         brca   8p_loss          KMT2C_Mutation_Status
# 23         brca   8p_loss           LRP2_Mutation_Status
# 24         brca   8p_loss         MAP3K1_Mutation_Status
# 25         brca   8p_loss         MT-CO1_Mutation_Status
# 26         brca   8p_loss         MT-CYB_Mutation_Status
# 27         brca   8p_loss         MT-ND1_Mutation_Status
# 28         brca   8p_loss         MT-ND4_Mutation_Status
# 29         brca   8p_loss         MT-ND5_Mutation_Status
# ..          ...       ...                            ...
# 98      ovarian   8p_loss         MT-CO1_Mutation_Status
# 99      ovarian   8p_loss         MT-CO2_Mutation_Status
# 100     ovarian   8p_loss         MT-CO3_Mutation_Status
# 101     ovarian   8p_loss         MT-ND5_Mutation_Status
# 102     ovarian   8p_loss          MUC12_Mutation_Status
# 103     ovarian   8p_loss          MUC16_Mutation_Status
# 104     ovarian   8p_loss          MUC17_Mutation_Status
# 105     ovarian   8p_loss           MUC4_Mutation_Status
# 106     ovarian   8p_loss          MUC5B_Mutation_Status
# 107     ovarian   8p_loss           NBEA_Mutation_Status
# 108     ovarian   8p_loss         NBPF10_Mutation_Status
# 109     ovarian   8p_loss          OBSCN_Mutation_Status
# 110     ovarian   8p_loss          POLA1_Mutation_Status
# 111     ovarian   8p_loss         PPP4R2_Mutation_Status
# 112     ovarian   8p_loss          PRKDC_Mutation_Status
# 113     ovarian   8p_loss  RP11-467N20.5_Mutation_Status
# 114     ovarian   8p_loss          RP1L1_Mutation_Status
# 115     ovarian   8p_loss           RYR1_Mutation_Status
# 116     ovarian   8p_loss           RYR3_Mutation_Status
# 117     ovarian   8p_loss      SPATA31D1_Mutation_Status
# 118     ovarian   8p_loss         SPHKAP_Mutation_Status
# 119     ovarian   8p_loss          STAB2_Mutation_Status
# 120     ovarian   8p_loss             TG_Mutation_Status
# 121     ovarian   8p_loss           TP53_Mutation_Status
# 122     ovarian   8p_loss            TTN_Mutation_Status
# 123     ovarian   8p_loss          USH2A_Mutation_Status
# 124     ovarian   8p_loss          WDFY4_Mutation_Status
# 125     ovarian   8p_loss         ZNF469_Mutation_Status
# 126     ovarian   8p_loss         ZNF831_Mutation_Status
# 127     ovarian   8p_loss         ZNF845_Mutation_Status
#
#                                                   pval
# 0                                             0.727568
# 1                                             0.325759
# 2    More than 20% of groups had expected frequency...
# 3    More than 20% of groups had expected frequency...
# 4    More than 20% of groups had expected frequency...
# 5    More than 20% of groups had expected frequency...
# 6    More than 20% of groups had expected frequency...
# 7    More than 20% of groups had expected frequency...
# 8    More than 20% of groups had expected frequency...
# 9    More than 20% of groups had expected frequency...
# 10   More than 20% of groups had expected frequency...
# 11   More than 20% of groups had expected frequency...
# 12                                            0.831214
# 13   More than 20% of groups had expected frequency...
# 14                                            0.903077
# 15   More than 20% of groups had expected frequency...
# 16   More than 20% of groups had expected frequency...
# 17   More than 20% of groups had expected frequency...
# 18   More than 20% of groups had expected frequency...
# 19   More than 20% of groups had expected frequency...
# 20   More than 20% of groups had expected frequency...
# 21   More than 20% of groups had expected frequency...
# 22   More than 20% of groups had expected frequency...
# 23   More than 20% of groups had expected frequency...
# 24   More than 20% of groups had expected frequency...
# 25                                            0.774902
# 26                                            0.387623
# 27                                            0.727568
# 28                                            0.224305
# 29                                            0.714722
# ..                                                 ...
# 98                                            0.577619
# 99   More than 20% of groups had expected frequency...
# 100                                           0.964865
# 101                                           0.822782
# 102                                           0.789889
# 103                                           0.822782
# 104                                           0.730337
# 105                                            0.30241
# 106                                           0.789889
# 107  More than 20% of groups had expected frequency...
# 108  More than 20% of groups had expected frequency...
# 109  More than 20% of groups had expected frequency...
# 110  More than 20% of groups had expected frequency...
# 111  More than 20% of groups had expected frequency...
# 112  More than 20% of groups had expected frequency...
# 113  More than 20% of groups had expected frequency...
# 114  More than 20% of groups had expected frequency...
# 115  More than 20% of groups had expected frequency...
# 116  More than 20% of groups had expected frequency...
# 117  More than 20% of groups had expected frequency...
# 118  More than 20% of groups had expected frequency...
# 119  More than 20% of groups had expected frequency...
# 120  More than 20% of groups had expected frequency...
# 121  More than 20% of groups had expected frequency...
# 122                                           0.711576
# 123  More than 20% of groups had expected frequency...
# 124                                           0.545395
# 125  More than 20% of groups had expected frequency...
# 126  More than 20% of groups had expected frequency...
# 127  More than 20% of groups had expected frequency...
#
# [8394 rows x 4 columns]

# %% [markdown]
# ## Multiple testing correction

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = statsmodels.stats.multitest.multipletests(
    pvals=all_results["pval"], 
    alpha=0.05, 
    method="fdr_bh"
)

all_results = all_results.assign(adj_p=pvals_corrected)

# %%
all_results[all_results["adj_p"] <= 0.05]

# %%
all_results

# %%
alt.Chart(all_results).mark_bar().encode(
    x=alt.X(
        "adj_p",
        bin=alt.Bin(step=0.05)
    ),
    y=alt.Y(
        "count()"
    )
)
