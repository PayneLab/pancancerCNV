# %% [markdown]
# # Assign overlap p values to individual proteins and perform multiple testing correction

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest

# %%
CHROMOSOME = "8"
ARM = "p"
TRANS_OR_CIS = "cis"

# %%
overlaps = pd.read_csv(f"pancancer_summary_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t")
pvals = pd.read_csv(f"overlap_pvals_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t")

# %% [markdown]
# ## Merge in the _p_ values for each protein
#
# We will exclude proteins that were only different in one cancer type (no overlap).

# %%
overlaps = overlaps[overlaps["num_cancers"] > 1].\
merge(
    right=pvals,
    left_on="num_cancers",
    right_on="overlap_size",
    how="inner"
)

# %% [markdown]
# ## Apply multiple testing correction

# %%
reject, adj_pvals, alpha_sidak, alpha_bonf = statsmodels.stats.multitest.multipletests(
    pvals=overlaps["pvals"], 
    alpha=0.05, 
    method="fdr_bh"
)

overlaps = overlaps.assign(
    adj_p=adj_pvals
)

# %%
overlaps
# Out:
#      protein                             cancers  mean_simp_change  \
# 0     AGPAT5  brca_colon_hnscc_lscc_luad_ovarian                -1
# 1   ATP6V1B2  brca_colon_hnscc_lscc_luad_ovarian                -1
# 2      CHMP7  brca_colon_hnscc_lscc_luad_ovarian                -1
# 3       ERI1  brca_colon_hnscc_lscc_luad_ovarian                -1
# 4     PPP2CB  brca_colon_hnscc_lscc_luad_ovarian                -1
# 5    PPP2R2A  brca_colon_hnscc_lscc_luad_ovarian                -1
# 6      SARAF  brca_colon_hnscc_lscc_luad_ovarian                -1
# 7     VPS37A  brca_colon_hnscc_lscc_luad_ovarian                -1
# 8       XPO7  brca_colon_hnscc_lscc_luad_ovarian                -1
# 9   FAM160B2          brca_colon_hnscc_lscc_luad                -1
# 10      NAT1          brca_colon_hnscc_lscc_luad                -1
# 11    SH2D4A          brca_colon_hnscc_lscc_luad                -1
# 12     PINX1       brca_colon_hnscc_lscc_ovarian                -1
# 13    KIF13B       brca_colon_hnscc_luad_ovarian                -1
# 14      MSRA       brca_colon_hnscc_luad_ovarian                -1
# 15     FDFT1        brca_colon_lscc_luad_ovarian                -1
# 16    R3HCC1        brca_colon_lscc_luad_ovarian                -1
# 17  SLC39A14        brca_colon_lscc_luad_ovarian                -1
# 18     DOCK5               brca_colon_hnscc_luad                -1
# 19     CNOT7                brca_hnscc_lscc_luad                -1
# 20    ERICH1                brca_hnscc_lscc_luad                -1
# 21     MTMR9             brca_hnscc_luad_ovarian                -1
# 22    GTF2E2              brca_lscc_luad_ovarian                -1
# 23       GSR             colon_lscc_luad_ovarian                -1
# 24  ARHGEF10                     brca_hnscc_luad                -1
# 25     NEIL2                     brca_hnscc_luad                -1
# 26     KCTD9                      brca_lscc_luad                -1
# 27    NUDT18                      brca_lscc_luad                -1
# 28       PBK                      brca_lscc_luad                -1
# 29      PSD3                   brca_lscc_ovarian                -1
# 30      CTSB                  colon_luad_ovarian                -1
# 31    PPP3CC                     hnscc_lscc_luad                -1
# 32     ASAH1                          brca_colon                -1
# 33     CDCA2                           brca_lscc                -1
# 34      TNKS                           brca_lscc                -1
# 35    HMBOX1                           brca_luad                -1
# 36     MTMR7                           brca_luad                -1
# 37     DCTN6                          colon_luad                -1
# 38      TDRP                          hnscc_lscc                -1
# 39   KBTBD11                          hnscc_luad                -1
#
#     num_cancers  overlap_size     pvals     adj_p
# 0             6             6  0.006474  0.028773
# 1             6             6  0.006474  0.028773
# 2             6             6  0.006474  0.028773
# 3             6             6  0.006474  0.028773
# 4             6             6  0.006474  0.028773
# 5             6             6  0.006474  0.028773
# 6             6             6  0.006474  0.028773
# 7             6             6  0.006474  0.028773
# 8             6             6  0.006474  0.028773
# 9             5             5  0.055178  0.122617
# 10            5             5  0.055178  0.122617
# 11            5             5  0.055178  0.122617
# 12            5             5  0.055178  0.122617
# 13            5             5  0.055178  0.122617
# 14            5             5  0.055178  0.122617
# 15            5             5  0.055178  0.122617
# 16            5             5  0.055178  0.122617
# 17            5             5  0.055178  0.122617
# 18            4             4  0.216008  0.360013
# 19            4             4  0.216008  0.360013
# 20            4             4  0.216008  0.360013
# 21            4             4  0.216008  0.360013
# 22            4             4  0.216008  0.360013
# 23            4             4  0.216008  0.360013
# 24            3             3  0.495878  0.619847
# 25            3             3  0.495878  0.619847
# 26            3             3  0.495878  0.619847
# 27            3             3  0.495878  0.619847
# 28            3             3  0.495878  0.619847
# 29            3             3  0.495878  0.619847
# 30            3             3  0.495878  0.619847
# 31            3             3  0.495878  0.619847
# 32            2             2  0.771186  0.771186
# 33            2             2  0.771186  0.771186
# 34            2             2  0.771186  0.771186
# 35            2             2  0.771186  0.771186
# 36            2             2  0.771186  0.771186
# 37            2             2  0.771186  0.771186
# 38            2             2  0.771186  0.771186
# 39            2             2  0.771186  0.771186

# %%
overlaps.to_csv(f"sig_diff_overlaps_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t", index=False)
