# %% [markdown]
# # Check for confounding variables
#
# This notebook uses chi-squared tests to look for clinical variables that are associated with having a chromosome event or not.

# %% [markdown]
# - Get clinical tables
# - Get event tables
# - Binarize clinical columns as needed
# - For each binary column in the clinical table, make a contingency table of that column and the event table
# - Run chi squared test and save results

# %%
import pandas as pd
import numpy as np
import os
import cptac
import cptac.utils as ut
import altair as alt
import scipy.stats
import statsmodels.stats.multitest

# %%
pd.options.display.max_columns = None
pd.options.display.max_colwidth = None

# %%
dss = {
    "brca": cptac.Brca,
#     "ccrcc": cptac.Ccrcc,
    "colon": cptac.Colon,
#     "endometrial": cptac.Endometrial,
#     "gbm": cptac.Gbm,
    "hnscc": cptac.Hnscc,
    "lscc": cptac.Lscc,
    "luad": cptac.Luad,
    "ovarian": cptac.Ovarian
}

# %%
def load_tables(cancer_type):
    
    # Load the dataset
    ds = dss[cancer_type]()
    
    # Get the clinical table
    clin = ds.get_clinical()
    
    # Get the event table
    event = pd.\
    read_csv(f"{cancer_type}_has_event.tsv", sep="\t", index_col=0).\
    rename(columns={"gain_event": "8q_gain", "loss_event": "8p_loss"})
    
    joined = clin.join(event, how="inner")
    
    return joined

# %%
def test_cnv_association(cancer_type, df, test_cols, cnv_col):
    
    pvals = []

    for col in test_cols:
        
        # Create contingency table
        contingency_table = pd.crosstab(df[cnv_col], df[col])
        
        # Run test
        chi2, p, dof, exp_freq = scipy.stats.chi2_contingency(contingency_table)
        
        # Check assumptions: No group has expected value < 1, and no more than
        # 20% of groups have expected frequency < 5.
        exp_freq = pd.DataFrame(exp_freq)
        
        if (exp_freq < 1).any().any():
            pvals.append("Not all expected frequencies were > 1.")
        elif (exp_freq < 5).sum().sum() > 0.2 * exp_freq.shape[0] * exp_freq.shape[1]:
            pvals.append("More than 20% of groups had expected frequency < 5.")
        else:
            pvals.append(p)
        
    pvals = pd.DataFrame({
        "cancer_type": cancer_type,
        "cnv_event": cnv_col,
        "variable": test_cols,
        "pval": pvals
    })
    
    return pvals

# %%
all_results = pd.DataFrame()

# %% [markdown]
# ## BRCA

# %%
brca = load_tables("brca")

# %% [markdown]
# ### Simplify the age column
# For the age column, we will create groups of 15 years, and combine all > 75 years.

# %%
brca = brca.assign(Age=brca["Age.in.Month"] // 12)
brca = brca.assign(Age_group=(brca["Age"] // 15) * 15)
brca = brca.assign(Age_group=brca["Age_group"].where(cond=(brca["Age_group"] < 75) | (pd.isnull(brca["Age"])), other=75))

# %%
brca["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 30.0    12
# 45.0    36
# 60.0    38
# 75.0    19
# NaN     17
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Simplify the stage column
#
# We will also simplify the "Stage" column.

# %%
brca["Stage"].value_counts(dropna=False).sort_index()
# Out:
# Stage IA       4
# Stage IIA     50
# Stage IIB     20
# Stage III      4
# Stage IIIA    22
# Stage IIIB     3
# Stage IIIC     4
# NaN           15
# Name: Stage, dtype: int64

# %% [markdown]
# Because there are only 4 Stage I samples, we will group them with Stage II.

# %%
def simplify_stage_brca(row):
    if pd.isna(row):
        return row
    elif row.startswith("Stage III"):
        return "III"
    elif row.startswith("Stage II"):
        return "I or II"
    elif row.startswith("Stage I"):
        return "I or II"
    else:
        return row
    
brca = brca.assign(Stage=brca["Stage"].apply(simplify_stage_brca))

# %%
brca["Stage"].value_counts(dropna=False).sort_index()
# Out:
# I or II    74
# III        33
# NaN        15
# Name: Stage, dtype: int64

# %% [markdown]
# ### Race column
#
# There aren't enough people in the hispanic.or.latino group to satisfy the requirements of the chi-squared test, so we have to drop the category.

# %%
brca["Race"].value_counts(dropna=False)
# Out:
# white                        78
# asian                        19
# black.or.african.american    14
# NaN                           7
# hispanic.or.latino            4
# Name: Race, dtype: int64

# %%
brca["Race"] = brca["Race"].replace(
    to_replace="hispanic.or.latino",
    value=np.nan
)

# %%
brca["Race"].value_counts(dropna=False)
# Out:
# white                        78
# asian                        19
# black.or.african.american    14
# NaN                          11
# Name: Race, dtype: int64

# %% [markdown]
# ### Run chi-squared tests
# Now we will run chi-squared tests to look for association between each variable and CNV events.

# %%
brca_cols = [
    "Age_group",
    "Race",
    "Stage",
    "PAM50",
    "NMF.v2.1",
]
# Don't use gender because all female

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="brca",
    df=brca,
    test_cols=brca_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="brca",
    df=brca,
    test_cols=brca_cols,
    cnv_col="8q_gain"
))

# %% [markdown]
# ## Colon

# %%
colon = load_tables("colon")

# %% [markdown]
# ### Simplify the Age column

# %%
colon = colon.assign(Age_years=colon["Age"] // 12)
colon = colon.assign(Age_group=(colon["Age_years"] // 15) * 15)

# %%
colon["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 30.0     4
# 45.0    31
# 60.0    48
# 75.0    19
# 90.0     1
# NaN      2
# Name: Age_group, dtype: int64

# %%
colon = colon.assign(
    Age_group=colon["Age_group"].where(cond=(colon["Age_group"] < 75) | (pd.isnull(colon["Age"])), other=75)
)
colon = colon.assign(
    Age_group=colon["Age_group"].where(cond=(colon["Age_group"] > 45) | (pd.isnull(colon["Age"])), other=30)
)

# %%
colon["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 30.0    35
# 60.0    48
# 75.0    20
# NaN      2
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Simplify the Stage column

# %%
colon["Stage"].value_counts(dropna=False).sort_index()
# Out:
# Stage I      12
# Stage II     42
# Stage III    44
# Stage IV      7
# Name: Stage, dtype: int64

# %%
colon = colon.assign(Stage=colon["Stage"].where(colon["Stage"] != "Stage IV", "Stage III or IV"))
colon = colon.assign(
    Stage=colon["Stage"].where(colon["Stage"] != "Stage III", "Stage III or IV")
)

# %%
colon["Stage"].value_counts(dropna=False).sort_index()
# Out:
# Stage I            12
# Stage II           42
# Stage III or IV    51
# Name: Stage, dtype: int64

# %% [markdown]
# ### Run chi-squared tests

# %%
colon_cols = [
    "Age_group",
    "Gender",
    "Stage",
    "Mucinous"
]

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="colon",
    df=colon,
    test_cols=colon_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="colon",
    df=colon,
    test_cols=colon_cols,
    cnv_col="8q_gain"
))

# %% [markdown]
# ## HNSCC

# %%
hnscc = load_tables("hnscc")

# %% [markdown]
# ### Group ages

# %%
hnscc = hnscc.assign(Age_group=(hnscc["age"] // 10) * 10)

# %%
hnscc["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 20.0     1
# 40.0     5
# 50.0    37
# 60.0    48
# 70.0    14
# 80.0     3
# NaN      1
# Name: Age_group, dtype: int64

# %%
hnscc = hnscc.assign(
    Age_group=hnscc["Age_group"].where(cond=(hnscc["Age_group"] < 70) | (pd.isnull(hnscc["age"])), other=70)
)
hnscc = hnscc.assign(
    Age_group=hnscc["Age_group"].where(cond=(hnscc["Age_group"] > 50) | (pd.isnull(hnscc["age"])), other=50)
)

# %%
hnscc["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 50.0    43
# 60.0    48
# 70.0    17
# NaN      1
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Simplify alcohol consumption column
#
# We are going to combine the past drinker group with the current but less group.
#
# Also replace the history not available group with NaN.

# %%
hnscc["alcohol_consum"].value_counts(dropna=False)
# Out:
# Alcohol consumption equal to or less than 2 drinks per day for men and 1 drink or less per day for women    44
# Alcohol consumption history not available                                                                   23
# Lifelong non-drinker                                                                                        21
# Alcohol consumption more than 2 drinks per day for men and more than 1 drink per day for women              11
# NaN                                                                                                          7
# Consumed alcohol in the past, but currently a non-drinker                                                    3
# Name: alcohol_consum, dtype: int64

# %%
hnscc["alcohol_consum"] = hnscc["alcohol_consum"].replace(
    to_replace="Consumed alcohol in the past, but currently a non-drinker",
    value="Alcohol consumption equal to or less than 2 drinks per day for men and 1 drink or less per day for women"
).replace(
    to_replace="Alcohol consumption history not available",
    value=np.nan
)

# %%
hnscc["alcohol_consum"].value_counts(dropna=False)
# Out:
# Alcohol consumption equal to or less than 2 drinks per day for men and 1 drink or less per day for women    47
# NaN                                                                                                         30
# Lifelong non-drinker                                                                                        21
# Alcohol consumption more than 2 drinks per day for men and more than 1 drink per day for women              11
# Name: alcohol_consum, dtype: int64

# %% [markdown]
# ### Simplify smoking history column
#
# Combine all the "current reformed" groups and set the "history not available" group to NaN.

# %%
hnscc["smoking_history"].value_counts(dropna=False)
# Out:
# Current smoker: Includes daily and non-daily smokers                38
# Smoking history not available                                       21
# Lifelong non-smoker: Less than 100 cigarettes smoked in lifetime    21
# Current reformed smoker within past 15 years                        14
# Current reformed smoker, more than 15 years                         10
# Current reformed smoker, years unknown                               4
# NaN                                                                  1
# Name: smoking_history, dtype: int64

# %%
hnscc["smoking_history"] = hnscc["smoking_history"].replace(
    to_replace="Smoking history not available",
    value=np.nan
).replace(
    to_replace=[
        "Current reformed smoker, years unknown", 
        "Current reformed smoker within past 15 years",
        "Current reformed smoker, more than 15 years"
    ],
    value="Current reformed smoker"
)

# %%
hnscc["smoking_history"].value_counts(dropna=False)
# Out:
# Current smoker: Includes daily and non-daily smokers                38
# Current reformed smoker                                             28
# NaN                                                                 22
# Lifelong non-smoker: Less than 100 cigarettes smoked in lifetime    21
# Name: smoking_history, dtype: int64

# %% [markdown]
# ### Simplify tumor site column
#
# Combine the two pharynx categories, and put lip with Oral cavity.

# %%
hnscc["tumor_site_curated"].value_counts(dropna=False)
# Out:
# Oral cavity    49
# Larynx         47
# Oropharynx      6
# Lip             4
# Hypopharynx     2
# NaN             1
# Name: tumor_site_curated, dtype: int64

# %%
hnscc["tumor_site_curated"] = hnscc["tumor_site_curated"].replace(
    to_replace=["Oropharynx", "Hypopharynx"],
    value="Pharynx"
).replace(
    to_replace="Lip",
    value="Oral cavity"
)

# %%
hnscc["tumor_site_curated"].value_counts(dropna=False)
# Out:
# Oral cavity    53
# Larynx         47
# Pharynx         8
# NaN             1
# Name: tumor_site_curated, dtype: int64

# %% [markdown]
# ### Simplify stage column
#
# Combine stage I and stage II groups

# %%
hnscc["patho_staging_curated"].value_counts(dropna=False)
# Out:
# Stage IV     45
# Stage III    32
# Stage II     24
# Stage I       7
# NaN           1
# Name: patho_staging_curated, dtype: int64

# %%
hnscc["patho_staging_curated"] = hnscc["patho_staging_curated"].replace(
    to_replace=["Stage I", "Stage II"],
    value="Stage I/II"
)

# %%
hnscc["patho_staging_curated"].value_counts(dropna=False)
# Out:
# Stage IV      45
# Stage III     32
# Stage I/II    31
# NaN            1
# Name: patho_staging_curated, dtype: int64

# %% [markdown]
# ### Run chi-squared tests

# %%
hnscc_cols = [
    "Age_group",
    "alcohol_consum",
#     "gender", # There are only 14 women and 94 men. Chi square assumption not met: More than 20% of groups had expected frequency < 5.
    "histologic_grade",
#     "histologic_type", # 97 out of 104 are all "Squamous cell carcinoma, conventional"
    "patho_staging_curated",
    "smoking_history",
    "tumor_site_curated"
]

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="hnscc",
    df=hnscc,
    test_cols=hnscc_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="hnscc",
    df=hnscc,
    test_cols=hnscc_cols,
    cnv_col="8q_gain"
))

# %% [markdown]
# ## LSCC

# %%
lscc = load_tables("lscc")
# Out:
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 4)

# %%
lscc["Age"] = lscc["Age"].astype(int)

# %% [markdown]
# ### Group ages

# %%
lscc = lscc.assign(Age_group=(lscc["Age"] // 10) * 10)

# %%
lscc["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 40     5
# 50    18
# 60    46
# 70    37
# 80     2
# Name: Age_group, dtype: int64

# %%
lscc = lscc.assign(
    Age_group=lscc["Age_group"].where(cond=(lscc["Age_group"] < 70) | (pd.isnull(lscc["Age"])), other=70)
)
lscc = lscc.assign(
    Age_group=lscc["Age_group"].where(cond=(lscc["Age_group"] > 50) | (pd.isnull(lscc["Age"])), other=50)
)

# %%
lscc["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 50    23
# 60    46
# 70    39
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Simplify the Stage column

# %%
lscc["Stage"].value_counts(dropna=False).sort_index()
# Out:
# I        3
# IA      12
# IB      22
# II       2
# IIA     22
# IIB     20
# III      2
# IIIA    17
# IIIB     2
# IV       1
# NaN      5
# Name: Stage, dtype: int64

# %%
def simplify_stage_lscc(row):
    if pd.isna(row):
        return row
    elif row.startswith("IV"):
        return "III or IV"
    elif row.startswith("III"):
        return "III or IV"
    elif row.startswith("II"):
        return "II"
    elif row.startswith("I"):
        return "I"
    else:
        return row
    
lscc = lscc.assign(Stage=lscc["Stage"].apply(simplify_stage_lscc))

# %%
lscc["Stage"].value_counts(dropna=False).sort_index()
# Out:
# I            37
# II           44
# III or IV    22
# NaN           5
# Name: Stage, dtype: int64

# %% [markdown]
# ### Country.of.Origin column
#
# Combine by region--North America, Asian, or Eurasia. We use this column instead of the Ethnicity column because the Ethnicity column only had enough info test two groups--white and Asian.

# %%
lscc["Country.of.Origin"].value_counts(dropna=False).sort_index()
# Out:
# bulgaria    25
# china       17
# other        2
# poland      14
# russia       2
# ukraine     10
# usa         32
# vietnam      6
# Name: Country.of.Origin, dtype: int64

# %%
lscc["Country.of.Origin"] = lscc["Country.of.Origin"].replace(
    to_replace="usa",
    value="North America"
).replace(
    to_replace=["bulgaria", "poland", "russia", "ukraine"],
    value="Eurasia"
).replace(
    to_replace=["china", "vietnam"],
    value="Asia"
).replace(
    to_replace="other",
    value=np.nan
)

# %%
lscc["Country.of.Origin"].value_counts(dropna=False).sort_index()
# Out:
# Asia             23
# Eurasia          51
# North America    32
# NaN               2
# Name: Country.of.Origin, dtype: int64

# %% [markdown]
# ### Pack.Years.Smoked column

# %%
lscc["Pack.Years.Smoked"] = lscc["Pack.Years.Smoked"].astype(float)

lscc = lscc.assign(**{"Pack.Years.Smoked": (lscc["Pack.Years.Smoked"] // 20) * 20})

lscc = lscc.assign(**{
    "Pack.Years.Smoked": lscc["Pack.Years.Smoked"].where(
        cond=(lscc["Pack.Years.Smoked"] < 60) | (pd.isnull(lscc["Pack.Years.Smoked"])), other=60
    )
})
lscc = lscc.assign(**{
    "Pack.Years.Smoked": lscc["Pack.Years.Smoked"].where(
        cond=(lscc["Pack.Years.Smoked"] > 20) | (pd.isnull(lscc["Pack.Years.Smoked"])), other=20
    )
})

# %%
lscc["Pack.Years.Smoked"].value_counts(dropna=False).sort_index()
# Out:
# 20.0    23
# 40.0    20
# 60.0    14
# NaN     51
# Name: Pack.Years.Smoked, dtype: int64

# %% [markdown]
# ### Run chi squared tests

# %%
lscc_cols = [
    "Age_group",
    "Gender",
    "Stage",
    "Country.of.Origin",
    "Pack.Years.Smoked"
]

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="lscc",
    df=lscc,
    test_cols=lscc_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="lscc",
    df=lscc,
    test_cols=lscc_cols,
    cnv_col="8q_gain"
))

# %% [markdown]
# ## LUAD

# %%
luad = load_tables("luad")

# %% [markdown]
# ### Group ages

# %%
luad = luad.assign(Age_group=(luad["Age"] // 10) * 10)

# %%
luad["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 30.0     2
# 40.0    10
# 50.0    32
# 60.0    39
# 70.0    23
# 80.0     3
# Name: Age_group, dtype: int64

# %%
luad = luad.assign(
    Age_group=luad["Age_group"].where(cond=(luad["Age_group"] < 70) | (pd.isnull(luad["Age"])), other=70)
)
luad = luad.assign(
    Age_group=luad["Age_group"].where(cond=(luad["Age_group"] > 40) | (pd.isnull(luad["Age"])), other=40)
)

# %%
luad["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 40.0    12
# 50.0    32
# 60.0    39
# 70.0    26
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Simplify BMI column
#
# Based on the ranges from the CDC: https://www.cdc.gov/obesity/adult/defining.html

# %%
luad = luad.assign(BMI_range=np.nan)
luad["BMI_range"] = np.where(luad["BMI"] < 18.5, "underweight", luad["BMI_range"])
luad["BMI_range"] = np.where((luad["BMI"] < 25) & (luad["BMI"] >= 18.5), "healthyweight", luad["BMI_range"])
luad["BMI_range"] = np.where(luad["BMI"] >= 25, "overweight or obese", luad["BMI_range"])

# %%
luad["BMI_range"].value_counts(dropna=False).sort_index()
# Out:
# healthyweight          52
# overweight or obese    40
# underweight            17
# Name: BMI_range, dtype: int64

# %% [markdown]
# ### Simplify the Stage column
#
# We had to combine the Stage 2 and 3 categories to get high enough counts to meet the assumptions of the chi squared test.

# %%
luad["Stage"].value_counts(dropna=False).sort_index()
# Out:
# 1       1
# 1A     15
# 1B     29
# 2A      8
# 2B      9
# 3       1
# 3A     12
# NaN    34
# Name: Stage, dtype: int64

# %%
def simplify_stage_luad(row):
    if pd.isna(row):
        return row
    elif row.startswith("3"):
        return "2 or 3"
    elif row.startswith("2"):
        return "2 or 3"
    elif row.startswith("1"):
        return "1"
    else:
        return row
    
luad = luad.assign(Stage=luad["Stage"].apply(simplify_stage_luad))

# %%
luad["Stage"].value_counts(dropna=False).sort_index()
# Out:
# 1         45
# 2 or 3    30
# NaN       34
# Name: Stage, dtype: int64

# %% [markdown]
# ### Pack.Years.Smoked column

# %%
luad["Pack.Years.Smoked"] = luad["Pack.Years.Smoked"].astype(float)

luad = luad.assign(**{"Pack.Years.Smoked": (luad["Pack.Years.Smoked"] // 20) * 20})

# %%
luad = luad.assign(**{
    "Pack.Years.Smoked": luad["Pack.Years.Smoked"].where(
        cond=(luad["Pack.Years.Smoked"] < 20) | (pd.isnull(luad["Pack.Years.Smoked"])), other=20
    )
})

# %%
luad["Pack.Years.Smoked"].value_counts(dropna=False).sort_index()
# Out:
# 0.0     23
# 20.0    26
# NaN     60
# Name: Pack.Years.Smoked, dtype: int64

# %% [markdown]
# ### Run chi squared tests

# %%
luad_cols = [
    "Age_group",
    "Gender",
    "BMI_range",
    "Stage",
    "Region.of.Origin",
    "Pack.Years.Smoked"
]

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="luad",
    df=luad,
    test_cols=luad_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="luad",
    df=luad,
    test_cols=luad_cols,
    cnv_col="8q_gain"
))

# %%
test_cnv_association(
    cancer_type="luad",
    df=luad,
    test_cols=luad_cols,
    cnv_col="8q_gain"
)
# Out:
#   cancer_type cnv_event           variable      pval
# 0        luad   8q_gain          Age_group  0.015650
# 1        luad   8q_gain             Gender  0.755291
# 2        luad   8q_gain          BMI_range  0.005345
# 3        luad   8q_gain              Stage  0.865882
# 4        luad   8q_gain   Region.of.Origin  0.001375
# 5        luad   8q_gain  Pack.Years.Smoked  0.817302

# %% [markdown]
# ## Ovarian

# %%
ovarian = load_tables("ovarian")

# %%
ovarian
# Out:
#         Sample_Tumor_Normal  Participant_Procurement_Age Participant_Gender  \
# 01OV002               Tumor                        540.0             Female
# 01OV007               Tumor                        820.0             Female
# 01OV008               Tumor                        665.0             Female
# 01OV010               Tumor                        625.0             Female
# 01OV013               Tumor                        828.0             Female
# 01OV017               Tumor                        672.0             Female
# 01OV018               Tumor                        535.0             Female
# 01OV019               Tumor                        694.0             Female
# 01OV023               Tumor                        707.0             Female
# 01OV026               Tumor                        932.0             Female
# 22OV001                  Not Jewish
# 26OV002                     Unknown
# 26OV008                  Not Jewish
# 26OV009                  Not Jewish
# 26OV010                  Not Jewish
# 26OV011                  Not Jewish
# 26OV013                  Not Jewish
#
#                                  Participant_History_Malignancy  \
# 01OV002                                                      No
# 01OV007                                                      No
# 01OV008                                                      No
# 01OV010                                                      No
# 01OV013                                                      No
# 01OV017                                                      No
# 01OV018                                                      No
# 01OV019                                                      No
# 01OV023                                                      No
# 01OV026                                                      No
# 01OV030                                                      No
# 01OV039                                                      No
# 01OV041                                                      No
# 01OV045                                                      No
# 01OV046                                                      No
# 01OV047                                                      No
# 01OV049                                                      No
# 02OV005                                                      No
# 02OV006                                                      No
# 02OV008                                                      No
# 02OV022                                                      No
# 02OV023                                                      No
# 02OV029                                                      No
# 02OV032                                                      No
# 02OV035                                                      No
# 02OV036                                                      No
# 02OV040                                                      No
# 02OV041                                                      No
# 02OV042                                                      No
# 02OV044                                                      No
# ...                                                         ...
# 15OV001                                                      No
# 17OV001                                                      No
# 17OV002                                                      No
# 17OV010                                                      No
# 17OV011                                                      No
# 17OV013                                                      No
# 17OV014                                                      No
# 17OV015                                                      No
# 17OV017  Yes, History of Other Cancer Greater Than One Year Ago
# 17OV018                                                      No
# 17OV019                                                      No
# 17OV025                                                      No
# 17OV027                                                      No
# 17OV028                                                      No
# 17OV029                                                      No
# 17OV030                                                      No
# 17OV033  Yes, History of Other Cancer Greater Than One Year Ago
# 17OV034                                                      No
# 17OV036  Yes, History of Other Cancer Greater Than One Year Ago
# 17OV039                                                      No
# 17OV040                                                      No
# 18OV001  Yes, History of Other Cancer Greater Than One Year Ago
# 20OV005  Yes, History of Other Cancer Greater Than One Year Ago
# 22OV001                                                      No
# 26OV002                                                      No
# 26OV008                                                      No
# 26OV009                                                      No
# 26OV010                                                      No
# 26OV011                                                      No
# 26OV013                                                      No
#
#         Participant_History_Chemotherapy  \
# 01OV002                               No
# 01OV007                               No
# 01OV008                               No
# 01OV010                               No
# 01OV013                               No
# 01OV017                               No
# 01OV018                               No
# 01OV019                               No
# 01OV023                               No
# 01OV026                               No
# 01OV030                               No
# 01OV039                               No
# 01OV041                               No
# 01OV045                              Yes
# 01OV046                               No
# 01OV047                               No
# 01OV049                               No
# 02OV005                               No
# 02OV006                               No
# 02OV008                               No
# 02OV022                               No
# 02OV023                               No
# 02OV029                               No
# 02OV032                               No
# 02OV035                               No
# 02OV036                               No
# 02OV040                               No
# 02OV041                               No
# 02OV042                               No
# 02OV044                               No
# ...                                  ...
# 15OV001                               No
# 17OV001                               No
# 17OV002                               No
# 17OV010                               No
# 17OV011                               No
# 17OV013                               No
# 17OV014                               No
# 17OV015                               No
# 17OV017                               No
# 17OV018                               No
# 17OV019                               No
# 17OV025                               No
# 17OV027                               No
# 17OV028                               No
# 17OV029                               No
# 17OV030                               No
# 17OV033                               No
# 17OV034                               No
# 17OV036                              Yes
# 17OV039                               No
# 17OV040                               No
# 18OV001                               No
# 20OV005                               No
# 22OV001                               No
# 26OV002                               No
# 26OV008                              Yes
# 26OV009                              Yes
# 26OV010                              Yes
# 26OV011                              Yes
# 26OV013                              Yes
#
#         Participant_History_Neo-adjuvant_Treatment  \
# 01OV002                                         No
# 01OV007                                         No
# 01OV008                                         No
# 01OV010                                         No
# 01OV013                                         No
# 01OV017                                         No
# 01OV018                                         No
# 01OV019                                         No
# 01OV023                                         No
# 01OV026                                         No
# 01OV030                                         No
# 01OV039                                         No
# 01OV041                                         No
# 01OV045                                        Yes
# 01OV046                                         No
# 01OV047                                         No
# 01OV049                                         No
# 02OV005                                         No
# 02OV006                                         No
# 02OV008                                         No
# 02OV022                                         No
# 02OV023                                         No
# 02OV029                                         No
# 02OV032                                         No
# 02OV035                                         No
# 02OV036                                         No
# 02OV040                                         No
# 02OV041                                         No
# 02OV042                                         No
# 02OV044                                         No
# ...                                            ...
# 15OV001                                         No
# 17OV001                                         No
# 17OV002                                         No
# 17OV010                                         No
# 17OV011                                         No
# 17OV013                                         No
# 17OV014                                         No
# 17OV015                                         No
# 17OV017                                         No
# 17OV018                                         No
# 17OV019                                         No
# 17OV025                                         No
# 17OV027                                         No
# 17OV028                                         No
# 17OV029                                         No
# 17OV030                                         No
# 17OV033                                         No
# 17OV034                                         No
# 17OV036                                         No
# 17OV039                                         No
# 17OV040                                         No
# 18OV001                                         No
# 20OV005                                         No
# 22OV001                                         No
# 26OV002                                         No
# 26OV008                                         No
# 26OV009                                         No
# 26OV010                                         No
# 26OV011                                         No
# 26OV013                                         No
#
#         Participant_History_Radiation_Therapy  \
# 01OV002                                    No
# 01OV007                                    No
# 01OV008                                    No
# 01OV010                                    No
# 01OV013                                    No
# 01OV017                                    No
# 01OV018                                    No
# 01OV019                                    No
# 01OV023                                    No
# 01OV026                                    No
# 01OV030                                    No
# 01OV039                                    No
# 01OV041                                    No
# 01OV045                                   Yes
# 01OV046                                    No
# 01OV047                                    No
# 01OV049                                    No
# 02OV005                                    No
# 02OV006                                    No
# 02OV008                                    No
# 02OV022                                    No
# 02OV023                                    No
# 02OV029                                    No
# 02OV032                                    No
# 02OV035                                    No
# 02OV036                                    No
# 02OV040                                    No
# 02OV041                                    No
# 02OV042                                    No
# 02OV044                                    No
# ...                                       ...
# 15OV001                                    No
# 17OV001                                    No
# 17OV002                                    No
# 17OV010                                    No
# 17OV011                                    No
# 17OV013                                    No
# 17OV014                                    No
# 17OV015                                    No
# 17OV017                                    No
# 17OV018                                    No
# 17OV019                                    No
# 17OV025                                    No
# 17OV027                                    No
# 17OV028                                    No
# 17OV029                                    No
# 17OV030                                    No
# 17OV033                                    No
# 17OV034                                    No
# 17OV036                                    No
# 17OV039                                    No
# 17OV040                                    No
# 18OV001                                    No
# 20OV005                                    No
# 22OV001                                    No
# 26OV002                                    No
# 26OV008                                    No
# 26OV009                                    No
# 26OV010                                    No
# 26OV011                                    No
# 26OV013                                    No
#
#         Participant_History_Hormonal_Therapy  Aliquots_Plasma  \
# 01OV002                                   No              2.0
# 01OV007                                   No              2.0
# 01OV008                                   No              2.0
# 01OV010                                   No              2.0
# 01OV013                                   No              2.0
# 01OV017                                   No              2.0
# 01OV018                                   No              2.0
# 01OV019                                   No              3.0
# 01OV023                                   No              2.0
# 01OV026                                   No              2.0
# 01OV030                                   No              2.0
# 01OV039                                   No              2.0
# 01OV041                                   No              2.0
# 01OV045                                  Yes              2.0
# 01OV046                                   No              2.0
# 01OV047                                   No              2.0
# 01OV049                                   No              2.0
# 02OV005                                   No              2.0
# 02OV006                                   No              2.0
# 02OV008                                   No              2.0
# 02OV022                                   No              2.0
# 02OV023                                   No              2.0
# 02OV029                                   No              2.0
# 02OV032                                   No              2.0
# 02OV035                                   No              2.0
# 02OV036                                   No              2.0
# 02OV040                                   No              2.0
# 02OV041                                   No              2.0
# 02OV042                                   No              2.0
# 02OV044                                   No              2.0
# ...                                      ...              ...
# 15OV001                                   No              3.0
# 17OV001                                   No              2.0
# 17OV002                                   No              2.0
# 17OV010                                   No              2.0
# 17OV011                                   No              2.0
# 17OV013                                   No              2.0
# 17OV014                                   No              2.0
# 17OV015                                   No              2.0
# 17OV017                                   No              2.0
# 17OV018                                   No              2.0
# 17OV019                                   No              2.0
# 17OV025                                   No              2.0
# 17OV027                                   No              2.0
# 17OV028                                   No              2.0
# 17OV029                                   No              2.0
# 17OV030                                   No              2.0
# 17OV033                                   No              2.0
# 17OV034                                   No              2.0
# 17OV036                                   No              2.0
# 17OV039                                   No              2.0
# 17OV040                                   No              2.0
# 18OV001                                   No              2.0
# 20OV005                                   No              2.0
# 22OV001                                   No              2.0
# 26OV002                                   No              2.0
# 26OV008                                   No              2.0
# 26OV009                                   No              2.0
# 26OV010                                   No              4.0
# 26OV011                                   No              3.0
# 26OV013                                   No              3.0
#
#         Blood_Collection_Time              Blood_Collection_Method  \
# 01OV002                  1240  Venipuncture (Vacutainer Apparatus)
# 01OV007                  1330               Venipuncture (Syringe)
# 01OV008                   630               Venipuncture (Syringe)
# 01OV010                  1430               Venipuncture (Syringe)
# 01OV013                  1230               Venipuncture (Syringe)
# 01OV017                   630               Venipuncture (Syringe)
# 01OV018                  1200               Venipuncture (Syringe)
# 01OV019                  1000               Venipuncture (Syringe)
# 01OV023                  1100               Venipuncture (Syringe)
# 01OV026                   930               Venipuncture (Syringe)
# 01OV030                   830               Venipuncture (Syringe)
# 01OV039                   700  Venipuncture (Vacutainer Apparatus)
# 01OV041                  1300  Venipuncture (Vacutainer Apparatus)
# 01OV045                  1300  Venipuncture (Vacutainer Apparatus)
# 01OV046                   630               Venipuncture (Syringe)
# 01OV047                   800  Venipuncture (Vacutainer Apparatus)
# 01OV049                  1200  Venipuncture (Vacutainer Apparatus)
# 02OV005                   950  Venipuncture (Vacutainer Apparatus)
# 02OV006                   930  Venipuncture (Vacutainer Apparatus)
# 02OV008                   945  Venipuncture (Vacutainer Apparatus)
# 02OV022                   913  Venipuncture (Vacutainer Apparatus)
# 02OV023                   930  Venipuncture (Vacutainer Apparatus)
# 02OV029                  1513  Venipuncture (Vacutainer Apparatus)
# 02OV032                  1219               Venipuncture (Syringe)
# 02OV035                   659  Venipuncture (Vacutainer Apparatus)
# 02OV036                   759  Venipuncture (Vacutainer Apparatus)
# 02OV040                   709               Venipuncture (Syringe)
# 01OV010                   2127.0                           7.0
# 01OV013                   1635.0                           5.0
# 01OV017                    830.0                           5.0
# 01OV018                   1354.0                           5.0
# 01OV019                   1232.0                           4.0
# 01OV023                   1313.0                           4.0
# 01OV026                   1358.0                           3.0
# 01OV030                   1023.0                           4.0
# 01OV039                    837.0                           3.0
# 01OV041                   1510.0                           7.0
# 01OV045                   1439.0                          10.0
# 01OV046                    848.0                           7.0
# 01OV047                   1055.0                           7.0
# 01OV049                   1407.0                           7.0
# 02OV005                   1208.0                           5.0
# 02OV006                   1104.0                           4.0
# 02OV008                   1201.0                           3.0
# 02OV022                   1040.0                           4.0
# 02OV023                   1136.0                           4.0
# 02OV029                   1642.0                           6.0
# 02OV032                   1342.0                           7.0
# 02OV035                    936.0                           6.0
# 02OV036                    927.0                           7.0
# 02OV040                    957.0                           7.0
# ...
# 18OV001                       NaN                     NaN
# 20OV005                       NaN                     NaN
# 22OV001                       NaN                     NaN
# 26OV002                       NaN                     NaN
# 26OV008                       NaN                     NaN
# 26OV009                       NaN                     NaN
# 26OV010                       NaN                     NaN
# 26OV011                       NaN                     NaN
# 26OV013                       NaN                     NaN
#
#          Days_Between_Collection_And_New_Tumor_Event_Surgery  \
# 01OV002                                                  NaN
# 01OV007                                                  NaN
# 01OV008                                                  NaN
# 01OV010                                                  NaN
# 01OV013                                                  NaN
# 01OV017                                                  NaN
# 01OV018                                                  NaN
# 01OV019                                                  NaN
# 01OV023                                                  NaN
# 01OV026                                                  NaN
# 01OV030                                                  NaN
# 01OV039                                                  NaN
# 01OV041                                                  NaN
# 01OV045                                                  NaN
# 01OV046                                                  NaN
# 01OV047                                                  NaN
# 01OV049                                                  NaN
# 02OV005                                                  NaN
# 02OV006                                                  NaN
# 02OV008                                                  NaN
# 02OV022                                                  NaN
# 02OV023                                                  NaN
# 02OV029                                                  NaN
# 02OV032                                                  NaN
# 02OV035                                                  NaN
# 02OV036                                                  NaN
# 02OV040                                                  NaN
# 02OV041                                                  NaN
# 02OV042                                                  NaN
# 02OV044                                                  NaN
# ...                                                      ...
# 15OV001                                                  NaN
# 17OV001                                                  NaN
# 17OV002                                                  NaN
# 17OV010                                                  NaN
# 17OV011                                                  NaN
# 17OV013                                                  NaN
# 17OV014                                                  NaN
# 17OV015                                                  NaN
# 17OV017                                                  NaN
# 17OV018                                                  NaN
# 17OV019                                                  NaN
# 17OV025                                                  NaN
# 17OV027                                                  NaN
# 17OV028                                                  NaN
# 17OV029                                                  NaN
# 17OV030                                                  NaN
# 17OV033                                                  NaN
# 17OV034                                                  NaN
# 17OV036                                                  NaN
# 17OV039                                                  NaN
# 17OV040                                                  NaN
# 18OV001                                                  NaN
# 20OV005                                                  NaN
# 22OV001                                                  NaN
# 26OV002                                                  NaN
# 26OV008                                                  NaN
# 26OV009                                                  NaN
# 26OV010                                                  NaN
# 26OV011                                                  NaN
# 26OV013                                                  NaN
#
#         New_Tumor_Event_Chemotherapy New_Tumor_Event_Immunotherapy  \
# 01OV002                          NaN                           NaN
# 01OV007                          NaN                           NaN
# 01OV008                          NaN                           NaN
# 01OV010                          NaN                           NaN
# 01OV013                          NaN                           NaN
# 01OV017                          NaN                           NaN
# 01OV018                          Yes                            No
# 01OV019                          NaN                           NaN
# 01OV023                          NaN                           NaN
# 01OV026                          NaN                           NaN
# 01OV030                          NaN                           NaN
# 01OV039                          NaN                           NaN
# 01OV041                          NaN                           NaN
# 01OV045                          NaN                           NaN
# 01OV046                          NaN                           NaN
# 01OV047                          NaN                           NaN
# 01OV049                          NaN                           NaN
# 02OV005                          NaN                           NaN
# 02OV006                          NaN                           NaN
# 02OV008                          NaN                           NaN
# 02OV022                          NaN                           NaN
# 02OV023                          NaN                           NaN
# 02OV029                          NaN                           NaN
# 02OV032                          NaN                           NaN
# 02OV035                          NaN                           NaN
# 02OV036                          NaN                           NaN
# 02OV040                          Yes                            No
# 02OV041                          NaN                           NaN
# 02OV042                          NaN                           NaN
# 02OV044                          NaN                           NaN
# ...                              ...                           ...
# 15OV001                          NaN                           NaN
# 17OV001                          NaN                           NaN
# 17OV002                          NaN                           NaN
# 17OV010                          NaN                           NaN
# 17OV011                          NaN                           NaN
# 17OV013                          NaN                           NaN
# 17OV014                          NaN                           NaN
# 17OV015                          NaN                           NaN
# 17OV017                          NaN                           NaN
# 17OV018                          NaN                           NaN
# 17OV019                          NaN                           NaN
# 17OV025                          NaN                           NaN
# 17OV027                          NaN                           NaN
# 17OV028                          NaN                           NaN
# 17OV029                          Yes                            No
# 17OV030                          NaN                           NaN
# 17OV033                          NaN                           NaN
# 17OV034                          NaN                           NaN
# 17OV036                          NaN                           NaN
# 17OV039                          NaN                           NaN
# 17OV040                          NaN                           NaN
# 18OV001                          NaN                           NaN
# 20OV005                          NaN                           NaN
# 22OV001                          NaN                           NaN
# 26OV002                          NaN                           NaN
# 26OV008                          NaN                           NaN
# 26OV009                          NaN                           NaN
# 26OV010                          NaN                           NaN
# 26OV011                          NaN                           NaN
# 26OV013                          NaN                           NaN
#
#         New_Tumor_Event_Hormone_Therapy  \
# 01OV002                             NaN
# 01OV007                             NaN
# 01OV008                             NaN
# 01OV010                             NaN
# 01OV013                             NaN
# 01OV017                             NaN
# 01OV018                              No
# 01OV019                             NaN
# 01OV023                             NaN
# 01OV026                             NaN
# 01OV030                             NaN
# 01OV039                             NaN
# 01OV041                             NaN
# 01OV045                             NaN
# 01OV046                             NaN
# 01OV047                             NaN
# 01OV049                             NaN
# 02OV005                             NaN
# 02OV006                             NaN
# 02OV008                             NaN
# 02OV022                             NaN
# 02OV023                             NaN
# 02OV029                             NaN
# 02OV032                             NaN
# 02OV035                             NaN
# 02OV036                             NaN
# 02OV040                              No
# 02OV041                             NaN
# 02OV042                             NaN
# 02OV044                             NaN
# ...                                 ...
# 15OV001                             NaN
# 17OV001                             NaN
# 17OV002                             NaN
# 17OV010                             NaN
# 17OV011                             NaN
# 17OV013                             NaN
# 17OV014                             NaN
# 17OV015                             NaN
# 17OV017                             NaN
# 17OV018                             NaN
# 17OV019                             NaN
# 17OV025                             NaN
# 17OV027                             NaN
# 17OV028                             NaN
# 17OV029                              No
# 17OV030                             NaN
# 17OV033                             NaN
# 17OV034                             NaN
# 17OV036                             NaN
# 17OV039                             NaN
# 17OV040                             NaN
# 18OV001                             NaN
# 20OV005                             NaN
# 22OV001                             NaN
# 26OV002                             NaN
# 26OV008                             NaN
# 26OV009                             NaN
# 26OV010                             NaN
# 26OV011                             NaN
# 26OV013                             NaN
#
#         New_Tumor_Event_Targeted_Molecular_Therapy  8q_gain  8p_loss
# 01OV002                                        NaN     True    False
# 01OV007                                        NaN    False     True
# 01OV008                                        NaN    False    False
# 01OV010                                        NaN     True    False
# 01OV013                                        NaN    False     True
# 01OV017                                        NaN    False     True
# 01OV018                                         No    False     True
# 01OV019                                        NaN    False    False
# 01OV023                                        NaN     True    False
# 01OV026                                        NaN     True    False
# 01OV030                                        NaN     True    False
# 01OV039                                        NaN    False     True
# 01OV041                                        NaN     True     True
# 01OV045                                        NaN    False    False
# 01OV046                                        NaN     True     True
# 01OV047                                        NaN     True    False
# 01OV049                                        NaN     True     True
# 02OV005                                        NaN     True     True
# 02OV006                                        NaN     True     True
# 02OV008                                        NaN     True    False
# 02OV022                                        NaN    False    False
# 02OV023                                        NaN    False     True
# 02OV029                                        NaN    False     True
# 02OV032                                        NaN    False     True
# 02OV035                                        NaN     True     True
# 02OV036                                        NaN    False     True
# 02OV040                                         No    False     True
# 02OV041                                        NaN    False    False
# 02OV042                                        NaN    False     True
# 02OV044                                        NaN     True     True
# ...                                            ...      ...      ...
# 15OV001                                        NaN    False    False
# 17OV001                                        NaN    False     True
# 17OV002                                        NaN    False    False
# 17OV010                                        NaN    False    False
# 17OV011                                        NaN    False     True
# 17OV013                                        NaN    False    False
# 17OV014                                        NaN    False    False
# 17OV015                                        NaN    False     True
# 17OV017                                        NaN    False     True
# 17OV018                                        NaN    False     True
# 17OV019                                        NaN    False    False
# 17OV025                                        NaN    False     True
# 17OV027                                        NaN    False    False
# 17OV028                                        NaN    False    False
# 17OV029                                         No     True     True
# 17OV030                                        NaN     True     True
# 17OV033                                        NaN     True     True
# 17OV034                                        NaN    False     True
# 17OV036                                        NaN     True    False
# 17OV039                                        NaN    False    False
# 17OV040                                        NaN    False    False
# 18OV001                                        NaN    False    False
# 20OV005                                        NaN     True     True
# 22OV001                                        NaN    False    False
# 26OV002                                        NaN     True    False
# 26OV008                                        NaN    False     True
# 26OV009                                        NaN    False     True
# 26OV010                                        NaN    False    False
# 26OV011                                        NaN    False    False
# 26OV013                                        NaN    False     True
#
# [100 rows x 87 columns]

# %% [markdown]
# ### Group ages

# %%
ovarian = ovarian.assign(Age=ovarian["Participant_Procurement_Age"] // 12)
ovarian = ovarian.assign(Age_group=(ovarian["Age"] // 10) * 10)

# %%
ovarian["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 30.0     3
# 40.0    14
# 50.0    38
# 60.0    29
# 70.0    15
# 80.0     1
# Name: Age_group, dtype: int64

# %%
ovarian = ovarian.assign(
    Age_group=ovarian["Age_group"].where(cond=(ovarian["Age_group"] < 70) | (pd.isnull(ovarian["Age"])), other=70)
)
ovarian = ovarian.assign(
    Age_group=ovarian["Age_group"].where(cond=(ovarian["Age_group"] > 40) | (pd.isnull(ovarian["Age"])), other=40)
)

# %%
ovarian["Age_group"].value_counts(dropna=False).sort_index()
# Out:
# 40.0    17
# 50.0    38
# 60.0    29
# 70.0    16
# Name: Age_group, dtype: int64

# %% [markdown]
# ### Run chi squared tests

# %%
ovarian_cols = [
    "Age_group",
#     "Participant_Race", # Not enough patients in the different categories to pass the assumptions of the test.
#     "Histological_Subtype", # All are "Serous Adenocarcinoma"
#     "Tumor_Stage_Ovary_FIGO", # Not enough of different stages to pass assumptions of test
#     "Tumor_Grade" # Not enough of different grades to pass assumptions of test
]

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="ovarian",
    df=ovarian,
    test_cols=ovarian_cols,
    cnv_col="8p_loss"
))

# %%
all_results = all_results.append(test_cnv_association(
    cancer_type="ovarian",
    df=ovarian,
    test_cols=ovarian_cols,
    cnv_col="8q_gain"
))

# %% [markdown]
# ## Multiple testing correction

# %%
all_results
# Out:
#   cancer_type cnv_event               variable      pval
# 0        brca   8p_loss              Age_group  0.279619
# 1        brca   8p_loss                   Race  0.383808
# 2        brca   8p_loss                  Stage  0.973413
# 3        brca   8p_loss                  PAM50  0.904833
# 4        brca   8p_loss               NMF.v2.1  0.943659
# 0        brca   8q_gain              Age_group  0.353898
# 1        brca   8q_gain                   Race  0.288137
# 2        brca   8q_gain                  Stage  0.606505
# 3        brca   8q_gain                  PAM50  0.000375
# 4        brca   8q_gain               NMF.v2.1  0.000138
# 0       colon   8p_loss              Age_group  0.162933
# 1       colon   8p_loss                 Gender  0.698452
# 2       colon   8p_loss                  Stage  0.177391
# 3       colon   8p_loss               Mucinous  0.270317
# 0       colon   8q_gain              Age_group  0.815270
# 1       colon   8q_gain                 Gender  0.765412
# 2       colon   8q_gain                  Stage  0.677828
# 3       colon   8q_gain               Mucinous  0.626902
# 0       hnscc   8p_loss              Age_group  0.593501
# 1       hnscc   8p_loss         alcohol_consum  0.497564
# 2       hnscc   8p_loss       histologic_grade  0.151296
# 3       hnscc   8p_loss  patho_staging_curated  0.085234
# 4       hnscc   8p_loss        smoking_history  0.447989
# 5       hnscc   8p_loss     tumor_site_curated  0.628355
# 0       hnscc   8q_gain              Age_group  0.069927
# 1       hnscc   8q_gain         alcohol_consum  0.207965
# 2       hnscc   8q_gain       histologic_grade  0.863069
# 3       hnscc   8q_gain  patho_staging_curated  0.061720
# 4       hnscc   8q_gain        smoking_history  0.467728
# 5       hnscc   8q_gain     tumor_site_curated  0.995840
# 0        lscc   8p_loss              Age_group  0.801651
# 1        lscc   8p_loss                 Gender  0.880098
# 2        lscc   8p_loss                  Stage  0.217336
# 3        lscc   8p_loss      Country.of.Origin  0.943253
# 4        lscc   8p_loss      Pack.Years.Smoked  0.966348
# 0        lscc   8q_gain              Age_group  0.020487
# 1        lscc   8q_gain                 Gender  0.672767
# 2        lscc   8q_gain                  Stage  0.329076
# 3        lscc   8q_gain      Country.of.Origin  0.023197
# 4        lscc   8q_gain      Pack.Years.Smoked  0.219610
# 0        luad   8p_loss              Age_group  0.282477
# 1        luad   8p_loss                 Gender  0.012277
# 2        luad   8p_loss              BMI_range  0.007883
# 3        luad   8p_loss                  Stage  0.625727
# 4        luad   8p_loss       Region.of.Origin  0.161302
# 5        luad   8p_loss      Pack.Years.Smoked  0.929637
# 0        luad   8q_gain              Age_group  0.015650
# 1        luad   8q_gain                 Gender  0.755291
# 2        luad   8q_gain              BMI_range  0.005345
# 3        luad   8q_gain                  Stage  0.865882
# 4        luad   8q_gain       Region.of.Origin  0.001375
# 5        luad   8q_gain      Pack.Years.Smoked  0.817302
# 0     ovarian   8p_loss              Age_group  0.265560
# 0     ovarian   8q_gain              Age_group  0.218780

# %%
reject, pvals_corrected, alphacSidak, alphacBonf = statsmodels.stats.multitest.multipletests(
    pvals=all_results["pval"], 
    alpha=0.05, 
    method="fdr_bh"
)

all_results = all_results.assign(adj_p=pvals_corrected)

# %%
all_results[all_results["adj_p"] <= 0.05]
# Out:
#   cancer_type cnv_event          variable      pval     adj_p
# 3        brca   8q_gain             PAM50  0.000375  0.010138
# 4        brca   8q_gain          NMF.v2.1  0.000138  0.007445
# 4        luad   8q_gain  Region.of.Origin  0.001375  0.024744

# %%
all_results
# Out:
#   cancer_type cnv_event               variable      pval     adj_p
# 0        brca   8p_loss              Age_group  0.279619  0.622375
# 1        brca   8p_loss                   Race  0.383808  0.740202
# 2        brca   8p_loss                  Stage  0.973413  0.991779
# 3        brca   8p_loss                  PAM50  0.904833  0.991779
# 4        brca   8p_loss               NMF.v2.1  0.943659  0.991779
# 0        brca   8q_gain              Age_group  0.353898  0.707796
# 1        brca   8q_gain                   Race  0.288137  0.622375
# 2        brca   8q_gain                  Stage  0.606505  0.942532
# 3        brca   8q_gain                  PAM50  0.000375  0.010138
# 4        brca   8q_gain               NMF.v2.1  0.000138  0.007445
# 0       colon   8p_loss              Age_group  0.162933  0.586560
# 1       colon   8p_loss                 Gender  0.698452  0.967088
# 2       colon   8p_loss                  Stage  0.177391  0.592947
# 3       colon   8p_loss               Mucinous  0.270317  0.622375
# 0       colon   8q_gain              Age_group  0.815270  0.991779
# 1       colon   8q_gain                 Gender  0.765412  0.991779
# 2       colon   8q_gain                  Stage  0.677828  0.963229
# 3       colon   8q_gain               Mucinous  0.626902  0.942532
# 0       hnscc   8p_loss              Age_group  0.593501  0.942532
# 1       hnscc   8p_loss         alcohol_consum  0.497564  0.866724
# 2       hnscc   8p_loss       histologic_grade  0.151296  0.586560
# 3       hnscc   8p_loss  patho_staging_curated  0.085234  0.383555
# 4       hnscc   8p_loss        smoking_history  0.447989  0.834186
# 5       hnscc   8p_loss     tumor_site_curated  0.628355  0.942532
# 0       hnscc   8q_gain              Age_group  0.069927  0.343280
# 1       hnscc   8q_gain         alcohol_consum  0.207965  0.592947
# 2       hnscc   8q_gain       histologic_grade  0.863069  0.991779
# 3       hnscc   8q_gain  patho_staging_curated  0.061720  0.333285
# 4       hnscc   8q_gain        smoking_history  0.467728  0.841910
# 5       hnscc   8q_gain     tumor_site_curated  0.995840  0.995840
# 0        lscc   8p_loss              Age_group  0.801651  0.991779
# 1        lscc   8p_loss                 Gender  0.880098  0.991779
# 2        lscc   8p_loss                  Stage  0.217336  0.592947
# 3        lscc   8p_loss      Country.of.Origin  0.943253  0.991779
# 4        lscc   8p_loss      Pack.Years.Smoked  0.966348  0.991779
# 0        lscc   8q_gain              Age_group  0.020487  0.138288
# 1        lscc   8q_gain                 Gender  0.672767  0.963229
# 2        lscc   8q_gain                  Stage  0.329076  0.683465
# 3        lscc   8q_gain      Country.of.Origin  0.023197  0.139182
# 4        lscc   8q_gain      Pack.Years.Smoked  0.219610  0.592947
# 0        luad   8p_loss              Age_group  0.282477  0.622375
# 1        luad   8p_loss                 Gender  0.012277  0.110494
# 2        luad   8p_loss              BMI_range  0.007883  0.085139
# 3        luad   8p_loss                  Stage  0.625727  0.942532
# 4        luad   8p_loss       Region.of.Origin  0.161302  0.586560
# 5        luad   8p_loss      Pack.Years.Smoked  0.929637  0.991779
# 0        luad   8q_gain              Age_group  0.015650  0.120730
# 1        luad   8q_gain                 Gender  0.755291  0.991779
# 2        luad   8q_gain              BMI_range  0.005345  0.072152
# 3        luad   8q_gain                  Stage  0.865882  0.991779
# 4        luad   8q_gain       Region.of.Origin  0.001375  0.024744
# 5        luad   8q_gain      Pack.Years.Smoked  0.817302  0.991779
# 0     ovarian   8p_loss              Age_group  0.265560  0.622375
# 0     ovarian   8q_gain              Age_group  0.218780  0.592947

# %%
alt.Chart(all_results).mark_bar().encode(
    x=alt.X(
        "adj_p",
        bin=alt.Bin(step=0.05)
    ),
    y=alt.Y(
        "count()"
    )
)
# Out:
# alt.Chart(...)

# %%
all_results
# Out:
#   cancer_type cnv_event               variable      pval     adj_p
# 0        brca   8p_loss              Age_group  0.279619  0.622375
# 1        brca   8p_loss                   Race  0.383808  0.740202
# 2        brca   8p_loss                  Stage  0.973413  0.991779
# 3        brca   8p_loss                  PAM50  0.904833  0.991779
# 4        brca   8p_loss               NMF.v2.1  0.943659  0.991779
# 0        brca   8q_gain              Age_group  0.353898  0.707796
# 1        brca   8q_gain                   Race  0.288137  0.622375
# 2        brca   8q_gain                  Stage  0.606505  0.942532
# 3        brca   8q_gain                  PAM50  0.000375  0.010138
# 4        brca   8q_gain               NMF.v2.1  0.000138  0.007445
# 0       colon   8p_loss              Age_group  0.162933  0.586560
# 1       colon   8p_loss                 Gender  0.698452  0.967088
# 2       colon   8p_loss                  Stage  0.177391  0.592947
# 3       colon   8p_loss               Mucinous  0.270317  0.622375
# 0       colon   8q_gain              Age_group  0.815270  0.991779
# 1       colon   8q_gain                 Gender  0.765412  0.991779
# 2       colon   8q_gain                  Stage  0.677828  0.963229
# 3       colon   8q_gain               Mucinous  0.626902  0.942532
# 0       hnscc   8p_loss              Age_group  0.593501  0.942532
# 1       hnscc   8p_loss         alcohol_consum  0.497564  0.866724
# 2       hnscc   8p_loss       histologic_grade  0.151296  0.586560
# 3       hnscc   8p_loss  patho_staging_curated  0.085234  0.383555
# 4       hnscc   8p_loss        smoking_history  0.447989  0.834186
# 5       hnscc   8p_loss     tumor_site_curated  0.628355  0.942532
# 0       hnscc   8q_gain              Age_group  0.069927  0.343280
# 1       hnscc   8q_gain         alcohol_consum  0.207965  0.592947
# 2       hnscc   8q_gain       histologic_grade  0.863069  0.991779
# 3       hnscc   8q_gain  patho_staging_curated  0.061720  0.333285
# 4       hnscc   8q_gain        smoking_history  0.467728  0.841910
# 5       hnscc   8q_gain     tumor_site_curated  0.995840  0.995840
# 0        lscc   8p_loss              Age_group  0.801651  0.991779
# 1        lscc   8p_loss                 Gender  0.880098  0.991779
# 2        lscc   8p_loss                  Stage  0.217336  0.592947
# 3        lscc   8p_loss      Country.of.Origin  0.943253  0.991779
# 4        lscc   8p_loss      Pack.Years.Smoked  0.966348  0.991779
# 0        lscc   8q_gain              Age_group  0.020487  0.138288
# 1        lscc   8q_gain                 Gender  0.672767  0.963229
# 2        lscc   8q_gain                  Stage  0.329076  0.683465
# 3        lscc   8q_gain      Country.of.Origin  0.023197  0.139182
# 4        lscc   8q_gain      Pack.Years.Smoked  0.219610  0.592947
# 0        luad   8p_loss              Age_group  0.282477  0.622375
# 1        luad   8p_loss                 Gender  0.012277  0.110494
# 2        luad   8p_loss              BMI_range  0.007883  0.085139
# 3        luad   8p_loss                  Stage  0.625727  0.942532
# 4        luad   8p_loss       Region.of.Origin  0.161302  0.586560
# 5        luad   8p_loss      Pack.Years.Smoked  0.929637  0.991779
# 0        luad   8q_gain              Age_group  0.015650  0.120730
# 1        luad   8q_gain                 Gender  0.755291  0.991779
# 2        luad   8q_gain              BMI_range  0.005345  0.072152
# 3        luad   8q_gain                  Stage  0.865882  0.991779
# 4        luad   8q_gain       Region.of.Origin  0.001375  0.024744
# 5        luad   8q_gain      Pack.Years.Smoked  0.817302  0.991779
# 0     ovarian   8p_loss              Age_group  0.265560  0.622375
# 0     ovarian   8q_gain              Age_group  0.218780  0.592947

# %%
def pval_plot(df, title, group_col, val_col, color_col, y=True, sig=0.05):
    
    val_log_col = "neg_log_p"
    log_cutoff = -np.log10(sig)
    df = df.assign(**{val_log_col: - np.log10(df[val_col])})
    
    if y:
        chart_y = alt.Y(
            val_log_col,
            title="-log(p)"
        )
        
    else:
        chart_y = alt.Y(
            val_log_col,
            axis=alt.Axis(
                labels=False,
                ticks=False,
                title=None
            )
        )
        
    chart = alt.Chart(df).mark_point().encode(
        x=group_col,
        y=chart_y,
        color=color_col
    )
    
    chart_text = chart.transform_filter(
        alt.datum.neg_log_p >= log_cutoff
    ).mark_text(
        align='left',
        baseline='middle',
        dx=7
    ).encode(
        text='variable'
    )


    line = alt.Chart(pd.DataFrame({
        'y': [log_cutoff],
        "label": [f"-log({sig})"]
    })).mark_rule(color="crimson").encode(
        y="y"
    )

    text = line.mark_text(
        align="right",
        dx=-175
    ).encode(
        text="label"
    )

    if y:
        return (chart + chart_text + line + text).properties(title=title)
    else:
        return (chart + chart_text + line).properties(title=title)

alt.hconcat(
    pval_plot(all_results[all_results["cnv_event"] == "8p_loss"], "8p loss", "variable", "adj_p", "cancer_type"),
    pval_plot(
        all_results[all_results["cnv_event"] == "8q_gain"], "8q gain", "variable", "adj_p", "cancer_type", False)
).resolve_scale(y="shared").configure_axisY(titleY=175, titleX=-35).properties(
    title="Chi-squared results for correlation of chr8 CNV events with clinical attributes"
).configure_title(
    anchor="middle"
)
# Out:
# alt.HConcatChart(...)
