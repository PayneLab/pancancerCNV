# %% [markdown]
# # Cis effects enrichment - g:Profiler
#
# This notebook will use the [g:Profiler tool](https://biit.cs.ut.ee/gprofiler/gost) to look for pathways enriched for proteins that came up across multiple cancers in the cis effects analysis.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import gprofiler
import cptac.utils as ut
import IPython.display

# %%
def run_gprofiler(input_file, cancer_type=None):

    input_df = pd.read_csv(input_file, sep="\t")
    
    if cancer_type is not None:
        cancer_df = input_df[input_df["cancers"].str.contains(cancer_type)]
        protein_list = cancer_df["protein"].tolist()
    else:
        protein_list = input_df["protein"].tolist()
    
    gp = gprofiler.GProfiler(return_dataframe=True)
    
    results = gp.profile(
        organism="hsapiens",
        query=protein_list,
        ordered=False,
        sources=["GO:BP", "KEGG", "REAC", "WP", "TF", "MIRNA", "HPA", "CORUM", "HP"]
    )
    
    return results

# %% [markdown]
# ### 7p trans effects

# %%
luad_7p_trans_results = run_gprofiler("pancancer_summary_7p_trans.tsv", cancer_type="luad")
luad_7p_trans_results
# Out:
#    source              native  \
# 0   GO:BP          GO:0019835
# 1   GO:BP          GO:0016192
# 2    KEGG          KEGG:04610
# 3    REAC   REAC:R-HSA-166665
# 4   GO:BP          GO:0006957
# 5   GO:BP          GO:0006950
# 6   GO:BP          GO:0006955
# 7   GO:BP          GO:0051649
# 8   GO:BP          GO:0051125
# 9   GO:BP          GO:0002376
# 10  GO:BP          GO:0002253
# 11   KEGG          KEGG:05020
# 12  GO:BP          GO:0050778
# 13  CORUM          CORUM:2510
# 14  GO:BP          GO:0002252
# 15     WP            WP:WP545
# 16  GO:BP          GO:0050776
# 17  GO:BP          GO:0002684
# 18  GO:BP          GO:0051179
# 19  GO:BP          GO:0051641
# 20     WP           WP:WP2806
# 21     WP            WP:WP558
# 22  GO:BP          GO:0051234
# 23     WP           WP:WP4223
# 24  GO:BP          GO:0006810
# 25   REAC  REAC:R-HSA-9006335
# 26  GO:BP          GO:0002682
# 27  GO:BP          GO:0050790
# 28  GO:BP          GO:0031589
# 29     WP           WP:WP2291
# 30  GO:BP          GO:0045010
# 31   REAC   REAC:R-HSA-168256
# 32     WP           WP:WP4255
# 33   REAC   REAC:R-HSA-168249
#
#                                                  name       p_value  \
# 0                                           cytolysis  1.656833e-07
# 1                          vesicle-mediated transport  4.942335e-06
# 2                 Complement and coagulation cascades  1.766383e-05
# 3                      Terminal pathway of complement  3.162415e-05
# 4          complement activation, alternative pathway  3.511521e-05
# 5                                  response to stress  1.599353e-04
# 6                                     immune response  2.973098e-04
# 7               establishment of localization in cell  4.087076e-04
# 8                      regulation of actin nucleation  5.394889e-04
# 9                               immune system process  6.867659e-04
# 10                      activation of immune response  1.540217e-03
# 11                                     Prion diseases  2.305610e-03
# 12             positive regulation of immune response  3.168217e-03
# 13                       ZAP70-CRKL-WIPF1-WAS complex  3.774298e-03
# 14                            immune effector process  4.067219e-03
# 15                              Complement Activation  4.508915e-03
# 16                      regulation of immune response  4.669991e-03
# 17       positive regulation of immune system process  4.709003e-03
# 18                                       localization  5.766805e-03
# 19                              cellular localization  5.804988e-03
# 20                            Human Complement System  6.495953e-03
# 21                Complement and Coagulation Cascades  8.757552e-03
# 22                      establishment of localization  1.052100e-02
# 23                                      Ras Signaling  1.135199e-02
# 24                                          transport  1.146787e-02
# 25                        Signaling by Erythropoietin  1.538714e-02
# 26                regulation of immune system process  1.578004e-02
# 27                   regulation of catalytic activity  1.832439e-02
# 28                            cell-substrate adhesion  1.872879e-02
# 29  Deregulation of Rab and Rab Effector Genes in ...  1.980241e-02
# 30                                   actin nucleation  2.241191e-02
# 31                                      Immune System  3.334289e-02
# 32                         Non-small cell lung cancer  3.503184e-02
# 33                               Innate Immune System  4.025374e-02
#
#     significant                                        description  term_size  \
# 0          True  "The rupture of cell membranes and the loss of...         28
# 1          True  "A cellular transport process in which transpo...       2149
# 2          True                Complement and coagulation cascades         85
# 3          True                     Terminal pathway of complement          8
# 4          True  "Any process involved in the activation of any...         14
# 5          True  "Any process that results in a change in state...       4112
# 6          True  "Any immune system process that functions in t...       2228
# 7          True  "Any process, occuring in a cell, that localiz...       2810
# 8          True  "Any process that modulates the frequency, rat...         33
# 9          True  "Any process involved in the development or fu...       3199
# 10         True  "Any process that initiates an immune response...        557
# 11         True                                     Prion diseases         35
# 12         True  "Any process that activates or increases the f...        751
# 13         True                       ZAP70-CRKL-WIPF1-WAS complex          4
# 14         True  "Any process of the immune system that can pot...       1281
# 15         True                              Complement Activation         22
# 16         True  "Any process that modulates the frequency, rat...        996
# 17         True  "Any process that activates or increases the f...       1092
# 18         True  "Any process in which a cell, a substance, or ...       6919
# 19         True  "A cellular localization process whereby a sub...       3497
# 20         True                            Human Complement System         97
# 21         True                Complement and Coagulation Cascades         58
# 22         True  "Any process that localizes a substance or cel...       5479
# 23         True                                      Ras Signaling        183
# 24         True  "The directed movement of substances (such as ...       5355
# 25         True                        Signaling by Erythropoietin         23
# 26         True  "Any process that modulates the frequency, rat...       1618
# 27         True  "Any process that modulates the activity of an...       2406
# 28         True  "The attachment of a cell to the underlying su...        357
# 29         True  Deregulation of Rab and Rab Effector Genes in ...         16
# 30         True  "The initial step in the formation of an actin...         56
# 31         True                                      Immune System       2146
# 32         True                         Non-small cell lung cancer         72
# 33         True                               Innate Immune System       1092
#
#     query_size  intersection_size  effective_domain_size  precision    recall  \
# 0          245                  9                  17916   0.036735  0.321429
# 1          245                 63                  17916   0.257143  0.029316
# 2          134                 11                   7747   0.082090  0.129412
# 3          183                  5                  10588   0.027322  0.625000
# 4          245                  6                  17916   0.024490  0.428571
# 5          245                 93                  17916   0.379592  0.022617
# 6          245                 60                  17916   0.244898  0.026930
# 7          245                 70                  17916   0.285714  0.024911
# 8          245                  7                  17916   0.028571  0.212121
# 9          245                 76                  17916   0.310204  0.023757
# 10         245                 24                  17916   0.097959  0.043088
# 11         134                  6                   7747   0.044776  0.171429
# 12         245                 28                  17916   0.114286  0.037284
# 13          70                  3                   3627   0.042857  0.750000
# 14         245                 39                  17916   0.159184  0.030445
# 15         122                  5                   6954   0.040984  0.227273
# 16         245                 33                  17916   0.134694  0.033133
# 17         245                 35                  17916   0.142857  0.032051
# 18         245                130                  17916   0.530612  0.018789
# 19         245                 78                  17916   0.318367  0.022305
# 20         122                  9                   6954   0.073770  0.092784
# 21         122                  7                   6954   0.057377  0.120690
# 22         245                108                  17916   0.440816  0.019712
# 23         122                 12                   6954   0.098361  0.065574
# 24         245                106                  17916   0.432653  0.019795
# 25         183                  5                  10588   0.027322  0.217391
# 26         245                 44                  17916   0.179592  0.027194
# 27         245                 58                  17916   0.236735  0.024106
# 28         245                 17                  17916   0.069388  0.047619
# 29         122                  4                   6954   0.032787  0.250000
# 30         245                  7                  17916   0.028571  0.125000
# 31         183                 59                  10588   0.322404  0.027493
# 32         122                  7                   6954   0.057377  0.097222
# 33         183                 36                  10588   0.196721  0.032967
#
#       query                                           parents
# 0   query_1                                      [GO:0009987]
# 1   query_1                          [GO:0006810, GO:0009987]
# 2   query_1                                      [KEGG:00000]
# 3   query_1                               [REAC:R-HSA-166658]
# 4   query_1                          [GO:0006956, GO:0045087]
# 5   query_1                                      [GO:0050896]
# 6   query_1                          [GO:0002376, GO:0050896]
# 7   query_1                          [GO:0051234, GO:0051641]
# 8   query_1                          [GO:0030833, GO:0045010]
# 9   query_1                                      [GO:0008150]
# 10  query_1                          [GO:0002376, GO:0050778]
# 11  query_1                                      [KEGG:00000]
# 12  query_1  [GO:0002684, GO:0006955, GO:0048584, GO:0050776]
# 13  query_1                                   [CORUM:0000000]
# 14  query_1                                      [GO:0002376]
# 15  query_1                                       [WP:000000]
# 16  query_1              [GO:0002682, GO:0006955, GO:0048583]
# 17  query_1              [GO:0002376, GO:0002682, GO:0048518]
# 18  query_1                                      [GO:0008150]
# 19  query_1                          [GO:0009987, GO:0051179]
# 20  query_1                                       [WP:000000]
# 21  query_1                                       [WP:000000]
# 22  query_1                                      [GO:0051179]
# 23  query_1                                       [WP:000000]
# 24  query_1                                      [GO:0051234]
# 25  query_1                               [REAC:R-HSA-162582]
# 26  query_1                          [GO:0002376, GO:0050789]
# 27  query_1                                      [GO:0065009]
# 28  query_1                                      [GO:0007155]
# 29  query_1                                       [WP:000000]
# 30  query_1                          [GO:0007015, GO:0030838]
# 31  query_1                                    [REAC:0000000]
# 32  query_1                                       [WP:000000]
# 33  query_1                               [REAC:R-HSA-168256]

# %%
luad_7p_trans_results[luad_7p_trans_results["source"] == "REAC"]
# Out:
#    source              native                            name   p_value  \
# 3    REAC   REAC:R-HSA-166665  Terminal pathway of complement  0.000032
# 25   REAC  REAC:R-HSA-9006335     Signaling by Erythropoietin  0.015387
# 31   REAC   REAC:R-HSA-168256                   Immune System  0.033343
# 33   REAC   REAC:R-HSA-168249            Innate Immune System  0.040254
#
#     significant                     description  term_size  query_size  \
# 3          True  Terminal pathway of complement          8         183
# 25         True     Signaling by Erythropoietin         23         183
# 31         True                   Immune System       2146         183
# 33         True            Innate Immune System       1092         183
#
#     intersection_size  effective_domain_size  precision    recall    query  \
# 3                   5                  10588   0.027322  0.625000  query_1
# 25                  5                  10588   0.027322  0.217391  query_1
# 31                 59                  10588   0.322404  0.027493  query_1
# 33                 36                  10588   0.196721  0.032967  query_1
#
#                 parents
# 3   [REAC:R-HSA-166658]
# 25  [REAC:R-HSA-162582]
# 31       [REAC:0000000]
# 33  [REAC:R-HSA-168256]
