# %%
import cptac
import matplotlib.pyplot as plt
import seaborn as sns

# %%
luad = cptac.Luad()

# %%
luad_cnv = luad.get_CNV()
luad_cnv
# Out:
# Name          A1BG    A1CF     A2M   A2ML1  A3GALT2  A4GALT   A4GNT    AAAS  \
# Patient_ID
# C3L-00001  -0.0617 -0.2425  0.2653  0.2653   0.2548 -0.1085 -0.0400 -0.2365
# C3L-00009  -0.0638 -0.0238  0.1814  0.1814   0.0070 -0.1128 -0.0482  0.2157
# C3L-00080   0.5650 -0.2897 -0.2499 -0.2499  -0.0467 -0.3407  0.4592  0.3043
# C3L-00083  -0.0060  0.0224 -0.0003 -0.0003  -0.0067  0.0104 -0.0141  0.0016
# C3L-00093  -0.1628 -0.0388 -0.2018 -0.2018  -0.0075 -0.1330 -0.0040  0.0006
# ...            ...     ...     ...     ...      ...     ...     ...     ...
# C3N-02729   0.2136 -0.3436  0.3787  0.3787   0.0093 -0.0137 -0.2898 -0.1998
# X11LU013   -0.0701  0.0149  0.1758  0.1758  -0.2453 -0.0689 -0.2020 -0.6964
# X11LU016   -0.0852 -0.2595 -0.2532 -0.2532  -0.0436 -0.1652  0.0362 -0.0554
# X11LU022    0.2549 -0.0664 -0.0662 -0.0662   0.1159  0.1087  0.2551 -0.0459
# X11LU035   -0.2315 -0.0787 -0.0735 -0.0735  -0.0845 -0.0953  0.0583 -0.0183
#
# ...

# %%
luad_cnv_t =luad_cnv.transpose()
sns.distplot(luad_cnv_t['C3L-00093'], hist=True, kde=False)

# %%
x

# %%
[(0, 166049.0, 0),
 (166049.0, 232137.0, 2),
 (232137.0, 2935353.0, 1),
 (2935353.0, 31639222.0, 0),
 (31639222.0, 32192028.0, 1),
 (32192028.0, 33370824.0, 0),
 (33370824.0, 34784028.0, 1),
 (34784028.0, 36784324.0, 2),
 (36784324.0, 37695782.0, 3),
 (37695782.0, 38163335.0, 4),
 (38163335.0, 38600661.0, 5),
 (38600661.0, 38728186.0, 4),
 (38728186.0, 39451045.0, 5),
 (39451045.0, 39584489.0, 4),
 (39584489.0, 41271048.0, 5),
 (41271048.0, 41490396.0, 4),
 (41490396.0, 43246755.0, 5),
 (43246755.0, 46549089.0, 4),
 (46549089.0, 52110839.0, 5),
 (52110839.0, 98042086.0, 6),
 (98042086.0, 104484369.0, 6),
 (104484369.0, 104489231.0, 5),
 (104489231.0, 119325171.0, 6),
 (119325171.0, 119557086.0, 5),
 (119557086.0, 123348034.0, 6),
 (123348034.0, 123416726.0, 5),
 (123416726.0, 145052465.0, 6)]
