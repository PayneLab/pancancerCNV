# %% [markdown]
# # Assign overlap p values to individual proteins and perform multiple testing correction

# %%
import pandas as pd
import numpy as np
import statsmodels.stats.multitest

# %%
CHROMOSOMES = ["8"]
ARMS = ["p", "q"]
TRANS_OR_CIS_OPTS = ["cis", "trans"]

# %% [markdown]
# ## Load files

# %%
all_overlaps = pd.DataFrame()
all_pvals = pd.DataFrame()

for CHROMOSOME in CHROMOSOMES:
    for ARM in ARMS:
        for TRANS_OR_CIS in TRANS_OR_CIS_OPTS:
            
            overlaps = pd.\
            read_csv(f"pancancer_summary_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            pvals = pd.\
            read_csv(f"overlap_pvals_{CHROMOSOME}{ARM}_{TRANS_OR_CIS}.tsv", sep="\t").\
            assign(group=f"{CHROMOSOME}{ARM}_{TRANS_OR_CIS}")
            
            all_overlaps = all_overlaps.append(overlaps)
            all_pvals = all_pvals.append(pvals)

# %% [markdown]
# ## Merge in the _p_ values for each protein
#
# We will exclude proteins that were only different in one cancer type (no overlap).

# %%
all_overlaps = all_overlaps[all_overlaps["num_cancers"] > 1].\
merge(
    right=all_pvals,
    left_on=["num_cancers", "group"],
    right_on=["overlap_size", "group"],
    how="inner"
)

# %% [markdown]
# ## Apply multiple testing correction

# %%
reject, adj_pvals, alpha_sidak, alpha_bonf = statsmodels.stats.multitest.multipletests(
    pvals=all_overlaps["pvals"], 
    alpha=0.05, 
    method="fdr_bh"
)

all_overlaps = all_overlaps.\
assign(adj_p=adj_pvals)

all_overlaps = all_overlaps[all_overlaps["adj_p"] <= 0.05].\
sort_values(by=["adj_p", "protein", "group"])

# %% [markdown]
# ## Split table by protein group

# %%
groups = { group:df.reset_index(drop=True) for group, df in all_overlaps.groupby("group")}
pd.options.display.max_rows = None

# %% [markdown]
# ## Print results

# %%
groups["8p_cis"]
# Out:
#     protein                             cancers  mean_simp_change  \
# 0    AGPAT5  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 1  ATP6V1B2  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 2     CHMP7  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 3      ERI1  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 4    KIF13B  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 5      MSRA  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 6      NAT1  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 7   PPP2R2A  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 8    VPS37A  brca_colon_hnscc_lscc_luad_ovarian              -1.0
# 9      XPO7  brca_colon_hnscc_lscc_luad_ovarian              -1.0
#
#    num_cancers   group  overlap_size     pvals     adj_p
# 0            6  8p_cis             6  0.007968  0.041866
# 1            6  8p_cis             6  0.007968  0.041866
# 2            6  8p_cis             6  0.007968  0.041866
# 3            6  8p_cis             6  0.007968  0.041866
# 4            6  8p_cis             6  0.007968  0.041866
# 5            6  8p_cis             6  0.007968  0.041866
# 6            6  8p_cis             6  0.007968  0.041866
# 7            6  8p_cis             6  0.007968  0.041866
# 8            6  8p_cis             6  0.007968  0.041866
# 9            6  8p_cis             6  0.007968  0.041866

# %%
groups["8p_trans"]
# Out:
#          protein          cancers  mean_simp_change  num_cancers     group  \
# 0       ATP6V1E1  colon_lscc_luad              -1.0            3  8p_trans
# 1        ATP6V1H  colon_lscc_luad              -1.0            3  8p_trans
# 2          CNOT8   brca_lscc_luad               1.0            3  8p_trans
# 3          ACAP1        lscc_luad              -1.0            2  8p_trans
# 4           AGO2       colon_lscc               1.0            2  8p_trans
# 5        ARFGAP3       colon_lscc              -1.0            2  8p_trans
# 6        ATP6V1A       colon_luad              -1.0            2  8p_trans
# 7       ATP6V1G1       colon_lscc              -1.0            2  8p_trans
# 8         CRELD2       colon_lscc              -1.0            2  8p_trans
# 9         CYB5R4        lscc_luad              -1.0            2  8p_trans
# 10         DDX28       colon_lscc               1.0            2  8p_trans
# 11       DNAJC19       colon_lscc               1.0            2  8p_trans
# 12         ELMO1        lscc_luad              -1.0            2  8p_trans
# 13           FAS       colon_lscc              -1.0            2  8p_trans
# 14          FGD3        lscc_luad              -1.0            2  8p_trans
# 15          GCLC       colon_lscc               1.0            2  8p_trans
# 16          GRAP        lscc_luad              -1.0            2  8p_trans
# 17      HIST1H1D       hnscc_luad              -1.0            2  8p_trans
# 18         ISG20        lscc_luad              -1.0            2  8p_trans
# 19         LMAN1       colon_lscc              -1.0            2  8p_trans
# 20        MRPL18       colon_lscc               1.0            2  8p_trans
# 21         MRPL3       colon_lscc               1.0            2  8p_trans
# 22        MRPL49       colon_lscc               1.0            2  8p_trans
# 23         MTMR6        lscc_luad              -1.0            2  8p_trans
# 24         NUCB2       colon_lscc              -1.0            2  8p_trans
# 25          P4HB       colon_lscc              -1.0            2  8p_trans
# 26         PLCL2        lscc_luad              -1.0            2  8p_trans
# 27          PPIB        lscc_luad              -1.0            2  8p_trans
# 28         PRKCB        lscc_luad              -1.0            2  8p_trans
# 29          PTK2       colon_luad               1.0            2  8p_trans
# 30         RCSD1        lscc_luad              -1.0            2  8p_trans
# 31  SETDB2-PHF11        lscc_luad              -1.0            2  8p_trans
# 32         SMAP2       hnscc_lscc              -1.0            2  8p_trans
# 33        TOMM70       colon_lscc               1.0            2  8p_trans
# 34        TXNDC5        lscc_luad              -1.0            2  8p_trans
# 35           WRN        brca_luad              -1.0            2  8p_trans
#
#     overlap_size     pvals     adj_p
# 0              3  0.000036  0.001002
# 1              3  0.000036  0.001002
# 2              3  0.000036  0.001002
# 3              2  0.011914  0.041866
# 4              2  0.011914  0.041866
# 5              2  0.011914  0.041866
# 6              2  0.011914  0.041866
# 7              2  0.011914  0.041866
# 8              2  0.011914  0.041866
# 9              2  0.011914  0.041866
# 10             2  0.011914  0.041866
# 11             2  0.011914  0.041866
# 12             2  0.011914  0.041866
# 13             2  0.011914  0.041866
# 14             2  0.011914  0.041866
# 15             2  0.011914  0.041866
# 16             2  0.011914  0.041866
# 17             2  0.011914  0.041866
# 18             2  0.011914  0.041866
# 19             2  0.011914  0.041866
# 20             2  0.011914  0.041866
# 21             2  0.011914  0.041866
# 22             2  0.011914  0.041866
# 23             2  0.011914  0.041866
# 24             2  0.011914  0.041866
# 25             2  0.011914  0.041866
# 26             2  0.011914  0.041866
# 27             2  0.011914  0.041866
# 28             2  0.011914  0.041866
# 29             2  0.011914  0.041866
# 30             2  0.011914  0.041866
# 31             2  0.011914  0.041866
# 32             2  0.011914  0.041866
# 33             2  0.011914  0.041866
# 34             2  0.011914  0.041866
# 35             2  0.011914  0.041866

# %%
groups["8q_cis"]
# Out:
#   protein                             cancers  mean_simp_change  num_cancers  \
# 0   CPNE3  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 1  OTUD6B  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 2    POP1  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 3    RIDA  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 4   RMDN1  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 5    STK3  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
# 6   YWHAZ  brca_colon_hnscc_lscc_luad_ovarian               1.0            6
#
#     group  overlap_size     pvals     adj_p
# 0  8q_cis             6  0.001634  0.014257
# 1  8q_cis             6  0.001634  0.014257
# 2  8q_cis             6  0.001634  0.014257
# 3  8q_cis             6  0.001634  0.014257
# 4  8q_cis             6  0.001634  0.014257
# 5  8q_cis             6  0.001634  0.014257
# 6  8q_cis             6  0.001634  0.014257

# %%
groups["8q_trans"]
# Out:
#     protein                     cancers  mean_simp_change  num_cancers  \
# 0   ARFGEF1  brca_colon_hnscc_lscc_luad               1.0            5
# 1       GGH  brca_colon_hnscc_lscc_luad               1.0            5
# 2     STAU2  brca_colon_hnscc_lscc_luad               1.0            5
# 3    YTHDF3  brca_colon_hnscc_lscc_luad               1.0            5
# 4     MTFR1        brca_hnscc_lscc_luad               1.0            4
# 5     PRKDC        brca_colon_lscc_luad               1.0            4
# 6    ANKFY1             brca_colon_lscc              -1.0            3
# 7   C8orf82             brca_colon_luad               1.0            3
# 8      CYC1             brca_colon_luad               1.0            3
# 9      HGH1             brca_colon_luad               1.0            3
# 10    NCOA2              brca_lscc_luad               1.0            3
# 11     PTK2             brca_colon_luad               1.0            3
# 12     RRS1             brca_colon_luad               1.0            3
# 13     TGS1              brca_lscc_luad               1.0            3
# 14   TMEM68             colon_lscc_luad               1.0            3
# 15   TMEM70             brca_colon_luad               1.0            3
# 16    UQCRH             brca_colon_luad               1.0            3
# 17   VCPIP1          brca_colon_ovarian               1.0            3
# 18   ZBTB10           brca_luad_ovarian               1.0            3
#
#        group  overlap_size     pvals     adj_p
# 0   8q_trans             5  0.000000  0.000000
# 1   8q_trans             5  0.000000  0.000000
# 2   8q_trans             5  0.000000  0.000000
# 3   8q_trans             5  0.000000  0.000000
# 4   8q_trans             4  0.000011  0.000481
# 5   8q_trans             4  0.000011  0.000481
# 6   8q_trans             3  0.000995  0.011447
# 7   8q_trans             3  0.000995  0.011447
# 8   8q_trans             3  0.000995  0.011447
# 9   8q_trans             3  0.000995  0.011447
# 10  8q_trans             3  0.000995  0.011447
# 11  8q_trans             3  0.000995  0.011447
# 12  8q_trans             3  0.000995  0.011447
# 13  8q_trans             3  0.000995  0.011447
# 14  8q_trans             3  0.000995  0.011447
# 15  8q_trans             3  0.000995  0.011447
# 16  8q_trans             3  0.000995  0.011447
# 17  8q_trans             3  0.000995  0.011447
# 18  8q_trans             3  0.000995  0.011447

# %% [markdown]
# ## Save results

# %%
all_overlaps.to_csv("sig_diff_all_overlaps.tsv", sep="\t", index=False)
