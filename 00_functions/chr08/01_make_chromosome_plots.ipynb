# %% [markdown]
# # Make chromosome plots

# %%
import cnvutils
from IPython.display import Image

CHROMOSOME = 8

# %% [markdown]
# ## Gradient plots

# %%
Image(cnvutils.make_chr_gradient_plot(
    source="cptac",
    chromosome=CHROMOSOME,
))
# Out:
# INFO:tornado.access:200 GET / (::1) 4.27ms
# INFO:tornado.access:200 GET / (::1) 4.27ms
# INFO:tornado.access:200 GET /vega.js (::1) 4.49ms
# INFO:tornado.access:200 GET /vega.js (::1) 4.49ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.21ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.21ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 7.77ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 7.77ms

# %%
Image(cnvutils.make_chr_gradient_plot(
    source="gistic",
    chromosome=CHROMOSOME,
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.42ms
# INFO:tornado.access:304 GET / (::1) 0.42ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.48ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.48ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 4.24ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 4.24ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 5.53ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 5.53ms

# %% [markdown]
# ## Line plots

# %%
Image(cnvutils.make_chr_line_plot(
    source="cptac",
    chromosome=CHROMOSOME,
))

# %%
Image(cnvutils.make_chr_line_plot(
    source="gistic",
    level="gene",
    chromosome=CHROMOSOME,
))
