# %%
import altair as alt
import cnvutils
import cptac
import IPython.display
import numpy as np
import os
import pandas as pd
import statsmodels

from cnvutils.filenames import (
    get_has_event_path,
    get_ttest_results_path,
    get_protein_ttest_boxplot_path,
    get_all_props_path,
    get_proportions_perm_p_values_path,
)

from cnvutils.constants import (
    CHART_FORMAT,
    CHART_RENDER_METHOD,
    CHART_SCALE,
    SIG_CUTOFF,
)

from cnvutils.load_data import (
    get_cnv_counts,
    get_tables,
    get_ensembl_gene_locations,
    get_ncbi_gene_locations,
)

from cnvutils.chromosome_funcs import (
    select_genes_for_event,
)

# %%
all_props = pd.read_csv(get_all_props_path(
    data_dir=os.path.join(os.getcwd(), "..", "data"),
    chromosome=8,
), sep="\t")

sig = all_props[
    (all_props["prop_name"] == "sig_prop") &
    (all_props["proteomics_or_transcriptomics"] == "proteomics") &
    (all_props["source"] == "gistic")
].\
dropna(how="any", axis=0).\
reset_index(drop=True)

sig = sig.\
assign(diff=sig["not_has_prop"] - sig["has_prop"]).\
drop(columns=[
    "not_has_prop",
    "has_prop",
    "proteomics_or_transcriptomics",
    "source",
    "level",
    "prop_name",
])

sig
# Out:
#     chromosome arm gain_or_loss cis_or_trans cancer_types      diff
# 0            8   p         loss          cis         coad  0.073684
# 1            8   p         loss          cis        hnscc  0.117188
# 2            8   p         loss          cis         lscc  0.013986
# 3            8   p         loss          cis         luad  0.161972
# 4            8   p         loss          cis           ov -0.122951
# 5            8   p         loss          cis         pdac  0.472441
# 6            8   p         loss        trans         coad  0.117099
# 7            8   p         loss        trans        hnscc  0.095388
# 8            8   p         loss        trans         lscc  0.063028
# 9            8   p         loss        trans         luad  0.097555
# 10           8   p         loss        trans           ov -0.207493
# 11           8   p         loss        trans         pdac  0.476912
# 12           8   q         gain          cis         coad -0.004065
# 13           8   q         gain          cis        hnscc  0.047771
# 14           8   q         gain          cis         lscc  0.053221
# 15           8   q         gain          cis         luad  0.079882
# 16           8   q         gain          cis           ov  0.122449
# 17           8   q         gain          cis         pdac  0.404459
# 18           8   q         gain        trans         coad  0.045112
# 19           8   q         gain        trans        hnscc  0.076363
# 20           8   q         gain        trans         lscc  0.090504
# 21           8   q         gain        trans         luad  0.112682
# 22           8   q         gain        trans           ov  0.164192
# 23           8   q         gain        trans         pdac  0.414203

# %%
def split_groups(df, split_cols, results, prefix):
    """Recursively split proportions into subgroups and run t-tests on subgroups."""
    
    if len(split_cols) == 0:
        return
    
    col = split_cols[0]
    for val in df[col].unique():
        
        group = df[df[col] == val]
        new_prefix = "_".join([prefix, val])
        group = group.assign(
            group=new_prefix
        )
        
        results.append(group)
        
        split_groups(
            df=group,
            split_cols=split_cols[1:],
            results=results,
            prefix=new_prefix,
        )

# %%
res = [sig.assign(group="p_all")]
split_groups(
    df=sig,
    split_cols=[
        "cis_or_trans",
        "gain_or_loss",
    ],
    results=res,
    prefix="p",
)

plt = pd.concat(res)

# %%
plt
# Out:
#     chromosome arm gain_or_loss cis_or_trans cancer_types      diff  \
# 0            8   p         loss          cis         coad  0.073684
# 1            8   p         loss          cis        hnscc  0.117188
# 2            8   p         loss          cis         lscc  0.013986
# 3            8   p         loss          cis         luad  0.161972
# 4            8   p         loss          cis           ov -0.122951
# 5            8   p         loss          cis         pdac  0.472441
# 6            8   p         loss        trans         coad  0.117099
# 7            8   p         loss        trans        hnscc  0.095388
# 8            8   p         loss        trans         lscc  0.063028
# 9            8   p         loss        trans         luad  0.097555
# 10           8   p         loss        trans           ov -0.207493
# 11           8   p         loss        trans         pdac  0.476912
# 12           8   q         gain          cis         coad -0.004065
# 13           8   q         gain          cis        hnscc  0.047771
# 14           8   q         gain          cis         lscc  0.053221
# 15           8   q         gain          cis         luad  0.079882
# 16           8   q         gain          cis           ov  0.122449
# 17           8   q         gain          cis         pdac  0.404459
# 18           8   q         gain        trans         coad  0.045112
# 19           8   q         gain        trans        hnscc  0.076363
# 20           8   q         gain        trans         lscc  0.090504
# 21           8   q         gain        trans         luad  0.112682
# 22           8   q         gain        trans           ov  0.164192
# 23           8   q         gain        trans         pdac  0.414203
# 0            8   p         loss          cis         coad  0.073684
# 1            8   p         loss          cis        hnscc  0.117188
# 2            8   p         loss          cis         lscc  0.013986
# 3            8   p         loss          cis         luad  0.161972
# 4            8   p         loss          cis           ov -0.122951
# 5            8   p         loss          cis         pdac  0.472441
# ..         ...  ..          ...          ...          ...       ...
# 12           8   q         gain          cis         coad -0.004065
# 13           8   q         gain          cis        hnscc  0.047771
# 14           8   q         gain          cis         lscc  0.053221
# 15           8   q         gain          cis         luad  0.079882
# 16           8   q         gain          cis           ov  0.122449
# 17           8   q         gain          cis         pdac  0.404459
# 6            8   p         loss        trans         coad  0.117099
# 7            8   p         loss        trans        hnscc  0.095388
# 8            8   p         loss        trans         lscc  0.063028
# 9            8   p         loss        trans         luad  0.097555
# 10           8   p         loss        trans           ov -0.207493
# 11           8   p         loss        trans         pdac  0.476912
# 18           8   q         gain        trans         coad  0.045112
# 19           8   q         gain        trans        hnscc  0.076363
# 20           8   q         gain        trans         lscc  0.090504
# 21           8   q         gain        trans         luad  0.112682
# 22           8   q         gain        trans           ov  0.164192
# 23           8   q         gain        trans         pdac  0.414203
# 6            8   p         loss        trans         coad  0.117099
# 7            8   p         loss        trans        hnscc  0.095388
# 8            8   p         loss        trans         lscc  0.063028
# 9            8   p         loss        trans         luad  0.097555
# 10           8   p         loss        trans           ov -0.207493
# 11           8   p         loss        trans         pdac  0.476912
# 18           8   q         gain        trans         coad  0.045112
# 19           8   q         gain        trans        hnscc  0.076363
# 20           8   q         gain        trans         lscc  0.090504
# 21           8   q         gain        trans         luad  0.112682
# 22           8   q         gain        trans           ov  0.164192
# 23           8   q         gain        trans         pdac  0.414203
#
#            group
# 0          p_all
# 1          p_all
# 2          p_all
# 3          p_all
# 4          p_all
# 5          p_all
# 6          p_all
# 7          p_all
# 8          p_all
# 9          p_all
# 10         p_all
# 11         p_all
# 12         p_all
# 13         p_all
# 14         p_all
# 15         p_all
# 16         p_all
# 17         p_all
# 18         p_all
# 19         p_all
# 20         p_all
# 21         p_all
# 22         p_all
# 23         p_all
# 0          p_cis
# 1          p_cis
# 2          p_cis
# 3          p_cis
# 4          p_cis
# 5          p_cis
# ..           ...
# 12    p_cis_gain
# 13    p_cis_gain
# 14    p_cis_gain
# 15    p_cis_gain
# 16    p_cis_gain
# 17    p_cis_gain
# 6        p_trans
# 7        p_trans
# 8        p_trans
# 9        p_trans
# 10       p_trans
# 11       p_trans
# 18       p_trans
# 19       p_trans
# 20       p_trans
# 21       p_trans
# 22       p_trans
# 23       p_trans
# 6   p_trans_loss
# 7   p_trans_loss
# 8   p_trans_loss
# 9   p_trans_loss
# 10  p_trans_loss
# 11  p_trans_loss
# 18  p_trans_gain
# 19  p_trans_gain
# 20  p_trans_gain
# 21  p_trans_gain
# 22  p_trans_gain
# 23  p_trans_gain
#
# [72 rows x 7 columns]

# %%
p_path = get_proportions_perm_p_values_path(
    data_dir=os.path.join(os.getcwd(), "..", "data"),
    chromosome=8,
)

p_vals = pd.read_csv(p_path, sep="\t")

# Filter out just the p values we want
p_vals = p_vals[p_vals["group"] == "sig_props"][["name", "p"]]
p_vals = p_vals[p_vals["name"].str.contains("gistic")]

# Benjamini-Hochberg FDR correction
reject, adj_p, alphac_sidak, alphac_bonf = statsmodels.stats.multitest.multipletests(
    pvals=p_vals["p"],
    alpha=SIG_CUTOFF,
    method="fdr_bh",
)

p_vals = p_vals.assign(adj_p=adj_p)

p_vals = p_vals[p_vals["name"].str.contains("proteomics")]

p_vals = p_vals.assign(
    name=p_vals["name"].str.replace("_gistic_proteomics", "").replace({"p": "p_all"})
).drop(columns="p")

# %%
p_vals
# Out:
#             name     adj_p
# 79         p_all  0.064125
# 80         p_cis  0.036857
# 81    p_cis_gain  0.197250
# 82    p_cis_loss  0.027000
# 83       p_trans  0.112200
# 84  p_trans_gain  0.412929
# 85  p_trans_loss  0.025000

# %%
plt = plt.merge(
    p_vals,
    how="inner",
    left_on="group",
    right_on="name",
)

# %%
plt
# Out:
#     chromosome arm gain_or_loss cis_or_trans cancer_types      diff  \
# 0            8   p         loss          cis         coad  0.073684
# 1            8   p         loss          cis        hnscc  0.117188
# 2            8   p         loss          cis         lscc  0.013986
# 3            8   p         loss          cis         luad  0.161972
# 4            8   p         loss          cis           ov -0.122951
# 5            8   p         loss          cis         pdac  0.472441
# 6            8   p         loss        trans         coad  0.117099
# 7            8   p         loss        trans        hnscc  0.095388
# 8            8   p         loss        trans         lscc  0.063028
# 9            8   p         loss        trans         luad  0.097555
# 10           8   p         loss        trans           ov -0.207493
# 11           8   p         loss        trans         pdac  0.476912
# 12           8   q         gain          cis         coad -0.004065
# 13           8   q         gain          cis        hnscc  0.047771
# 14           8   q         gain          cis         lscc  0.053221
# 15           8   q         gain          cis         luad  0.079882
# 16           8   q         gain          cis           ov  0.122449
# 17           8   q         gain          cis         pdac  0.404459
# 18           8   q         gain        trans         coad  0.045112
# 19           8   q         gain        trans        hnscc  0.076363
# 20           8   q         gain        trans         lscc  0.090504
# 21           8   q         gain        trans         luad  0.112682
# 22           8   q         gain        trans           ov  0.164192
# 23           8   q         gain        trans         pdac  0.414203
# 24           8   p         loss          cis         coad  0.073684
# 25           8   p         loss          cis        hnscc  0.117188
# 26           8   p         loss          cis         lscc  0.013986
# 27           8   p         loss          cis         luad  0.161972
# 28           8   p         loss          cis           ov -0.122951
# 29           8   p         loss          cis         pdac  0.472441
# ..         ...  ..          ...          ...          ...       ...
# 42           8   q         gain          cis         coad -0.004065
# 43           8   q         gain          cis        hnscc  0.047771
# 44           8   q         gain          cis         lscc  0.053221
# 45           8   q         gain          cis         luad  0.079882
# 46           8   q         gain          cis           ov  0.122449
# 47           8   q         gain          cis         pdac  0.404459
# 48           8   p         loss        trans         coad  0.117099
# 49           8   p         loss        trans        hnscc  0.095388
# 50           8   p         loss        trans         lscc  0.063028
# 51           8   p         loss        trans         luad  0.097555
# 52           8   p         loss        trans           ov -0.207493
# 53           8   p         loss        trans         pdac  0.476912
# 54           8   q         gain        trans         coad  0.045112
# 55           8   q         gain        trans        hnscc  0.076363
# 56           8   q         gain        trans         lscc  0.090504
# 57           8   q         gain        trans         luad  0.112682
# 58           8   q         gain        trans           ov  0.164192
# 59           8   q         gain        trans         pdac  0.414203
# 60           8   p         loss        trans         coad  0.117099
# 61           8   p         loss        trans        hnscc  0.095388
# 62           8   p         loss        trans         lscc  0.063028
# 63           8   p         loss        trans         luad  0.097555
# 64           8   p         loss        trans           ov -0.207493
# 65           8   p         loss        trans         pdac  0.476912
# 66           8   q         gain        trans         coad  0.045112
# 67           8   q         gain        trans        hnscc  0.076363
# 68           8   q         gain        trans         lscc  0.090504
# 69           8   q         gain        trans         luad  0.112682
# 70           8   q         gain        trans           ov  0.164192
# 71           8   q         gain        trans         pdac  0.414203
#
#            group          name     adj_p
# 0          p_all         p_all  0.064125
# 1          p_all         p_all  0.064125
# 2          p_all         p_all  0.064125
# 3          p_all         p_all  0.064125
# 4          p_all         p_all  0.064125
# 5          p_all         p_all  0.064125
# 6          p_all         p_all  0.064125
# 7          p_all         p_all  0.064125
# 8          p_all         p_all  0.064125
# 9          p_all         p_all  0.064125
# 10         p_all         p_all  0.064125
# 11         p_all         p_all  0.064125
# 12         p_all         p_all  0.064125
# 13         p_all         p_all  0.064125
# 14         p_all         p_all  0.064125
# 15         p_all         p_all  0.064125
# 16         p_all         p_all  0.064125
# 17         p_all         p_all  0.064125
# 18         p_all         p_all  0.064125
# 19         p_all         p_all  0.064125
# 20         p_all         p_all  0.064125
# 21         p_all         p_all  0.064125
# 22         p_all         p_all  0.064125
# 23         p_all         p_all  0.064125
# 24         p_cis         p_cis  0.036857
# 25         p_cis         p_cis  0.036857
# 26         p_cis         p_cis  0.036857
# 27         p_cis         p_cis  0.036857
# 28         p_cis         p_cis  0.036857
# 29         p_cis         p_cis  0.036857
# ..           ...           ...       ...
# 42    p_cis_gain    p_cis_gain  0.197250
# 43    p_cis_gain    p_cis_gain  0.197250
# 44    p_cis_gain    p_cis_gain  0.197250
# 45    p_cis_gain    p_cis_gain  0.197250
# 46    p_cis_gain    p_cis_gain  0.197250
# 47    p_cis_gain    p_cis_gain  0.197250
# 48       p_trans       p_trans  0.112200
# 49       p_trans       p_trans  0.112200
# 50       p_trans       p_trans  0.112200
# 51       p_trans       p_trans  0.112200
# 52       p_trans       p_trans  0.112200
# 53       p_trans       p_trans  0.112200
# 54       p_trans       p_trans  0.112200
# 55       p_trans       p_trans  0.112200
# 56       p_trans       p_trans  0.112200
# 57       p_trans       p_trans  0.112200
# 58       p_trans       p_trans  0.112200
# 59       p_trans       p_trans  0.112200
# 60  p_trans_loss  p_trans_loss  0.025000
# 61  p_trans_loss  p_trans_loss  0.025000
# 62  p_trans_loss  p_trans_loss  0.025000
# 63  p_trans_loss  p_trans_loss  0.025000
# 64  p_trans_loss  p_trans_loss  0.025000
# 65  p_trans_loss  p_trans_loss  0.025000
# 66  p_trans_gain  p_trans_gain  0.412929
# 67  p_trans_gain  p_trans_gain  0.412929
# 68  p_trans_gain  p_trans_gain  0.412929
# 69  p_trans_gain  p_trans_gain  0.412929
# 70  p_trans_gain  p_trans_gain  0.412929
# 71  p_trans_gain  p_trans_gain  0.412929
#
# [72 rows x 9 columns]

# %%
plt = plt.assign(sig=(plt["adj_p"] <= SIG_CUTOFF).replace({True: "p <= 0.05", False: "p > 0.05"}))
p_vals = p_vals.assign(sig=(p_vals["adj_p"] <= SIG_CUTOFF).replace({True: "p <= 0.05", False: "p > 0.05"}))

bp = alt.Chart(plt).mark_boxplot(
    size=50,
    extent='min-max',
).encode(
    x=alt.X(
        "group",
        axis=alt.Axis(
            title=None,
            labelAngle=-30,
        )
    ),
    y=alt.Y(
        "diff",
        title="(No event prop affected) - (Has event prop affected)",
    ),
    color=alt.Color(
        "sig",
        title=None,
        scale=alt.Scale(
            domain=["p <= 0.05", "p > 0.05"],
            range=["#54a24b", "#4c78a8"]
        ),
    ),
).properties(
    width=500,
)

p_vals = p_vals.\
assign(
    line=-np.log10(SIG_CUTOFF),
    neg_log_adj_p=-np.log10(p_vals["adj_p"]),
)

base = alt.Chart(p_vals)

dots = base.mark_point(
    filled=True,
    opacity=1,
).encode(
    x=alt.X(
        "name",
        axis=alt.Axis(
            title=None,
            labels=False,
            ticks=False,
        ),
    ),
    y=alt.Y(
        "neg_log_adj_p",
        axis=alt.Axis(
            title="-log(p)",
            titlePadding=15,
        ),
    ),
    color=alt.Color(
        "sig",
    )
)

line = base.mark_rule(color="crimson").encode(
    y="line"
)

mhp = (dots + line).properties(
    width=500,
    height=100
)

xax = alt.Chart(pd.DataFrame({'y': [0]})).mark_rule(
    opacity=0.2,
).encode(y='y')

final = alt.vconcat(
    mhp,
    bp + xax,
    spacing=15,
).properties(
    title="",
).configure_axis(
    grid=False,
    domainWidth=1,
    domainColor="black",
).configure_title(
    fontSize=15,
    anchor="middle",
    orient="top",
    dy=20,
).configure_view(
    strokeOpacity=0,
)

# %%
final.save("final.png", method=CHART_RENDER_METHOD, scale_factor=CHART_SCALE)
# Out:
# INFO:tornado.access:200 GET / (::1) 4.64ms
# INFO:tornado.access:200 GET / (::1) 4.64ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.94ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.94ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.06ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.06ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 7.85ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 7.85ms

# %%
IPython.display.Image("final.png")
