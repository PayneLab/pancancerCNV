# %% [markdown]
# # Number of proteins different between tumor and normal in samples with an event versus samples without it

# %%
import altair as alt
import cnvutils
import numpy as np

# %%
all_pvals = cnvutils.get_has_vs_not_has_tumor_normal_diff_props(
    chromosomes_events={
            8: {
                "p": ["loss"],
                "q": ["gain"],
            },
        },
    sources=["cptac", "gistic"],
    levels=["gene"],    
)
# Out:
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
#
#
#
#
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': True, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov'], 'source': 'cptac', 'has_event': False, 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': True, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running _get_ttest_sig_counts with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'cancer_types': ['brca', 'coad', 'hnscc', 'lscc', 'luad', 'ov', 'pdac'], 'source': 'gistic', 'has_event': False, 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...

# %%
all_pvals = all_pvals.infer_objects()

all_pvals = all_pvals.assign(
    line=-np.log10(0.05),
    neg_log_sig_props=-np.log10(all_pvals["sig_props"]),
    neg_log_not_sig_props=-np.log10(all_pvals["not_sig_props"]),
    neg_log_na_props=-np.log10(all_pvals["na_props"]),
)

all_pvals = all_pvals.drop(columns=["sig_props", "not_sig_props", "na_props"])
all_pvals = all_pvals.melt(
    id_vars=["name", "line"],
    value_vars=["neg_log_sig_props", "neg_log_not_sig_props", "neg_log_na_props"],
    var_name="group",
    value_name="neg_log_p",
)

base = alt.Chart(all_pvals)

dots = base.mark_point().encode(
    x="name",
    y="neg_log_p",
    color="group",
)

line = base.mark_rule(color="crimson").encode(
    y="line"
)

dots + line
# Out:
#                                    name     line              group  neg_log_p
# 0                                 p_all  1.30103  neg_log_sig_props  10.471005
# 1                               p_cptac  1.30103  neg_log_sig_props   9.569432
# 2                    p_cptac_proteomics  1.30103  neg_log_sig_props   7.469667
# 3                p_cptac_proteomics_cis  1.30103  neg_log_sig_props   3.151706
# 4           p_cptac_proteomics_cis_loss  1.30103  neg_log_sig_props   1.269244
# 5           p_cptac_proteomics_cis_gain  1.30103  neg_log_sig_props   2.002133
# 6              p_cptac_proteomics_trans  1.30103  neg_log_sig_props   4.713781
# 7         p_cptac_proteomics_trans_loss  1.30103  neg_log_sig_props   2.247902
# 8         p_cptac_proteomics_trans_gain  1.30103  neg_log_sig_props   2.646476
# 9               p_cptac_transcriptomics  1.30103  neg_log_sig_props   2.728121
# 10          p_cptac_transcriptomics_cis  1.30103  neg_log_sig_props   1.930384
# 11     p_cptac_transcriptomics_cis_loss  1.30103  neg_log_sig_props   0.779076
# 12     p_cptac_transcriptomics_cis_gain  1.30103  neg_log_sig_props   1.067931
# 13        p_cptac_transcriptomics_trans  1.30103  neg_log_sig_props   2.438835
# 14   p_cptac_transcriptomics_trans_loss  1.30103  neg_log_sig_props   0.829068
# 15   p_cptac_transcriptomics_trans_gain  1.30103  neg_log_sig_props   1.882081
# 16                             p_gistic  1.30103  neg_log_sig_props   5.246858
# 17                  p_gistic_proteomics  1.30103  neg_log_sig_props   2.846877
# 18              p_gistic_proteomics_cis  1.30103  neg_log_sig_props   1.497648
# 19         p_gistic_proteomics_cis_loss  1.30103  neg_log_sig_props   0.694633
# 20         p_gistic_proteomics_cis_gain  1.30103  neg_log_sig_props   0.968778
# 21            p_gistic_proteomics_trans  1.30103  neg_log_sig_props   1.573778
# 22       p_gistic_proteomics_trans_loss  1.30103  neg_log_sig_props   0.548059
# 23       p_gistic_proteomics_trans_gain  1.30103  neg_log_sig_props   1.382908
# 24             p_gistic_transcriptomics  1.30103  neg_log_sig_props   2.762087
# 25         p_gistic_transcriptomics_cis  1.30103  neg_log_sig_props   1.106476
# 26    p_gistic_transcriptomics_cis_loss  1.30103  neg_log_sig_props   0.763201
# 27    p_gistic_transcriptomics_cis_gain  1.30103  neg_log_sig_props   0.496325
# 28       p_gistic_transcriptomics_trans  1.30103  neg_log_sig_props   1.870819
# 29  p_gistic_transcriptomics_trans_loss  1.30103  neg_log_sig_props   0.834192
# ..                                  ...      ...                ...        ...
# 63                              p_cptac  1.30103   neg_log_na_props   1.992831
# 64                   p_cptac_proteomics  1.30103   neg_log_na_props   1.970903
# 65               p_cptac_proteomics_cis  1.30103   neg_log_na_props   1.073446
# 66          p_cptac_proteomics_cis_loss  1.30103   neg_log_na_props   0.582385
# 67          p_cptac_proteomics_cis_gain  1.30103   neg_log_na_props   0.579498
# 68             p_cptac_proteomics_trans  1.30103   neg_log_na_props   1.089051
# 69        p_cptac_proteomics_trans_loss  1.30103   neg_log_na_props   0.577165
# 70        p_cptac_proteomics_trans_gain  1.30103   neg_log_na_props   0.589436
# 71              p_cptac_transcriptomics  1.30103   neg_log_na_props   2.067109
# 72          p_cptac_transcriptomics_cis  1.30103   neg_log_na_props   0.872976
# 73     p_cptac_transcriptomics_cis_loss  1.30103   neg_log_na_props   0.827562
# 74     p_cptac_transcriptomics_cis_gain  1.30103   neg_log_na_props   0.129713
# 75        p_cptac_transcriptomics_trans  1.30103   neg_log_na_props   3.244864
# 76   p_cptac_transcriptomics_trans_loss  1.30103   neg_log_na_props   1.383807
# 77   p_cptac_transcriptomics_trans_gain  1.30103   neg_log_na_props   1.554197
# 78                             p_gistic  1.30103   neg_log_na_props   0.471075
# 79                  p_gistic_proteomics  1.30103   neg_log_na_props   0.392695
# 80              p_gistic_proteomics_cis  1.30103   neg_log_na_props   0.272025
# 81         p_gistic_proteomics_cis_loss  1.30103   neg_log_na_props   0.177906
# 82         p_gistic_proteomics_cis_gain  1.30103   neg_log_na_props   0.667958
# 83            p_gistic_proteomics_trans  1.30103   neg_log_na_props   0.220332
# 84       p_gistic_proteomics_trans_loss  1.30103   neg_log_na_props   0.192948
# 85       p_gistic_proteomics_trans_gain  1.30103   neg_log_na_props   0.695917
# 86             p_gistic_transcriptomics  1.30103   neg_log_na_props   1.675656
# 87         p_gistic_transcriptomics_cis  1.30103   neg_log_na_props   0.816872
# 88    p_gistic_transcriptomics_cis_loss  1.30103   neg_log_na_props   0.805696
# 89    p_gistic_transcriptomics_cis_gain  1.30103   neg_log_na_props  -0.000000
# 90       p_gistic_transcriptomics_trans  1.30103   neg_log_na_props   2.022133
# 91  p_gistic_transcriptomics_trans_loss  1.30103   neg_log_na_props   0.912348
# 92  p_gistic_transcriptomics_trans_gain  1.30103   neg_log_na_props   1.099489
#
# [93 rows x 4 columns]
