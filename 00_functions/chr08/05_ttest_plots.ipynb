# %% [markdown]
# # t-test plots

# %%
import cnvutils
import IPython.display

# %%
paths = cnvutils.multi_runner(
    func=cnvutils.make_ttest_counts_plot,
    sources=["cptac", "gistic"],
    levels=["gene"],
    chromosomes_events={
        8: {
            "p": ["loss"],
            "q": ["gain"],
        },
    },
    more_dicts=[
        {
            "name": "tissue_type",
            "vals": ["tumor", "normal"],
        },
        {
            "name": "cis_or_trans",
            "vals": ["cis", "trans"],
        },
        {
            "name": "proteomics_or_transcriptomics",
            "vals": ["transcriptomics", "proteomics"],
        },
    ]
)
# Out:
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'tissue_type': 'tumor', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'tissue_type': 'tumor', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'tissue_type': 'tumor', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# ...

# %%
tumors = [path for path in paths if "_tumor.png" in path]

# %%
normals = [path for path in paths if "_tumor.png" not in path]

# %%
IPython.display.display(*[IPython.display.Image(path) for path in tumors])

# %%
IPython.display.display(*[IPython.display.Image(path) for path in normals])
