# %% [markdown]
# # t-test plots

# %%
import cnvutils
import IPython.display

# %%
paths = cnvutils.multi_runner(
    func=cnvutils.make_ttest_counts_plot,
    sources=["cptac", "gistic"],
    levels=["gene"],
    chromosomes_events={
        8: {
            "p": ["loss"],
            "q": ["gain"],
        },
    },
    more_dicts=[
        {
            "name": "cis_or_trans",
            "vals": ["cis", "trans"],
        },
        {
            "name": "proteomics_or_transcriptomics",
            "vals": ["transcriptomics", "proteomics"],
        },
    ]
)
# Out:
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'cptac', 'level': None, 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# INFO:tornado.access:200 GET / (::1) 7.10ms
# INFO:tornado.access:200 GET / (::1) 7.77ms
# INFO:tornado.access:200 GET / (::1) 10.00ms
# INFO:tornado.access:200 GET / (::1) 7.64ms
# INFO:tornado.access:200 GET / (::1) 9.20ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.32ms
# INFO:tornado.access:200 GET /vega.js (::1) 10.41ms
# INFO:tornado.access:200 GET / (::1) 6.55ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 5.29ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.95ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 0.92ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 3.76ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 10.27ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.09ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 11.21ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 21.43ms
# INFO:tornado.access:200 GET /vega.js (::1) 17.19ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 24.68ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 27.46ms
# INFO:tornado.access:200 GET / (::1) 9.83ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 28.93ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.23ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 16.51ms
# INFO:tornado.access:200 GET / (::1) 24.69ms
# INFO:tornado.access:200 GET /vega.js (::1) 2.59ms
# INFO:tornado.access:200 GET /vega.js (::1) 23.16ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.83ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 33.12ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.27ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 18.28ms
# INFO:tornado.access:200 GET /vega.js (::1) 2.94ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 55.65ms
# INFO:tornado.access:200 GET / (::1) 7.64ms
# INFO:tornado.access:200 GET / (::1) 7.10ms
# INFO:tornado.access:200 GET / (::1) 7.77ms
# INFO:tornado.access:200 GET / (::1) 9.20ms
# INFO:tornado.access:200 GET / (::1) 10.00ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.32ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 3.76ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 5.29ms
# INFO:tornado.access:200 GET /vega.js (::1) 10.41ms
# INFO:tornado.access:200 GET / (::1) 6.55ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 0.92ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 10.27ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.95ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 11.21ms
# INFO:tornado.access:200 GET /vega.js (::1) 17.19ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.09ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 28.93ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 21.43ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 24.68ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 27.46ms
# INFO:tornado.access:200 GET / (::1) 9.83ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.23ms
# INFO:tornado.access:200 GET /vega.js (::1) 2.59ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.83ms
# INFO:tornado.access:200 GET / (::1) 24.69ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 16.51ms
# INFO:tornado.access:200 GET /vega.js (::1) 23.16ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 2.27ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 33.12ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 18.28ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 55.65ms
# INFO:tornado.access:200 GET /vega.js (::1) 2.94ms
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'p', 'gain_or_loss': 'loss', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'cis', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'transcriptomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
#
#
#
# Running make_ttest_counts_plot with {'chromosome': 8, 'arm': 'q', 'gain_or_loss': 'gain', 'cis_or_trans': 'trans', 'proteomics_or_transcriptomics': 'proteomics', 'source': 'gistic', 'level': 'gene', 'data_dir': '/home/caleb/github/PayneLab/pancancerCNV/00_functions/chr08/../data'}...
# INFO:tornado.access:304 GET / (::1) 0.52ms
# INFO:tornado.access:304 GET / (::1) 0.47ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.54ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.69ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.94ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 6.40ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.03ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 22.82ms
# INFO:tornado.access:304 GET / (::1) 0.64ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.71ms
# INFO:tornado.access:304 GET / (::1) 0.59ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 4.49ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 4.44ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.86ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.17ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 7.75ms
# INFO:tornado.access:304 GET / (::1) 0.52ms
# INFO:tornado.access:304 GET / (::1) 0.47ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.54ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.69ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.03ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.94ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 6.40ms
# INFO:tornado.access:304 GET / (::1) 0.64ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 22.82ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.71ms
# INFO:tornado.access:304 GET / (::1) 0.59ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 4.49ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 4.44ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.86ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.17ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 7.75ms
# INFO:tornado.access:304 GET / (::1) 0.47ms
# INFO:tornado.access:304 GET / (::1) 0.43ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.10ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.41ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.48ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.95ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.51ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.69ms
# INFO:tornado.access:304 GET / (::1) 0.39ms
# INFO:tornado.access:304 GET / (::1) 0.50ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.03ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.53ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.81ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.83ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.10ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.77ms
# INFO:tornado.access:304 GET / (::1) 0.47ms
# INFO:tornado.access:304 GET / (::1) 0.43ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.10ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.41ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.48ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.95ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.51ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.69ms
# INFO:tornado.access:304 GET / (::1) 0.39ms
# INFO:tornado.access:304 GET / (::1) 0.50ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.03ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.53ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.81ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.83ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.10ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.77ms

# %%
IPython.display.display(*[IPython.display.Image(path) for path in paths])
