# %% [markdown]
# # t-test plots

# %%
import cnvutils
from IPython.display import Image

CHROMOSOME = 8
PROTEOMICS_OR_TRANSCRIPTOMICS = "proteomics"

# %% [markdown]
# ## 8p loss _cis_ effects

# %%
CIS_OR_TRANS = "cis"

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="p",
    gain_or_loss="loss",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:200 GET / (::1) 10.77ms
# INFO:tornado.access:200 GET / (::1) 10.77ms
# INFO:tornado.access:200 GET /vega.js (::1) 5.94ms
# INFO:tornado.access:200 GET /vega.js (::1) 5.94ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.11ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 6.11ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 8.66ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 8.66ms

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="p",
    gain_or_loss="loss",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.95ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.95ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.37ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.37ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.18ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.18ms

# %% [markdown]
# ## 8p loss _trans_ effects

# %%
CIS_OR_TRANS = "trans"

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="p",
    gain_or_loss="loss",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.53ms
# INFO:tornado.access:304 GET / (::1) 0.53ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.88ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.88ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.33ms

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="p",
    gain_or_loss="loss",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.79ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.79ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.58ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.58ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.11ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.11ms

# %% [markdown]
# ## 8q gain _cis_ effects

# %%
CIS_OR_TRANS = "cis"

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="q",
    gain_or_loss="gain",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.57ms
# INFO:tornado.access:304 GET / (::1) 0.57ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.30ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.30ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.15ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.15ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.96ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 3.96ms

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="q",
    gain_or_loss="gain",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.52ms
# INFO:tornado.access:304 GET / (::1) 0.52ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.24ms
# INFO:tornado.access:304 GET /vega.js (::1) 2.24ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.07ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 2.07ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 4.01ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 4.01ms

# %% [markdown]
# ## 8q gain _trans_ effects

# %%
CIS_OR_TRANS = "trans"

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="q",
    gain_or_loss="gain",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.42ms
# INFO:tornado.access:304 GET / (::1) 0.42ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.76ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.76ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.39ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.39ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.54ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.54ms

# %%
Image(cnvutils.make_ttest_plot(
    chromosome=CHROMOSOME,
    arm="q",
    gain_or_loss="gain",
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET / (::1) 0.44ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.86ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.86ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.53ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.53ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.34ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.34ms
