# %% [markdown]
# # t-test plots

# %%
import cnvutils
from IPython.display import Image

CHROMOSOME = 8
PROTEOMICS_OR_TRANSCRIPTOMICS = "proteomics"

# %% [markdown]
# ## 8p loss _cis_ effects

# %%
ARM = "p"
GAIN_OR_LOSS = "loss"

# %%
CIS_OR_TRANS = "cis"

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:200 GET / (::1) 3.10ms
# INFO:tornado.access:200 GET / (::1) 3.10ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.44ms
# INFO:tornado.access:200 GET /vega.js (::1) 3.44ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 5.16ms
# INFO:tornado.access:200 GET /vega-lite.js (::1) 5.16ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 6.13ms
# INFO:tornado.access:200 GET /vega-embed.js (::1) 6.13ms

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.35ms
# INFO:tornado.access:304 GET / (::1) 0.35ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.36ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.36ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.30ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.30ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.74ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 0.74ms

# %% [markdown]
# ## 8p loss _trans_ effects

# %%
CIS_OR_TRANS = "trans"

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.40ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.40ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.23ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.23ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.18ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.18ms

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.56ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.56ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.40ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.40ms

# %% [markdown]
# ## 8q gain _cis_ effects

# %%
ARM = "q"
GAIN_OR_LOSS = "gain"

# %%
CIS_OR_TRANS = "cis"

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.34ms
# INFO:tornado.access:304 GET / (::1) 0.34ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.33ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.05ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.05ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.96ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.96ms

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.34ms
# INFO:tornado.access:304 GET / (::1) 0.34ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.31ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.31ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.25ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.25ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.01ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.01ms

# %% [markdown]
# ## 8q gain _trans_ effects

# %%
CIS_OR_TRANS = "trans"

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="cptac",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.33ms
# INFO:tornado.access:304 GET / (::1) 0.33ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.50ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.50ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.75ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.75ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.99ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 2.99ms

# %%
Image(cnvutils.make_ttest_counts_plot(
    chromosome=CHROMOSOME,
    arm=ARM,
    gain_or_loss=GAIN_OR_LOSS,
    cis_or_trans=CIS_OR_TRANS,
    proteomics_or_transcriptomics=PROTEOMICS_OR_TRANSCRIPTOMICS,
    source="gistic",
    level="gene",
))
# Out:
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET / (::1) 0.30ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.58ms
# INFO:tornado.access:304 GET /vega.js (::1) 1.58ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.04ms
# INFO:tornado.access:304 GET /vega-lite.js (::1) 1.04ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.61ms
# INFO:tornado.access:304 GET /vega-embed.js (::1) 1.61ms
