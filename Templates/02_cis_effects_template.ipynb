# %% [markdown]
# # Cis Effects Template
#
# * Get a list of genes that occur within the event.
# * Run Pearson correlation test on proteomics
# * Run Pearson correlation test on transcriptomics
# * Create a graph like this:
#
# ![image.png](attachment:image.png)
