# %% [markdown]
# # Find proteins within the event (cis) that are commonly equivalent between samples with and without the event

# %% [markdown]
# ## Setup

# %%
import cnvutils
import pandas as pd
import numpy as np
import os
import altair as alt

# %%
params = cnvutils.load_params(os.path.join("..", "data", "params.json"))
CHROMOSOME = params["CHROMOSOME"]
ARM = params["ARM"]
CIS_OR_TRANS = "cis"

equiv_results_file = os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_equiv.tsv")

# %%
equiv_results = pd.\
read_csv(equiv_results_file, sep="\t").\
rename(columns={"Name": "protein"})

# %%
equiv_results
# Out:
#     cancer_type   protein                                        Database_ID  \
# 0          brca  ADAMDEC1                         NP_055294.1|NP_001138744.1
# 1          brca    AGPAT5                                        NP_060831.2
# 2          brca    ANGPT2          NP_001138.1|NP_001112360.1|NP_001112359.1
# 3          brca  ARHGEF10          NP_001295082.1|NP_055444.2|NP_001295081.1
# 4          brca     ASAH1                            NP_004306.3|NP_808592.2
# 5          brca  ATP6V1B2                                        NP_001684.2
# 6          brca      BIN3                                        NP_061158.1
# 7          brca       BLK                         NP_001706.2|NP_001317394.1
# 8          brca      BMP1                            NP_006120.1|NP_001190.1
# 9          brca    BNIP3L                         NP_004322.1|NP_001317420.1
# 10         brca     CDCA2          NP_689775.2|NP_001304835.1|NP_001304836.1
# 11         brca     CHMP7                         NP_689485.1|NP_001304828.1
# 12         brca       CLU                                        NP_001822.3
# 13         brca     CNOT7  NP_001309022.1|NP_001309020.1|NP_001309023.1|N...
# 14         brca      CTSB                         NP_001899.1|NP_001304166.1
# 15         brca     DCTN6                                        NP_006562.1
# 16         brca     DEFA3             NP_005208.1|NP_001289194.1|NP_004075.1
# 17         brca     DEFA4                                        NP_001916.1
# 18         brca      DLC1  NP_872584.2|NP_001303597.1|NP_001157743.1|NP_0...
# 19         brca     DOCK5                                        NP_079216.4
# 20         brca      DOK2                         NP_003965.2|NP_001304729.1
# 21         brca     DUSP4                NP_001385.1|NP_476499.1|NP_004409.1
# 22         brca      ERI1                                        NP_699163.2
# 23         brca    ERICH1                         NP_997215.1|NP_001290029.1
# 24         brca  FAM160B2                                        NP_073586.5
# 25         brca     FDFT1  NP_001274671.1|NP_001274679.1|NP_001274673.1|N...
# 26         brca       GSR  NP_000628.2|NP_001182031.1|NP_001182032.1|NP_0...
# 27         brca    GTF2E2                                        NP_002086.1
# 28         brca    HMBOX1  NP_001311312.1|NP_001317427.1|NP_001311314.1|N...
# 29         brca   KBTBD11                                        NP_055682.1
# ..          ...       ...                                                ...
# 370     ovarian      MSR1                                          NP_619729
# 371     ovarian      MSRA                                          NP_036463
# 372     ovarian     MTMR9                                          NP_056273
# 373     ovarian     MYOM2                                          NP_003961
# 374     ovarian      NAT1                                       NP_001153651
# 375     ovarian      NEFL                                          NP_006149
# 376     ovarian     NEIL2                                          NP_659480
# 377     ovarian    NUDT18                                          NP_079091
# 378     ovarian       PBK                                          NP_060962
# 379     ovarian    PDGFRL                                          NP_006198
# 380     ovarian    PDLIM2                                          NP_067643
# 381     ovarian     PINX1                                          NP_060354
# 382     ovarian    POLR3D                                          NP_001713
# 383     ovarian    PPP2CB                                       NP_001009552
# 384     ovarian   PPP2R2A                                       NP_001171062
# 385     ovarian    PPP3CC                                       NP_001230904
# 386     ovarian      PSD3                                          NP_056125
# 387     ovarian    R3HCC1                                       NP_001129580
# 388     ovarian     RBPMS                                       NP_001008710
# 389     ovarian     SARAF                                          NP_057211
# 390     ovarian    SH2D4A                                          NP_071354
# 391     ovarian  SLC39A14                                       NP_001121903
# 392     ovarian    SLC7A2                                       NP_001008539
# 393     ovarian    SORBS3                                          NP_005766
# 394     ovarian      TDRP                                       NP_001243042
# 395     ovarian      TNKS                                          NP_003738
# 396     ovarian      TTI2                                       NP_001095871
# 397     ovarian    VPS37A                                          NP_689628
# 398     ovarian       WRN                                          NP_000544
# 399     ovarian      XPO7                                          NP_055839
#
#         adj_p
# 0    0.016401
# 1    0.690930
# 2    0.067187
# 3    0.325628
# 4    0.204879
# 5    0.982561
# 6    0.236663
# 7    0.217724
# 8    0.011296
# 9    0.297309
# 10   0.160600
# 11   0.999996
# 12   0.031069
# 13   0.585772
# 14   0.051327
# 15   0.023440
# 16   0.011296
# 17   0.027803
# 18   0.034663
# 19   0.503490
# 20   0.013743
# 21   0.114284
# 22   0.982561
# 23   0.493481
# 24   0.929325
# 25   0.204879
# 26   0.037954
# 27   0.276745
# 28   0.503490
# 29   0.013743
# ..        ...
# 370  0.017307
# 371  0.530443
# 372  0.261246
# 373  0.013935
# 374  0.656544
# 375  0.311543
# 376  0.018637
# 377  0.032215
# 378  0.228992
# 379  0.018637
# 380  0.047510
# 381  0.431831
# 382  0.055576
# 383  0.730207
# 384  0.832120
# 385  0.013935
# 386  0.403050
# 387  0.286447
# 388  0.165527
# 389  0.324837
# 390  0.286447
# 391  0.462708
# 392  0.073275
# 393  0.181047
# 394  0.096592
# 395  0.024695
# 396  0.084970
# 397  0.540740
# 398  0.034704
# 399  0.979361
#
# [400 rows x 4 columns]

# %% [markdown]
# ## Select the equivalent proteins, and take a detour to make some plots

# %%
prots = equiv_results[equiv_results["adj_p"] <= 0.05].reset_index(drop=True)
prots_cts = prots.groupby("cancer_type").count()[["protein"]]

fail_prots = equiv_results[equiv_results["adj_p"] > 0.05].reset_index(drop=True)
fail_cts = fail_prots.groupby("cancer_type").count()[["protein"]]

prots_cts.insert(0, "count_type", "Equivalent")
fail_cts.insert(0, "count_type", "Not equivalent")

counts = prots_cts.append(fail_cts).sort_index().reset_index(drop=False)

alt.Chart(counts).mark_bar().encode(
    x=alt.X(
        "count_type",
        axis=alt.Axis(
            title=None,
            labels=False
        ),
        sort=["Equivalent"]
    ),
    y=alt.Y(
        "protein",
        axis=alt.Axis(
            title="Number of proteins"
        )
    ),
    color=alt.Color(
        "count_type",
        title=None,
        sort=["Equivalent"],
        scale=alt.Scale(
            domain=["Equivalent", "Not equivalent"],
            range=["#2d3da4", "#d1d1d1"]
        )
    )
).facet(
    column=alt.Column(
        "cancer_type",
        title=None
    )
).properties(
    title="Chr 8p cis equivalence"
).configure_title(
    anchor="middle"
)
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ## Find how many cancers each protein was different in

# %%
prots_summary = prots.groupby("protein").agg(**{
    "cancers": ("cancer_type", lambda x: x.sort_values().drop_duplicates(keep="first").tolist())
})

prots_summary = prots_summary.\
assign(
    num_cancers=prots_summary["cancers"].apply(len),
    tmp_sort=prots_summary["cancers"].apply(lambda x: "".join(x))
).\
sort_values(by=["num_cancers", "tmp_sort"], ascending=[False, True]).\
drop(columns="tmp_sort")

prots_summary
# Out:
#                                             cancers  num_cancers
# protein
# MSR1      [brca, colon, hnscc, lscc, luad, ovarian]            6
# CLU                      [brca, colon, hnscc, lscc]            4
# DEFA4                    [brca, colon, hnscc, lscc]            4
# TTI2                     [brca, colon, hnscc, lscc]            4
# POLR3D                    [brca, colon, lscc, luad]            4
# PDLIM2                 [brca, colon, lscc, ovarian]            4
# ADAMDEC1               [brca, hnscc, lscc, ovarian]            4
# LOXL2                           [brca, colon, lscc]            3
# DOK2                         [brca, colon, ovarian]            3
# LPL                             [brca, hnscc, lscc]            3
# MFHAS1                          [brca, hnscc, lscc]            3
# LZTS1                        [brca, hnscc, ovarian]            3
# MYOM2                        [brca, hnscc, ovarian]            3
# DLC1                             [brca, lscc, luad]            3
# KBTBD11                       [brca, lscc, ovarian]            3
# KCTD9                        [hnscc, lscc, ovarian]            3
# BMP1                                   [brca, lscc]            2
# DEFA3                                  [brca, lscc]            2
# GSR                                    [brca, lscc]            2
# NEFL                                   [brca, lscc]            2
# PEBP4                                  [brca, lscc]            2
# DCTN6                               [brca, ovarian]            2
# PDGFRL                              [brca, ovarian]            2
# SORBS3                                [colon, lscc]            2
# ANGPT2                                [hnscc, lscc]            2
# BIN3                                  [hnscc, lscc]            2
# BNIP3L                                [hnscc, lscc]            2
# MAK16                                 [hnscc, lscc]            2
# PSD3                                  [hnscc, lscc]            2
# NUDT18                             [hnscc, ovarian]            2
# CDCA2                               [lscc, ovarian]            2
# TNKS                                [lscc, ovarian]            2
# KCNU1                                        [brca]            1
# RBPMS                                        [brca]            1
# STMN4                                        [brca]            1
# TDRP                                         [brca]            1
# ARHGEF10                                    [colon]            1
# MTMR9                                       [colon]            1
# CTSB                                        [hnscc]            1
# PNMA2                                       [hnscc]            1
# SLC7A2                                      [hnscc]            1
# ASAH1                                        [lscc]            1
# PBK                                          [lscc]            1
# PINX1                                        [lscc]            1
# PPP2CB                                       [lscc]            1
# STC1                                         [lscc]            1
# PURG                                         [luad]            1
# BLK                                       [ovarian]            1
# CNOT7                                     [ovarian]            1
# NEIL2                                     [ovarian]            1
# PPP3CC                                    [ovarian]            1
# WRN                                       [ovarian]            1

# %% [markdown]
# ## Check that there isn't overlap between proteins found as different and proteins found as equivalent
#
# If there is overlap, we probably were too lenient in our bounds for the TOST test.

# %%
diff_summary_path = os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_common_diff.tsv")
df = pd.read_csv(diff_summary_path, sep="\t")
df = df.assign(cancers=df["cancers"].apply(lambda x: x.split("_")))

shared = df[df["protein"].isin(prots_summary.index)]
shared = shared.merge(
    right=prots_summary.reset_index(drop=False),
    on="protein",
    how="left", 
    suffixes=["_diff", "_equiv"],
)

ints = []
cts = []

for prot in shared["protein"]:
    diff_cancers = set(shared.loc[shared["protein"] == prot, "cancers_diff"].iloc[0])
    equiv_cancers = set(shared.loc[shared["protein"] == prot, "cancers_equiv"].iloc[0])
    
    intersection = diff_cancers.intersection(equiv_cancers)
    
    ints.append(intersection)
    cts.append(len(intersection))
    
shared = shared.assign(
    intersection=ints,
    intersection_size=cts
)

shared.sort_values(by="intersection_size", ascending=False)
# Out:
#      protein                        cancers_diff  mean_simp_change  \
# 0      MTMR9  [brca, hnscc, lscc, luad, ovarian]              -1.0
# 16   KBTBD11                       [hnscc, luad]              -1.0
# 29     PNMA2                              [luad]              -1.0
# 28       PBK                              [luad]              -1.0
# 27       LPL                              [luad]              -1.0
# 26     KCTD9                              [luad]              -1.0
# 25     DEFA4                              [luad]              -1.0
# 24       BLK                              [luad]              -1.0
# 23      TDRP                             [hnscc]              -1.0
# 22    SORBS3                             [hnscc]              -1.0
# 21    PDLIM2                             [hnscc]              -1.0
# 20     MAK16                             [colon]              -1.0
# 19    SLC7A2                              [brca]              -1.0
# 18     RBPMS                        [lscc, luad]              -1.0
# 17      BMP1                    [hnscc, ovarian]               0.0
# 15      DOK2                       [hnscc, lscc]              -1.0
# 1      CNOT7           [brca, hnscc, lscc, luad]              -1.0
# 14     ASAH1                    [colon, ovarian]              -1.0
# 13      PSD3                     [brca, ovarian]              -1.0
# 12    BNIP3L                     [brca, ovarian]              -1.0
# 11    PPP3CC                 [hnscc, lscc, luad]              -1.0
# 10       GSR              [colon, luad, ovarian]              -1.0
# 9      DCTN6                 [colon, lscc, luad]              -1.0
# 8     NUDT18                  [brca, lscc, luad]              -1.0
# 7       CTSB        [colon, lscc, luad, ovarian]              -1.0
# 6     PPP2CB       [colon, hnscc, luad, ovarian]              -1.0
# 5      PINX1       [colon, hnscc, luad, ovarian]              -1.0
# 4   ARHGEF10        [brca, hnscc, luad, ovarian]              -1.0
# 3        WRN           [brca, hnscc, lscc, luad]              -1.0
# 2      NEIL2           [brca, hnscc, lscc, luad]              -1.0
# 30      NEFL                           [ovarian]              -1.0
#
#     num_cancers_diff                 cancers_equiv  num_cancers_equiv  \
# 0                  5                       [colon]                  1
# 16                 2         [brca, lscc, ovarian]                  3
# 29                 1                       [hnscc]                  1
# 28                 1                        [lscc]                  1
# 27                 1           [brca, hnscc, lscc]                  3
# 26                 1        [hnscc, lscc, ovarian]                  3
# 25                 1    [brca, colon, hnscc, lscc]                  4
# 24                 1                     [ovarian]                  1
# 23                 1                        [brca]                  1
# 22                 1                 [colon, lscc]                  2
# 21                 1  [brca, colon, lscc, ovarian]                  4
# 20                 1                 [hnscc, lscc]                  2
# 19                 1                       [hnscc]                  1
# 18                 2                        [brca]                  1
# 17                 2                  [brca, lscc]                  2
# 15                 2        [brca, colon, ovarian]                  3
# 1                  4                     [ovarian]                  1
# 14                 2                        [lscc]                  1
# 13                 2                 [hnscc, lscc]                  2
# 12                 2                 [hnscc, lscc]                  2
# 11                 3                     [ovarian]                  1
# 10                 3                  [brca, lscc]                  2
# 9                  3               [brca, ovarian]                  2
# 8                  3              [hnscc, ovarian]                  2
# 7                  4                       [hnscc]                  1
# 6                  4                        [lscc]                  1
# 5                  4                        [lscc]                  1
# 4                  4                       [colon]                  1
# 3                  4                     [ovarian]                  1
# 2                  4                     [ovarian]                  1
# 30                 1                  [brca, lscc]                  2
#
#    intersection  intersection_size
# 0            {}                  0
# 16           {}                  0
# 29           {}                  0
# 28           {}                  0
# 27           {}                  0
# 26           {}                  0
# 25           {}                  0
# 24           {}                  0
# 23           {}                  0
# 22           {}                  0
# 21           {}                  0
# 20           {}                  0
# 19           {}                  0
# 18           {}                  0
# 17           {}                  0
# 15           {}                  0
# 1            {}                  0
# 14           {}                  0
# 13           {}                  0
# 12           {}                  0
# 11           {}                  0
# 10           {}                  0
# 9            {}                  0
# 8            {}                  0
# 7            {}                  0
# 6            {}                  0
# 5            {}                  0
# 4            {}                  0
# 3            {}                  0
# 2            {}                  0
# 30           {}                  0

# %% [markdown]
# ## Out of curiousity, look at the ttest pvalues for difference, for the equivalent proteins

# %%
ttest_diff_res_path = os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_ttest.tsv")

ttres = pd.read_csv(ttest_diff_res_path, sep="\t")

# Get the difference p values for all proteins that passed
diffs = pd.DataFrame()
for prot_idx in prots.index:
    
    prot = prots.loc[prot_idx, "protein"]
    cancer_type = prots.loc[prot_idx, "cancer_type"]
    
    diffs = diffs.append(ttres[
        (ttres["protein"] == prot) &
        (ttres["cancer_type"] == cancer_type)
    ])

# Plot the distribution of the difference p values for the equivalent proteins
alt.Chart(diffs).mark_bar().encode(
    x=alt.X(
        "adj_p",
        bin=alt.Bin(step=0.05),
        scale=alt.Scale(
            domain=[0, 1]
        )
    ),
    y=alt.Y(
        "count()"
    )
).properties(
    title="Distribution of difference p values for equivalent proteins"
)
# Out:
# alt.Chart(...)

# %%
# Plot the distribution of all the difference p values
alt.Chart(ttres).mark_bar().encode(
    x=alt.X(
        "adj_p",
        bin=alt.Bin(step=0.05),
        scale=alt.Scale(
            domain=[0, 1]
        )
    ),
    y=alt.Y(
        "count()"
    )
).properties(
    title="Distribution of difference p values for all proteins"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Save results

# %%
prots_summary = prots_summary.assign(
    cancers=prots_summary["cancers"].apply(lambda x: "_".join(x))
)

output_file = os.path.join("..", "data", f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}_common_equiv.tsv")
prots_summary.to_csv(output_file, sep="\t")
