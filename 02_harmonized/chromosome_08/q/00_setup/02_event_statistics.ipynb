# %% [markdown]
# # Calculate event statistics
#
# Such as what proportion of patients in each cancer type have the event.

# %%
import cnvutils
import os
import pandas as pd

# %%
# Load parameters
gen_params = cnvutils.load_params(os.path.join("..", "..", "..", "data", "gen_params.json"))
PANCAN = gen_params["PANCAN"]

chr_params = cnvutils.load_params(os.path.join("..", "..", "data", "chr_params.json"))
CHROMOSOME = chr_params["CHROMOSOME"]

arm_params = cnvutils.load_params(os.path.join("..", "data", "arm_params.json"))
ARM = arm_params["ARM"]
CANCER_TYPES = arm_params["ARM_CANCER_TYPES"]

# %%
# Get the total number of samples in each cancer type. We saved this earlier.
total_samples = pd.read_csv(os.path.join(
    "..", 
    "..",
    "data", 
    f"chr{CHROMOSOME:0>2}_cnv_counts_{'harmonized' if PANCAN else 'AWG'}.tsv"
), sep='\t', index_col=0)[["cancer", "cancer_type_total_patients"]].\
drop_duplicates(keep="first").\
reset_index(drop=True)

total_samples
# Out:
#         cancer  cancer_type_total_patients
# 0         brca                         122
# 1        ccrcc                         110
# 2        colon                         106
# 3  endometrial                          95
# 4          gbm                          99
# 5        hnscc                         110
# 6         lscc                         110
# 7         luad                         110
# 8      ovarian                          82

# %%
# Load arm event table
has_event = pd.DataFrame()
for cancer_type in CANCER_TYPES:
    
    cancer_type_event = pd.read_csv(os.path.join(
        "..", 
        "data", 
        f"chr{CHROMOSOME}_{cancer_type}_has_event_{'harmonized' if PANCAN else 'AWG'}.tsv"
    ), sep='\t', index_col=0).\
    assign(cancer_type=cancer_type)
    
    has_event = has_event.append(cancer_type_event)
    
has_event
# Out:
#          event cancer_type
# 01BR001   True        brca
# 01BR008  False        brca
# 01BR009  False        brca
# 01BR010  False        brca
# 01BR015   True        brca
# 01BR017  False        brca
# 01BR018  False        brca
# 01BR020   True        brca
# 01BR023   True        brca
# 01BR025  False        brca
# 01BR026   True        brca
# 01BR027   True        brca
# 01BR030   True        brca
# 01BR031  False        brca
# 01BR032  False        brca
# 01BR033  False        brca
# 01BR040   True        brca
# 01BR042  False        brca
# 01BR043  False        brca
# 03BR002  False        brca
# 03BR004   True        brca
# 03BR005  False        brca
# 03BR006   True        brca
# 03BR010  False        brca
# 03BR011  False        brca
# 03BR013  False        brca
# 05BR001  False        brca
# 05BR003  False        brca
# 05BR004  False        brca
# 05BR005   True        brca
# ...        ...         ...
# 04OV063  False     ovarian
# 11OV002   True     ovarian
# 13OV003  False     ovarian
# 14OV011   True     ovarian
# 15OV001  False     ovarian
# 17OV001  False     ovarian
# 17OV002  False     ovarian
# 17OV010  False     ovarian
# 17OV011  False     ovarian
# 17OV013  False     ovarian
# 17OV014  False     ovarian
# 17OV015  False     ovarian
# 17OV017  False     ovarian
# 17OV018  False     ovarian
# 17OV025  False     ovarian
# 17OV027  False     ovarian
# 17OV028  False     ovarian
# 17OV029   True     ovarian
# 17OV030   True     ovarian
# 17OV033   True     ovarian
# 17OV036   True     ovarian
# 17OV039   True     ovarian
# 17OV040  False     ovarian
# 18OV001  False     ovarian
# 20OV005   True     ovarian
# 26OV002   True     ovarian
# 26OV008  False     ovarian
# 26OV009  False     ovarian
# 26OV011  False     ovarian
# 26OV013  False     ovarian
#
# [640 rows x 2 columns]

# %%
# Get event counts
event_counts = has_event.\
groupby("cancer_type")["event"].\
value_counts().\
rename("count").\
reset_index().\
merge(
    total_samples,
    left_on="cancer_type",
    right_on="cancer"
).\
drop(columns="cancer")

event_counts.insert(
    3,
    "proportion",
    (event_counts["count"] / event_counts["cancer_type_total_patients"]).round(2)
)

event_counts
# Out:
#    cancer_type  event  count  proportion  cancer_type_total_patients
# 0         brca  False     86        0.70                         122
# 1         brca   True     36        0.30                         122
# 2        colon  False     68        0.64                         106
# 3        colon   True     38        0.36                         106
# 4        hnscc  False     68        0.62                         110
# 5        hnscc   True     42        0.38                         110
# 6         lscc  False     85        0.77                         110
# 7         lscc   True     25        0.23                         110
# 8         luad  False     81        0.74                         110
# 9         luad   True     29        0.26                         110
# 10     ovarian  False     56        0.68                          82
# 11     ovarian   True     26        0.32                          82

# %%
true_counts = event_counts[event_counts["event"]]
true_counts
# Out:
#    cancer_type  event  count  proportion  cancer_type_total_patients
# 1         brca   True     36        0.30                         122
# 3        colon   True     38        0.36                         106
# 5        hnscc   True     42        0.38                         110
# 7         lscc   True     25        0.23                         110
# 9         luad   True     29        0.26                         110
# 11     ovarian   True     26        0.32                          82

# %%
false_counts = event_counts[~event_counts["event"]]
false_counts
# Out:
#    cancer_type  event  count  proportion  cancer_type_total_patients
# 0         brca  False     86        0.70                         122
# 2        colon  False     68        0.64                         106
# 4        hnscc  False     68        0.62                         110
# 6         lscc  False     85        0.77                         110
# 8         luad  False     81        0.74                         110
# 10     ovarian  False     56        0.68                          82
