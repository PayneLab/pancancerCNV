# %%
import functions

# %%
functions.get_counts_table('luad', dropna=True)
# Out:
#          gain  neutral  loss  chromo     location
# Name
# A1BG       10       80    19    19.0   58349335.0
# A1CF        2       92    15    10.0   50842542.0
# A2M         9       79    21    12.0    9091946.5
# A2ML1      10       77    22    12.0    8854811.0
# A3GALT2     9       92     8     1.0   33313932.0
# ...       ...      ...   ...     ...          ...
# ZXDC       12       85    12     3.0  126456746.0
# ZYG11A      6       91    12     1.0   52868754.5
# ZYG11B      6       91    12     1.0   52776894.5
# ZYX        16       89     4     7.0  143386203.0
# ZZEF1       4       64    41    17.0    4073737.5
#
# [17704 rows x 5 columns]

# %%
functions.make_cnv_visual(['brca', 'ovarian', 'luad', 'lscc', 'gbm', 'colon', 'endo', 'hnscc', 'ccrcc'], 8)
# Out:
#                            gain  neutral  loss  chromo     location
# Name   Database_ID
# A1BG   ENSG00000121410.7     22       85    15    19.0   58349335.0
# A1CF   ENSG00000148584.9     16       91    15    10.0   50842542.0
# A2M    ENSG00000175899.10    19       88    15    12.0    9091946.5
# A2ML1  ENSG00000166535.15    18       89    15    12.0    8854811.0
# A2MP1  ENSG00000256069.3     20       89    13    12.0    9252175.0
# ...                         ...      ...   ...     ...          ...
# ZXDC   ENSG00000070476.10    25       89     8     3.0  126456746.0
# ZYG11A ENSG00000203995.5     14       80    28     1.0   52868754.5
# ZYG11B ENSG00000162378.8     14       80    28     1.0   52776894.5
# ZYX    ENSG00000159840.11    40       72    10     7.0  143386203.0
# ZZEF1  ENSG00000074755.10     8       55    59    17.0    4073737.5
#
# [21365 rows x 5 columns]
#                             gain  neutral  loss  chromo     location
# Name    Database_ID
# ...
