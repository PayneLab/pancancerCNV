# %% [markdown]
# # Cis Effects 8q

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cptac
from scipy import stats
from cnvutils import *
import statsmodels.stats.multitest
import cptac.utils

# %% [markdown]
# ## Stuff to fill out

# %%
# Enter the Chromosome and arm you are looking at. 
CHROMOSOME = '8'
ARM = 'q'
EVENT_START = 52110839
EVENT_END = 145052465

# %%
cancer_types = {
    # Put here all the types of cancer that you want to look at. 
    'luad': cptac.Luad(),
    'hnscc': cptac.Hnscc(),
    'ovarian': cptac.Ovarian(),
    'colon': cptac.Colon(),
    'brca': cptac.Brca(),
    'lscc': cptac.Lscc()
}
# Out:
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 8)

# %% [markdown]
# ## Load all the data

# %%
proteomics = dict()
cnv = dict()
transcriptomics = dict()
for cancer_type in cancer_types:
    proteomics[cancer_type] = cancer_types[cancer_type].get_proteomics()
    cnv[cancer_type] = cancer_types[cancer_type].get_CNV()
    transcriptomics[cancer_type] = cancer_types[cancer_type].get_transcriptomics()

# %%
locations = get_gene_locations()

# %%
# Get just the genes that are in our event
subset_event = locations[(locations.chromosome == CHROMOSOME) & (locations.arm == ARM) & (locations.start_bp >= EVENT_START) & (locations.end_bp <= EVENT_END)]
genes = set(subset_event.index.get_level_values('Name'))

# %% [markdown]
# ## Run Pearson Tests

# %%
def run_pearsons(protein, cnv_df, omics):
    try:
        if protein in cnv_df.columns.get_level_values('Name'):
            cnv_data = cnv_df.loc[:,cnv_df.columns.get_level_values('Name')==protein]
            cnv_column_name = cnv_data.columns.tolist()[0]
        else:
            return (np.nan, np.nan)
        omics_data = omics[protein]
        if isinstance(omics_data, pd.DataFrame):
            omics_data = omics.iloc[:,0]
        omics_data.name = 'omics'
        df = pd.concat([cnv_data, omics_data], axis=1)
        df.dropna(inplace=True)
        if len(df) < 3:
            return (np.nan,np.nan)
        return stats.pearsonr(df[cnv_column_name], df['omics'])
    except Exception as e:
        print(e)

# %% [markdown]
# ### Proteomics

# %%
proteomics_results = None
for cancer_type in proteomics.keys():
    try:
        # We will use the index from the proteomics table. 
        proteomics_table = proteomics[cancer_type].copy()
        proteomics_table = proteomics_table.loc[:, proteomics_table.columns.get_level_values('Name').isin(genes)]
        if isinstance(proteomics_table.columns, pd.MultiIndex):
            proteomics_table = proteomics_table.droplevel('Database_ID', axis=1)
        pvalues = list()
        rvalues = list()
        index = proteomics_table.columns.get_level_values('Name').tolist()
        for protein in index:
            r, p = run_pearsons(protein, cnv[cancer_type], proteomics_table)
            pvalues.append(p)
            rvalues.append(r)
        # Correct for multiple tests
        pvalues = np.array(pvalues)
        mask = np.isfinite(pvalues)
        pval_corrected = np.empty(len(pvalues))
        pval_corrected.fill(np.nan)
        pval_corrected[mask] = statsmodels.stats.multitest.multipletests(pvals=list(pvalues[mask]), alpha=0.05, method='fdr_bh')[1]
        temp = pd.DataFrame(data={f'{cancer_type}_pvalue_proteomics': pval_corrected, f'{cancer_type}_rvalue_proteomics': rvalues}, index=index)
        temp.index.name = 'Name'
        if proteomics_results is not None:
            proteomics_results = proteomics_results.join(temp, how='outer')
        else:
            proteomics_results = temp
    except Exception as e:
        print(e)

# %%
proteomics_results
# Out:
#           luad_pvalue_proteomics  luad_rvalue_proteomics  \
# Name
# ADCK5               1.071355e-06                0.529184
# ADCY8               2.825241e-01               -0.199202
# ADHFE1              5.591530e-01               -0.094753
# AGO2                1.464466e-09                0.561370
# ANGPT1              1.107765e-02               -0.272637
# ANKRD46             5.328596e-02                0.242783
# ANXA13              5.996005e-01               -0.060488
# ARFGEF1             6.728161e-14                0.664117
# ARHGAP39            2.825241e-01                0.136380
# ARMC1               2.453643e-09                0.554888
# ASPH                1.570513e-02                0.247077
# ASPH                1.570513e-02                0.247077
# ASPH                1.570513e-02                0.247077
# ATAD2               6.665587e-09                0.542292
# ATP6V0D2            1.077203e-01               -0.169347
# ATP6V1C1            1.003746e-03                0.327923
# ATP6V1H             4.214391e-01                0.090322
# BOP1                4.222318e-02                0.210091
# C8orf37             1.299512e-02                0.259693
# C8orf76             8.433904e-01                0.031886
# C8orf82             5.360346e-08                0.512898
# C8orf88                      NaN                     NaN
# CA1                 1.358933e-02                0.289941
# CA1                 1.358933e-02                0.289941
# CA1                 1.358933e-02                0.289941
# CA1                 1.358933e-02                0.289941
# CA13                1.783163e-03                0.313047
# CA2                 1.150484e-02                0.296699
# CA2                 1.150484e-02                0.296699
# CA3                 8.227439e-01               -0.027242
# ...                          ...                     ...
# UBXN2B              3.772524e-08                0.518250
# UQCRB               9.149549e-02                0.176899
# UTP23               9.345920e-10                0.568097
# VCPIP1                       NaN                     NaN
# VIRMA                        NaN                     NaN
# VPS13B              1.937509e-05                0.414224
# VPS28                        NaN                     NaN
# WASHC5              3.781581e-02                0.214586
# WDYHV1              8.859455e-02                0.292710
# WWP1                4.785900e-02                0.204242
# YTHDF3              4.246838e-18                0.733931
# YWHAZ               6.256947e-20                0.758175
# ZBTB10              1.045039e-10                0.602575
# ZC2HC1A             5.945760e-03                0.321342
# ZC2HC1A             5.945760e-03                0.321342
# ZC2HC1A             5.945760e-03                0.321342
# ZC2HC1A             5.945760e-03                0.321342
# ZC3H3               5.708529e-01               -0.070522
# ZFAND1              3.548200e-08                0.519309
# ZFHX4               6.962112e-01                0.050454
# ZFP41                        NaN                     NaN
# ZHX1                7.586714e-07                0.480244
# ZHX2                1.806322e-05                0.415881
# ZNF16                        NaN                     NaN
# ZNF250                       NaN                     NaN
# ZNF251              5.731755e-01                0.075016
# ZNF34                        NaN                     NaN
# ZNF623                       NaN                     NaN
# ZNF7                         NaN                     NaN
# ZNF706              1.077203e-01                0.173539
#
#           hnscc_pvalue_proteomics  hnscc_rvalue_proteomics  \
# Name
# ADCK5                4.025665e-02                 0.255199
# ADCY8                         NaN                      NaN
# ADHFE1               8.827123e-01                -0.024365
# AGO2                 6.060852e-09                 0.561954
# ANGPT1                        NaN                      NaN
# ANKRD46              8.958845e-02                 0.353214
# ANXA13               4.717983e-01                 0.128624
# ARFGEF1              2.335016e-09                 0.577159
# ARHGAP39             9.788467e-01                -0.010658
# ARMC1                6.725564e-04                 0.357050
# ASPH                 1.425976e-05                 0.439936
# ASPH                 1.425976e-05                 0.439936
# ASPH                 1.425976e-05                 0.439936
# ATAD2                5.970395e-07                 0.493030
# ATP6V0D2             8.880074e-01                 0.089318
# ATP6V1C1             3.803748e-05                 0.420475
# ATP6V1H              4.882596e-03                 0.298945
# BOP1                 6.668027e-04                 0.357622
# C8orf37              6.043136e-01                 0.086958
# C8orf76              2.138006e-01                -0.382520
# C8orf82              3.557727e-03                 0.310427
# C8orf88              5.446921e-01                 0.424236
# CA1                  9.596605e-01                 0.007847
# CA1                  9.596605e-01                 0.007847
# CA1                  9.596605e-01                 0.007847
# CA1                  9.596605e-01                 0.007847
# CA13                 9.044235e-01                 0.018183
# CA2                  3.317224e-01                 0.119489
# CA2                  3.317224e-01                 0.119489
# CA3                  2.191651e-01                -0.145865
# ...                           ...                      ...
# UBXN2B               4.596467e-03                 0.302113
# UQCRB                7.966895e-01                -0.039143
# UTP23                5.834197e-06                 0.455701
# VCPIP1               7.738387e-09                 0.557527
# VIRMA                8.282289e-01                 0.031580
# VPS13B               1.014856e-02                 0.275508
# VPS28                1.009222e-01                 0.186685
# WASHC5               7.273103e-01                 0.051386
# WDYHV1               4.025665e-02                 0.302263
# WWP1                 9.386509e-01                 0.013546
# YTHDF3               3.457083e-18                 0.750155
# YWHAZ                8.905194e-09                 0.554348
# ZBTB10               9.101386e-01                 0.043030
# ZC2HC1A              8.184638e-01                 0.034025
# ZC2HC1A              8.184638e-01                 0.034025
# ZC2HC1A              8.184638e-01                 0.034025
# ZC2HC1A              8.184638e-01                 0.034025
# ZC3H3                2.350062e-01                 0.152503
# ZFAND1               7.327914e-02                 0.201677
# ZFHX4                         NaN                      NaN
# ZFP41                8.802390e-01                 0.145576
# ZHX1                 1.370969e-01                 0.170440
# ZHX2                 7.921279e-04                 0.350881
# ZNF16                         NaN                      NaN
# ZNF250               7.167297e-01                -0.286790
# ZNF251                        NaN                      NaN
# ZNF34                         NaN                      NaN
# ZNF623                        NaN                      NaN
# ZNF7                 3.020032e-02                 0.419626
# ZNF706               3.353363e-03                 0.312277
#
#           ovarian_pvalue_proteomics  ovarian_rvalue_proteomics  \
# Name
# ADCK5                           NaN                        NaN
# ADCY8                           NaN                        NaN
# ADHFE1                 1.310936e-01                   0.208438
# AGO2                   7.274694e-06                   0.506962
# ANGPT1                          NaN                        NaN
# ANKRD46                2.371684e-01                   0.205632
# ANXA13                 4.243211e-01                  -0.105472
# ARFGEF1                6.427898e-12                   0.703011
# ARHGAP39                        NaN                        NaN
# ARMC1                  4.914812e-04                   0.404516
# ASPH                   1.006683e-02                   0.307809
# ASPH                   1.006683e-02                   0.307809
# ASPH                   1.006683e-02                   0.307809
# ATAD2                  2.301674e-04                   0.424062
# ATP6V0D2                        NaN                        NaN
# ATP6V1C1               5.884772e-10                   0.655231
# ATP6V1H                9.370194e-03                   0.311541
# BOP1                   8.209227e-02                   0.217419
# C8orf37                5.306393e-01                   0.097020
# C8orf76                         NaN                        NaN
# C8orf82                1.507510e-08                   0.612084
# C8orf88                         NaN                        NaN
# CA1                    6.440456e-01                  -0.061306
# CA1                    6.440456e-01                  -0.061306
# CA1                    6.440456e-01                  -0.061306
# CA1                    6.440456e-01                  -0.061306
# CA13                   1.875615e-02                   0.284918
# CA2                    8.669868e-01                  -0.023255
# CA2                    8.669868e-01                  -0.023255
# CA3                    5.096005e-01                   0.089113
# ...                             ...                        ...
# UBXN2B                 2.902674e-01                   0.140402
# UQCRB                  3.283134e-01                   0.128333
# UTP23                  3.509901e-04                   0.413072
# VCPIP1                 7.399856e-15                   0.771234
# VIRMA                           NaN                        NaN
# VPS13B                 2.870333e-01                   0.141998
# VPS28                  3.255704e-02                   0.261141
# WASHC5                          NaN                        NaN
# WDYHV1                 2.632270e-02                   0.363176
# WWP1                            NaN                        NaN
# YTHDF3                          NaN                        NaN
# YWHAZ                  1.315411e-12                   0.720828
# ZBTB10                 4.646611e-08                   0.592807
# ZC2HC1A                5.430876e-04                   0.401041
# ZC2HC1A                5.430876e-04                   0.401041
# ZC2HC1A                5.430876e-04                   0.401041
# ZC2HC1A                5.430876e-04                   0.401041
# ZC3H3                  8.669868e-01                  -0.038181
# ZFAND1                 1.865537e-05                   0.486798
# ZFHX4                           NaN                        NaN
# ZFP41                           NaN                        NaN
# ZHX1                   1.244336e-02                   0.299886
# ZHX2                   5.504591e-02                   0.236516
# ZNF16                  5.182945e-01                   0.087225
# ZNF250                 8.066706e-01                  -0.037648
# ZNF251                          NaN                        NaN
# ZNF34                  7.667676e-01                  -0.041977
# ZNF623                          NaN                        NaN
# ZNF7                            NaN                        NaN
# ZNF706                 1.786632e-08                   0.609190
#
#           colon_pvalue_proteomics  colon_rvalue_proteomics  \
# Name
# ADCK5                5.200657e-01                 0.137726
# ADCY8                         NaN                      NaN
# ADHFE1                        NaN                      NaN
# AGO2                 2.228620e-08                 0.567648
# ANGPT1                        NaN                      NaN
# ANKRD46                       NaN                      NaN
# ANXA13               9.026626e-02                 0.202179
# ARFGEF1              2.089487e-14                 0.718423
# ARHGAP39                      NaN                      NaN
# ARMC1                2.447415e-01                 0.145229
# ASPH                 6.762253e-03                 0.304077
# ASPH                 6.762253e-03                 0.304077
# ASPH                 6.762253e-03                 0.304077
# ATAD2                2.198129e-01                 0.188646
# ATP6V0D2                      NaN                      NaN
# ATP6V1C1             2.515183e-01                 0.142718
# ATP6V1H              1.539431e-01                -0.174047
# BOP1                 1.478072e-07                 0.539634
# C8orf37                       NaN                      NaN
# C8orf76                       NaN                      NaN
# C8orf82              1.241355e-13                 0.701880
# C8orf88              5.837502e-01                 0.201781
# CA1                  6.550053e-01                -0.062739
# CA1                  6.550053e-01                -0.062739
# CA1                  6.550053e-01                -0.062739
# CA1                  6.550053e-01                -0.062739
# CA13                 2.539276e-03                 0.349949
# CA2                  6.752609e-01                 0.057303
# CA2                  6.752609e-01                 0.057303
# CA3                  5.255922e-01                -0.141915
# ...                           ...                      ...
# UBXN2B               4.248184e-01                 0.181833
# UQCRB                1.669960e-03                 0.348104
# UTP23                2.024977e-05                 0.594456
# VCPIP1               6.241404e-10                 0.615004
# VIRMA                         NaN                      NaN
# VPS13B                        NaN                      NaN
# VPS28                5.002114e-01                 0.090877
# WASHC5                        NaN                      NaN
# WDYHV1                        NaN                      NaN
# WWP1                 3.296266e-01                 0.310184
# YTHDF3               1.241355e-13                 0.699967
# YWHAZ                1.151170e-12                 0.680201
# ZBTB10                        NaN                      NaN
# ZC2HC1A              4.333514e-01                 0.107787
# ZC2HC1A              4.333514e-01                 0.107787
# ZC2HC1A              4.333514e-01                 0.107787
# ZC2HC1A              4.333514e-01                 0.107787
# ZC3H3                         NaN                      NaN
# ZFAND1               2.636920e-02                 0.278643
# ZFHX4                         NaN                      NaN
# ZFP41                         NaN                      NaN
# ZHX1                          NaN                      NaN
# ZHX2                 7.040135e-01                -0.105419
# ZNF16                         NaN                      NaN
# ZNF250                        NaN                      NaN
# ZNF251                        NaN                      NaN
# ZNF34                         NaN                      NaN
# ZNF623                        NaN                      NaN
# ZNF7                          NaN                      NaN
# ZNF706               4.952520e-06                 0.493256
#
#           brca_pvalue_proteomics  brca_rvalue_proteomics  \
# Name
# ADCK5               1.203762e-03                0.343326
# ADCY8                        NaN                     NaN
# ADHFE1              8.381515e-01               -0.025818
# AGO2                3.099972e-08                0.496262
# ANGPT1                       NaN                     NaN
# ANKRD46             2.706443e-01                0.187764
# ANXA13                       NaN                     NaN
# ARFGEF1             2.731893e-10                0.553758
# ARHGAP39            6.145594e-04                0.325121
# ARMC1               5.312909e-11                0.570808
# ASPH                5.759412e-01                0.057590
# ASPH                5.759412e-01                0.057590
# ASPH                5.759412e-01                0.057590
# ATAD2               4.439736e-14                0.639058
# ATP6V0D2                     NaN                     NaN
# ATP6V1C1            1.320907e-07                0.476015
# ATP6V1H             5.958937e-01               -0.054270
# BOP1                2.770784e-08                0.497951
# C8orf37             8.842857e-02                0.168441
# C8orf76                      NaN                     NaN
# C8orf82             1.411722e-09                0.534322
# C8orf88                      NaN                     NaN
# CA1                 3.088737e-01                0.103488
# CA1                 3.088737e-01                0.103488
# CA1                 3.088737e-01                0.103488
# CA1                 3.088737e-01                0.103488
# CA13                8.906941e-01                0.014066
# CA2                 4.829450e-01                0.071847
# CA2                 4.829450e-01                0.071847
# CA3                 2.290939e-01                0.122078
# ...                          ...                     ...
# UBXN2B              2.931462e-05                0.387775
# UQCRB               6.731142e-03                0.258789
# UTP23               3.767900e-10                0.549728
# VCPIP1              4.361801e-21                0.751316
# VIRMA                        NaN                     NaN
# VPS13B              8.664292e-03                0.251102
# VPS28               5.958937e-01               -0.054555
# WASHC5                       NaN                     NaN
# WDYHV1              2.196637e-03                0.336384
# WWP1                2.907709e-03                0.282321
# YTHDF3              5.942634e-17                0.691635
# YWHAZ               1.571510e-13                0.626268
# ZBTB10              1.333593e-15                0.669952
# ZC2HC1A             1.266935e-01                0.152297
# ZC2HC1A             1.266935e-01                0.152297
# ZC2HC1A             1.266935e-01                0.152297
# ZC2HC1A             1.266935e-01                0.152297
# ZC3H3               9.948952e-01                0.000851
# ZFAND1              3.433537e-07                0.462582
# ZFHX4                        NaN                     NaN
# ZFP41                        NaN                     NaN
# ZHX1                5.829476e-06                0.416715
# ZHX2                9.093600e-05                0.366517
# ZNF16                        NaN                     NaN
# ZNF250              4.749091e-02                0.215570
# ZNF251                       NaN                     NaN
# ZNF34                        NaN                     NaN
# ZNF623              1.746068e-03                0.329596
# ZNF7                         NaN                     NaN
# ZNF706              1.272094e-14                0.650938
#
#           lscc_pvalue_proteomics  lscc_rvalue_proteomics
# Name
# ADCK5               1.493486e-02                0.278639
# ADCY8                        NaN                     NaN
# ADHFE1              7.173051e-01                0.062784
# AGO2                2.811529e-10                0.596681
# ANGPT1              8.980819e-01                0.020585
# ANKRD46             5.442768e-02                0.259457
# ANXA13              8.019923e-01                0.034743
# ARFGEF1             1.549559e-08                0.545353
# ARHGAP39            2.970148e-01                0.131405
# ARMC1               6.392303e-06                0.452071
# ASPH                3.636042e-01                0.105645
# ASPH                3.636042e-01                0.105645
# ASPH                3.636042e-01                0.105645
# ATAD2               5.820937e-09                0.560070
# ATP6V0D2            3.602213e-01               -0.114979
# ATP6V1C1            6.991512e-01                0.050713
# ATP6V1H             6.044741e-01                0.064771
# BOP1                2.940811e-07                0.503240
# C8orf37             1.801668e-05                0.450867
# C8orf76             7.099384e-01                0.064687
# C8orf82             1.033885e-03                0.342734
# C8orf88                      NaN                     NaN
# CA1                 5.262272e-02                0.225377
# CA1                 5.262272e-02                0.225377
# CA1                 5.262272e-02                0.225377
# CA1                 5.262272e-02                0.225377
# CA13                2.358011e-01                0.133180
# CA2                 6.237911e-01                0.061168
# CA2                 6.237911e-01                0.061168
# CA3                 6.913171e-01               -0.052064
# ...                          ...                     ...
# UBXN2B              3.602570e-02                0.224960
# UQCRB               1.355725e-02                0.262323
# UTP23               2.508626e-06                0.469026
# VCPIP1              2.192765e-05                0.427405
# VIRMA                        NaN                     NaN
# VPS13B              1.109540e-02                0.269170
# VPS28               8.430719e-01               -0.026827
# WASHC5                       NaN                     NaN
# WDYHV1              3.332055e-03                0.374278
# WWP1                5.530847e-04                0.358815
# YTHDF3              4.221159e-11                0.621517
# YWHAZ               3.210400e-08                0.534444
# ZBTB10              3.048978e-01                0.117277
# ZC2HC1A             1.824489e-01                0.159917
# ZC2HC1A             1.824489e-01                0.159917
# ZC2HC1A             1.824489e-01                0.159917
# ZC2HC1A             1.824489e-01                0.159917
# ZC3H3               1.600571e-02                0.281800
# ZFAND1              3.828586e-03                0.305516
# ZFHX4               1.904854e-01                0.165329
# ZFP41                        NaN                     NaN
# ZHX1                9.642532e-07                0.484833
# ZHX2                7.156977e-06                0.448477
# ZNF16                        NaN                     NaN
# ZNF250                       NaN                     NaN
# ZNF251              8.309866e-01                0.037579
# ZNF34                        NaN                     NaN
# ZNF623              2.394204e-01                0.155132
# ZNF7                2.471900e-02                0.258191
# ZNF706              3.205112e-03                0.311057
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Transcriptomics

# %%
transcriptomics_results = None
for cancer_type in transcriptomics.keys():
    try:
        # We will use the index from the proteomics table. 
        transcriptomics_table = transcriptomics[cancer_type].copy()
        transcriptomics_table = transcriptomics_table.loc[:, transcriptomics_table.columns.get_level_values('Name').isin(genes)]
        if isinstance(transcriptomics_table.columns, pd.MultiIndex):
            transcriptomics_table = transcriptomics_table.droplevel('Database_ID', axis=1)
        pvalues = list()
        rvalues = list()
        index = transcriptomics_table.columns.get_level_values('Name').tolist()
        for protein in index:
            r, p = run_pearsons(protein, cnv[cancer_type], transcriptomics_table)
            pvalues.append(p)
            rvalues.append(r)
        pvalues = np.array(pvalues)
        mask = np.isfinite(pvalues)
        pval_corrected = np.empty(len(pvalues))
        pval_corrected.fill(np.nan)
        pval_corrected[mask] = statsmodels.stats.multitest.multipletests(pvals=list(pvalues[mask]), alpha=0.05, method='fdr_bh')[1]
        temp = pd.DataFrame(data={f'{cancer_type}_pvalue_transcriptomics': pval_corrected, f'{cancer_type}_rvalue_transcriptomics': rvalues}, index=index)
        temp.index.name = 'Name'
        if transcriptomics_results is not None:
            transcriptomics_results = transcriptomics_results.join(temp, how='outer')
        else:
            transcriptomics_results = temp
    except Exception as e:
        print(e)
# Out:
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# /home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %%
transcriptomics_results
# Out:
#               luad_pvalue_transcriptomics  luad_rvalue_transcriptomics  \
# Name
# AARD                         6.356175e-01                    -0.055060
# ABRA                         8.793561e-04                     0.327661
# ADCK5                        9.719253e-23                     0.782195
# ADCY8                        2.380193e-01                     0.130965
# ADGRB1                       4.321550e-03                     0.283806
# ADHFE1                       6.057527e-01                    -0.058895
# AGO2                         4.026910e-17                     0.705354
# ALKAL1                       1.962002e-01                    -0.140225
# ANGPT1                       1.265395e-01                    -0.159222
# ANKRD46                      2.170805e-25                     0.810623
# ANXA13                       4.958835e-01                    -0.077644
# ARC                          1.011858e-01                     0.170534
# ARFGEF1                      1.440712e-23                     0.791575
# ARHGAP39                     2.703392e-11                     0.592665
# ARMC1                        1.219784e-20                     0.755833
# ASAP1-IT2                             NaN                          NaN
# ASPH                         1.247114e-04                     0.370954
# ATAD2                        1.685740e-11                     0.597514
# ATP6V0D2                     2.520029e-02                    -0.226929
# ATP6V1C1                     3.219990e-25                     0.808880
# ATP6V1H                      1.332935e-19                     0.742090
# AZIN1                        1.400398e-29                     0.846434
# AZIN1-AS1                             NaN                          NaN
# BAALC                        2.434378e-01                     0.123947
# BAALC-AS1                             NaN                          NaN
# BAALC-AS2                             NaN                          NaN
# BHLHE22                      2.246599e-02                    -0.231121
# BOP1                         2.173692e-13                     0.638476
# C8orf31                               NaN                          NaN
# C8orf34                      8.677006e-01                     0.021554
# ...                                   ...                          ...
# YTHDF3                       2.283547e-29                     0.844647
# YTHDF3-AS1                            NaN                          NaN
# YWHAZ                        4.811415e-18                     0.719857
# ZBTB10                       2.087677e-17                     0.709920
# ZC2HC1A                      7.551513e-05                     0.381514
# ZC3H3                        3.836134e-15                     0.671950
# ZFAND1                       6.676529e-20                     0.746097
# ZFAT                         3.897726e-13                     0.633237
# ZFAT-AS1                              NaN                          NaN
# ZFHX4                        7.130724e-01                     0.042990
# ZFHX4-AS1                             NaN                          NaN
# ZFP41                        1.456267e-15                     0.679543
# ZFPM2-AS1                             NaN                          NaN
# ZHX1                         5.667289e-18                     0.718623
# ZHX1-C8orf76                          NaN                          NaN
# ZHX2                         1.007593e-04                     0.375425
# ZNF16                        1.257783e-26                     0.822244
# ZNF250                       3.525607e-21                     0.762607
# ZNF251                       7.336601e-19                     0.731742
# ZNF252P                               NaN                          NaN
# ZNF252P-AS1                           NaN                          NaN
# ZNF34                        9.301677e-15                     0.664728
# ZNF517                       5.818128e-15                     0.668594
# ZNF572                       2.910227e-10                     0.567215
# ZNF623                       7.255546e-34                     0.880199
# ZNF696                       3.439237e-22                     0.775788
# ZNF7                         3.204770e-32                     0.867147
# ZNF704                       5.536548e-02                     0.196740
# ZNF706                       5.715428e-16                     0.686693
# ZNF707                       3.612829e-20                     0.749616
#
#               hnscc_pvalue_transcriptomics  hnscc_rvalue_transcriptomics  \
# Name
# AARD                          7.882077e-01                     -0.033735
# ABRA                          9.080882e-01                      0.014087
# ADCK5                         9.433319e-13                      0.638019
# ADCY8                         9.080882e-01                      0.013893
# ADGRB1                        1.559108e-01                      0.157131
# ADHFE1                        8.363092e-01                     -0.026203
# AGO2                          9.433319e-13                      0.637924
# ALKAL1                        8.850058e-01                      0.018083
# ANGPT1                        4.572205e-01                      0.088299
# ANKRD46                       8.128512e-16                      0.697556
# ANXA13                        3.304421e-01                      0.110612
# ARC                           1.277557e-02                      0.259316
# ARFGEF1                       5.008354e-13                      0.643756
# ARHGAP39                      4.108916e-12                      0.623270
# ARMC1                         8.771048e-15                      0.678623
# ASAP1-IT2                     7.657884e-03                      0.275720
# ASPH                          8.888445e-09                      0.536583
# ATAD2                         1.103888e-12                      0.636430
# ATP6V0D2                      1.217404e-02                      0.261159
# ATP6V1C1                      2.822813e-17                      0.721940
# ATP6V1H                       1.332014e-15                      0.693383
# AZIN1                         2.575719e-10                      0.579652
# AZIN1-AS1                     3.917972e-03                      0.296361
# BAALC                         3.719724e-03                      0.297876
# BAALC-AS1                     5.100910e-03                      0.288319
# BAALC-AS2                     7.922434e-02                      0.190632
# BHLHE22                       2.065305e-01                     -0.141015
# BOP1                          2.168218e-12                      0.630198
# C8orf31                       6.788235e-01                     -0.051233
# C8orf34                       8.592552e-01                      0.022028
# ...                                    ...                           ...
# YTHDF3                        1.160644e-15                      0.694511
# YTHDF3-AS1                    1.553920e-04                      0.377051
# YWHAZ                         4.369469e-10                      0.573454
# ZBTB10                        7.811610e-01                      0.035229
# ZC2HC1A                       9.385594e-01                      0.009242
# ZC3H3                         9.932700e-09                      0.535027
# ZFAND1                        1.115215e-16                      0.712329
# ZFAT                          4.661895e-01                      0.086813
# ZFAT-AS1                      8.949854e-01                     -0.016416
# ZFHX4                         4.175023e-01                      0.094636
# ZFHX4-AS1                     9.945031e-02                      0.179706
# ZFP41                         2.364337e-11                      0.605307
# ZFPM2-AS1                     4.005364e-01                      0.097945
# ZHX1                          3.876168e-08                      0.516976
# ZHX1-C8orf76                  4.053733e-13                      0.645925
# ZHX2                          1.282436e-02                      0.259079
# ZNF16                         2.515241e-10                      0.580002
# ZNF250                        1.387372e-06                      0.464449
# ZNF251                        1.154395e-02                      0.262905
# ZNF252P                       4.018264e-09                      0.546873
# ZNF252P-AS1                   1.301306e-02                      0.258508
# ZNF34                         6.409807e-03                      0.281309
# ZNF517                        3.813714e-08                      0.517281
# ZNF572                        6.396324e-04                      0.344787
# ZNF623                        2.438300e-20                      0.767678
# ZNF696                        2.253568e-12                      0.629734
# ZNF7                          9.333276e-22                      0.785909
# ZNF704                        3.293007e-01                      0.111061
# ZNF706                        5.603768e-16                      0.700584
# ZNF707                        5.919586e-13                      0.642202
#
#               ovarian_pvalue_transcriptomics  ovarian_rvalue_transcriptomics  \
# Name
# AARD                            4.117559e-03                        0.302940
# ABRA                            1.942591e-01                       -0.147640
# ADCK5                                    NaN                             NaN
# ADCY8                           7.007415e-01                        0.049351
# ADGRB1                                   NaN                             NaN
# ADHFE1                                   NaN                             NaN
# AGO2                            1.991916e-06                        0.471840
# ALKAL1                                   NaN                             NaN
# ANGPT1                          5.394442e-01                        0.073580
# ANKRD46                         3.631554e-11                        0.622385
# ANXA13                          3.451407e-01                        0.111051
# ARC                             2.735011e-01                        0.126616
# ARFGEF1                         2.889885e-17                        0.753026
# ARHGAP39                                 NaN                             NaN
# ARMC1                           1.529553e-14                        0.697588
# ASAP1-IT2                                NaN                             NaN
# ASPH                            2.098468e-07                        0.509054
# ATAD2                           3.174326e-09                        0.568972
# ATP6V0D2                        4.027338e-01                        0.099721
# ATP6V1C1                        1.682344e-08                        0.547441
# ATP6V1H                         1.293536e-14                        0.699968
# AZIN1                           2.748226e-09                        0.570879
# AZIN1-AS1                                NaN                             NaN
# BAALC                           8.560237e-01                       -0.023347
# BAALC-AS1                                NaN                             NaN
# BAALC-AS2                                NaN                             NaN
# BHLHE22                         4.517794e-01                       -0.090164
# BOP1                                     NaN                             NaN
# C8orf31                         3.063783e-02                        0.234598
# C8orf34                         7.630739e-01                        0.039018
# ...                                      ...                             ...
# YTHDF3                                   NaN                             NaN
# YTHDF3-AS1                               NaN                             NaN
# YWHAZ                           2.077719e-08                        0.544152
# ZBTB10                          8.751235e-12                        0.637873
# ZC2HC1A                         1.533599e-03                        0.330547
# ZC3H3                           6.969031e-04                        0.351288
# ZFAND1                                   NaN                             NaN
# ZFAT                            1.548507e-04                        0.386745
# ZFAT-AS1                                 NaN                             NaN
# ZFHX4                           1.658500e-01                        0.157405
# ZFHX4-AS1                                NaN                             NaN
# ZFP41                                    NaN                             NaN
# ZFPM2-AS1                                NaN                             NaN
# ZHX1                                     NaN                             NaN
# ZHX1-C8orf76                             NaN                             NaN
# ZHX2                            3.080351e-01                        0.118561
# ZNF16                           3.378403e-07                        0.501597
# ZNF250                                   NaN                             NaN
# ZNF251                          1.197410e-14                        0.701173
# ZNF252P                                  NaN                             NaN
# ZNF252P-AS1                              NaN                             NaN
# ZNF34                           1.293425e-11                        0.633199
# ZNF517                          7.156618e-06                        0.449179
# ZNF572                                   NaN                             NaN
# ZNF623                                   NaN                             NaN
# ZNF696                          6.514544e-11                        0.615532
# ZNF7                            2.889885e-17                        0.746397
# ZNF704                          5.984369e-07                        0.492041
# ZNF706                          1.868057e-08                        0.545905
# ZNF707                                   NaN                             NaN
#
#               colon_pvalue_transcriptomics  colon_rvalue_transcriptomics  \
# Name
# AARD                                   NaN                           NaN
# ABRA                                   NaN                           NaN
# ADCK5                         1.963035e-11                      0.610827
# ADCY8                                  NaN                           NaN
# ADGRB1                                 NaN                           NaN
# ADHFE1                                 NaN                           NaN
# AGO2                          1.747359e-06                      0.457059
# ALKAL1                                 NaN                           NaN
# ANGPT1                        9.546013e-01                     -0.006114
# ANKRD46                       7.509411e-11                      0.595736
# ANXA13                        1.219547e-02                      0.250526
# ARC                                    NaN                           NaN
# ARFGEF1                       3.379111e-25                      0.825209
# ARHGAP39                      5.071031e-05                      0.393166
# ARMC1                         5.042108e-07                      0.477659
# ASAP1-IT2                              NaN                           NaN
# ASPH                          1.158237e-02                      0.252353
# ATAD2                         4.737264e-06                      0.439456
# ATP6V0D2                               NaN                           NaN
# ATP6V1C1                      6.734144e-20                      0.765005
# ATP6V1H                       2.182956e-17                      0.728913
# AZIN1                         5.877524e-18                      0.737812
# AZIN1-AS1                              NaN                           NaN
# BAALC                                  NaN                           NaN
# BAALC-AS1                              NaN                           NaN
# BAALC-AS2                              NaN                           NaN
# BHLHE22                                NaN                           NaN
# BOP1                          1.991151e-11                      0.610522
# C8orf31                                NaN                           NaN
# C8orf34                                NaN                           NaN
# ...                                    ...                           ...
# YTHDF3                        3.652246e-18                      0.741135
# YTHDF3-AS1                             NaN                           NaN
# YWHAZ                         2.713606e-10                      0.581237
# ZBTB10                        1.309891e-04                      0.372788
# ZC2HC1A                       4.026856e-03                      0.285760
# ZC3H3                         4.837609e-03                      0.280321
# ZFAND1                        3.556803e-10                      0.577712
# ZFAT                          3.588217e-01                      0.095029
# ZFAT-AS1                               NaN                           NaN
# ZFHX4                                  NaN                           NaN
# ZFHX4-AS1                              NaN                           NaN
# ZFP41                         2.800037e-10                      0.580469
# ZFPM2-AS1                              NaN                           NaN
# ZHX1                          9.780201e-05                      0.379184
# ZHX1-C8orf76                           NaN                           NaN
# ZHX2                          6.169776e-01                      0.052443
# ZNF16                         3.374604e-09                      0.549671
# ZNF250                        2.644688e-17                      0.726913
# ZNF251                        1.602964e-11                      0.612974
# ZNF252P                       3.792259e-11                      0.603633
# ZNF252P-AS1                            NaN                           NaN
# ZNF34                         2.011667e-14                      0.677610
# ZNF517                        1.334951e-15                      0.700175
# ZNF572                        2.045896e-06                      0.454020
# ZNF623                        4.817278e-20                      0.768235
# ZNF696                        3.594275e-15                      0.692380
# ZNF7                          5.466603e-23                      0.801751
# ZNF704                        9.895385e-08                      0.502647
# ZNF706                        6.776579e-14                      0.666225
# ZNF707                        1.785476e-15                      0.697748
#
#               brca_pvalue_transcriptomics  brca_rvalue_transcriptomics  \
# Name
# AARD                         7.860418e-03                     0.260587
# ABRA                         7.895485e-01                    -0.086423
# ADCK5                        1.582929e-08                     0.756367
# ADCY8                        3.813367e-01                     0.138662
# ADGRB1                                NaN                          NaN
# ADHFE1                       4.240621e-02                     0.203409
# AGO2                         3.870560e-13                     0.623225
# ALKAL1                                NaN                          NaN
# ANGPT1                       3.813367e-01                     0.094477
# ANKRD46                      2.233242e-07                     0.469283
# ANXA13                       1.595117e-02                    -0.246441
# ARC                          2.038249e-01                     0.139299
# ARFGEF1                      3.675766e-08                     0.493962
# ARHGAP39                     9.680762e-04                     0.316522
# ARMC1                        8.767803e-10                     0.541874
# ASAP1-IT2                             NaN                          NaN
# ASPH                         7.513628e-01                    -0.036859
# ATAD2                        2.890351e-09                     0.527397
# ATP6V0D2                     2.083701e-01                    -0.131386
# ATP6V1C1                     1.418093e-07                     0.475996
# ATP6V1H                      7.048933e-11                     0.570097
# AZIN1                        1.017587e-07                     0.482444
# AZIN1-AS1                             NaN                          NaN
# BAALC                        2.549573e-01                     0.119820
# BAALC-AS1                             NaN                          NaN
# BAALC-AS2                             NaN                          NaN
# BHLHE22                      6.433136e-01                    -0.052262
# BOP1                         3.538234e-08                     0.494603
# C8orf31                      7.163894e-01                    -0.043256
# C8orf34                      8.020438e-01                    -0.031256
# ...                                   ...                          ...
# YTHDF3                       5.210066e-04                     0.328496
# YTHDF3-AS1                            NaN                          NaN
# YWHAZ                        5.303443e-09                     0.519371
# ZBTB10                       1.845534e-06                     0.436673
# ZC2HC1A                      2.671324e-01                     0.117065
# ZC3H3                        1.062808e-03                     0.312871
# ZFAND1                       5.875196e-12                     0.595695
# ZFAT                         1.375910e-03                     0.305204
# ZFAT-AS1                              NaN                          NaN
# ZFHX4                        1.532897e-01                    -0.148528
# ZFHX4-AS1                             NaN                          NaN
# ZFP41                        6.312716e-04                     0.323965
# ZFPM2-AS1                             NaN                          NaN
# ZHX1                         7.466687e-15                     0.658012
# ZHX1-C8orf76                          NaN                          NaN
# ZHX2                         7.734289e-02                     0.179369
# ZNF16                        9.310669e-13                     0.614337
# ZNF250                       4.292656e-05                     0.380988
# ZNF251                       4.756454e-14                     0.644384
# ZNF252P                      1.897367e-11                     0.583334
# ZNF252P-AS1                           NaN                          NaN
# ZNF34                        2.500438e-02                     0.222708
# ZNF517                       2.348092e-06                     0.435750
# ZNF572                       8.262188e-03                     0.256436
# ZNF623                       1.944453e-14                     0.650334
# ZNF696                       2.627149e-15                     0.667046
# ZNF7                         5.788307e-18                     0.715206
# ZNF704                       1.622224e-02                     0.235563
# ZNF706                       4.529419e-06                     0.421599
# ZNF707                       6.666527e-12                     0.596259
#
#               lscc_pvalue_transcriptomics  lscc_rvalue_transcriptomics
# Name
# AARD                         9.793174e-01                     0.003161
# ABRA                         1.070717e-01                    -0.271560
# ADCK5                        7.660768e-07                     0.470326
# ADCY8                        5.617166e-01                     0.071655
# ADGRB1                       5.988875e-01                     0.061999
# ADHFE1                       1.356589e-01                     0.160482
# AGO2                         4.344359e-23                     0.798487
# ALKAL1                                NaN                          NaN
# ANGPT1                       9.360686e-01                    -0.009744
# ANKRD46                      2.922799e-16                     0.703134
# ANXA13                       5.853263e-01                    -0.068190
# ARC                          1.341374e-03                     0.321736
# ARFGEF1                      2.883339e-15                     0.685229
# ARHGAP39                     4.209090e-04                     0.350540
# ARMC1                        3.261252e-10                     0.574437
# ASAP1-IT2                    9.051280e-03                     0.266404
# ASPH                         6.107608e-03                     0.278975
# ATAD2                        1.357263e-11                     0.609033
# ATP6V0D2                     7.809182e-02                    -0.187691
# ATP6V1C1                     2.133764e-10                     0.579514
# ATP6V1H                      4.753375e-16                     0.699416
# AZIN1                        6.589150e-13                     0.637919
# AZIN1-AS1                             NaN                          NaN
# BAALC                        1.800647e-02                     0.242858
# BAALC-AS1                    1.465914e-08                     0.527761
# BAALC-AS2                    5.381511e-03                     0.316031
# BHLHE22                      9.364782e-01                     0.009417
# BOP1                         2.975031e-20                     0.763634
# C8orf31                      1.461089e-02                    -0.250323
# C8orf34                      7.892611e-01                    -0.031102
# ...                                   ...                          ...
# YTHDF3                       2.437238e-18                     0.737528
# YTHDF3-AS1                   2.377799e-07                     0.488854
# YWHAZ                        3.406279e-13                     0.644450
# ZBTB10                       4.456081e-02                     0.210210
# ZC2HC1A                      6.206314e-04                     0.341529
# ZC3H3                        1.373364e-13                     0.652687
# ZFAND1                       3.046839e-17                     0.719219
# ZFAT                         3.343954e-04                     0.355847
# ZFAT-AS1                              NaN                          NaN
# ZFHX4                        9.661175e-01                     0.005273
# ZFHX4-AS1                    7.279022e-02                     0.219696
# ZFP41                        5.116929e-13                     0.640344
# ZFPM2-AS1                             NaN                          NaN
# ZHX1                         5.017005e-10                     0.569532
# ZHX1-C8orf76                 4.029531e-06                     0.442851
# ZHX2                         5.842826e-05                     0.393279
# ZNF16                        2.551961e-07                     0.487583
# ZNF250                       8.079298e-05                     0.386826
# ZNF251                       1.450777e-03                     0.319380
# ZNF252P                               NaN                          NaN
# ZNF252P-AS1                  4.473906e-04                     0.349064
# ZNF34                        1.251343e-06                     0.462397
# ZNF517                       7.565406e-06                     0.431845
# ZNF572                       7.219185e-10                     0.565190
# ZNF623                       2.900160e-25                     0.819691
# ZNF696                       8.249372e-18                     0.728937
# ZNF7                         2.597047e-09                     0.549522
# ZNF704                       8.336708e-05                     0.386096
# ZNF706                       7.469400e-11                     0.591007
# ZNF707                                NaN                          NaN
#
# [536 rows x 12 columns]

# %%
# stats.stdev(list(proteomics_results['brca_rvalue_proteomics']))

# %%
# sns.distplot(proteomics_results['lscc_rvalue_proteomics'])

# %% [markdown]
# ## Create Graphs

# %%
# Join the graphs
all_results = transcriptomics_results.join(proteomics_results)

# %%
all_results.to_csv('pearson_cis_effect_results_8q.tsv', sep='\t')

# %%
all_results
# Out:
#               luad_pvalue_transcriptomics  luad_rvalue_transcriptomics  \
# Name
# AARD                         6.356175e-01                    -0.055060
# ABRA                         8.793561e-04                     0.327661
# ADCK5                        9.719253e-23                     0.782195
# ADCY8                        2.380193e-01                     0.130965
# ADGRB1                       4.321550e-03                     0.283806
# ADHFE1                       6.057527e-01                    -0.058895
# AGO2                         4.026910e-17                     0.705354
# ALKAL1                       1.962002e-01                    -0.140225
# ANGPT1                       1.265395e-01                    -0.159222
# ANKRD46                      2.170805e-25                     0.810623
# ANXA13                       4.958835e-01                    -0.077644
# ARC                          1.011858e-01                     0.170534
# ARFGEF1                      1.440712e-23                     0.791575
# ARHGAP39                     2.703392e-11                     0.592665
# ARMC1                        1.219784e-20                     0.755833
# ASAP1-IT2                             NaN                          NaN
# ASPH                         1.247114e-04                     0.370954
# ASPH                         1.247114e-04                     0.370954
# ASPH                         1.247114e-04                     0.370954
# ATAD2                        1.685740e-11                     0.597514
# ATP6V0D2                     2.520029e-02                    -0.226929
# ATP6V1C1                     3.219990e-25                     0.808880
# ATP6V1H                      1.332935e-19                     0.742090
# AZIN1                        1.400398e-29                     0.846434
# AZIN1-AS1                             NaN                          NaN
# BAALC                        2.434378e-01                     0.123947
# BAALC-AS1                             NaN                          NaN
# BAALC-AS2                             NaN                          NaN
# BHLHE22                      2.246599e-02                    -0.231121
# BOP1                         2.173692e-13                     0.638476
# ...                                   ...                          ...
# ZBTB10                       2.087677e-17                     0.709920
# ZC2HC1A                      7.551513e-05                     0.381514
# ZC2HC1A                      7.551513e-05                     0.381514
# ZC2HC1A                      7.551513e-05                     0.381514
# ZC2HC1A                      7.551513e-05                     0.381514
# ZC3H3                        3.836134e-15                     0.671950
# ZFAND1                       6.676529e-20                     0.746097
# ZFAT                         3.897726e-13                     0.633237
# ZFAT-AS1                              NaN                          NaN
# ZFHX4                        7.130724e-01                     0.042990
# ZFHX4-AS1                             NaN                          NaN
# ZFP41                        1.456267e-15                     0.679543
# ZFPM2-AS1                             NaN                          NaN
# ZHX1                         5.667289e-18                     0.718623
# ZHX1-C8orf76                          NaN                          NaN
# ZHX2                         1.007593e-04                     0.375425
# ZNF16                        1.257783e-26                     0.822244
# ZNF250                       3.525607e-21                     0.762607
# ZNF251                       7.336601e-19                     0.731742
# ZNF252P                               NaN                          NaN
# ZNF252P-AS1                           NaN                          NaN
# ZNF34                        9.301677e-15                     0.664728
# ZNF517                       5.818128e-15                     0.668594
# ZNF572                       2.910227e-10                     0.567215
# ZNF623                       7.255546e-34                     0.880199
# ZNF696                       3.439237e-22                     0.775788
# ZNF7                         3.204770e-32                     0.867147
# ZNF704                       5.536548e-02                     0.196740
# ZNF706                       5.715428e-16                     0.686693
# ZNF707                       3.612829e-20                     0.749616
#
#               hnscc_pvalue_transcriptomics  hnscc_rvalue_transcriptomics  \
# Name
# AARD                          7.882077e-01                     -0.033735
# ABRA                          9.080882e-01                      0.014087
# ADCK5                         9.433319e-13                      0.638019
# ADCY8                         9.080882e-01                      0.013893
# ADGRB1                        1.559108e-01                      0.157131
# ADHFE1                        8.363092e-01                     -0.026203
# AGO2                          9.433319e-13                      0.637924
# ALKAL1                        8.850058e-01                      0.018083
# ANGPT1                        4.572205e-01                      0.088299
# ANKRD46                       8.128512e-16                      0.697556
# ANXA13                        3.304421e-01                      0.110612
# ARC                           1.277557e-02                      0.259316
# ARFGEF1                       5.008354e-13                      0.643756
# ARHGAP39                      4.108916e-12                      0.623270
# ARMC1                         8.771048e-15                      0.678623
# ASAP1-IT2                     7.657884e-03                      0.275720
# ASPH                          8.888445e-09                      0.536583
# ASPH                          8.888445e-09                      0.536583
# ASPH                          8.888445e-09                      0.536583
# ATAD2                         1.103888e-12                      0.636430
# ATP6V0D2                      1.217404e-02                      0.261159
# ATP6V1C1                      2.822813e-17                      0.721940
# ATP6V1H                       1.332014e-15                      0.693383
# AZIN1                         2.575719e-10                      0.579652
# AZIN1-AS1                     3.917972e-03                      0.296361
# BAALC                         3.719724e-03                      0.297876
# BAALC-AS1                     5.100910e-03                      0.288319
# BAALC-AS2                     7.922434e-02                      0.190632
# BHLHE22                       2.065305e-01                     -0.141015
# BOP1                          2.168218e-12                      0.630198
# ...                                    ...                           ...
# ZBTB10                        7.811610e-01                      0.035229
# ZC2HC1A                       9.385594e-01                      0.009242
# ZC2HC1A                       9.385594e-01                      0.009242
# ZC2HC1A                       9.385594e-01                      0.009242
# ZC2HC1A                       9.385594e-01                      0.009242
# ZC3H3                         9.932700e-09                      0.535027
# ZFAND1                        1.115215e-16                      0.712329
# ZFAT                          4.661895e-01                      0.086813
# ZFAT-AS1                      8.949854e-01                     -0.016416
# ZFHX4                         4.175023e-01                      0.094636
# ZFHX4-AS1                     9.945031e-02                      0.179706
# ZFP41                         2.364337e-11                      0.605307
# ZFPM2-AS1                     4.005364e-01                      0.097945
# ZHX1                          3.876168e-08                      0.516976
# ZHX1-C8orf76                  4.053733e-13                      0.645925
# ZHX2                          1.282436e-02                      0.259079
# ZNF16                         2.515241e-10                      0.580002
# ZNF250                        1.387372e-06                      0.464449
# ZNF251                        1.154395e-02                      0.262905
# ZNF252P                       4.018264e-09                      0.546873
# ZNF252P-AS1                   1.301306e-02                      0.258508
# ZNF34                         6.409807e-03                      0.281309
# ZNF517                        3.813714e-08                      0.517281
# ZNF572                        6.396324e-04                      0.344787
# ZNF623                        2.438300e-20                      0.767678
# ZNF696                        2.253568e-12                      0.629734
# ZNF7                          9.333276e-22                      0.785909
# ZNF704                        3.293007e-01                      0.111061
# ZNF706                        5.603768e-16                      0.700584
# ZNF707                        5.919586e-13                      0.642202
#
#               ovarian_pvalue_transcriptomics  ovarian_rvalue_transcriptomics  \
# Name
# AARD                            4.117559e-03                        0.302940
# ABRA                            1.942591e-01                       -0.147640
# ADCK5                                    NaN                             NaN
# ADCY8                           7.007415e-01                        0.049351
# ADGRB1                                   NaN                             NaN
# ADHFE1                                   NaN                             NaN
# AGO2                            1.991916e-06                        0.471840
# ALKAL1                                   NaN                             NaN
# ANGPT1                          5.394442e-01                        0.073580
# ANKRD46                         3.631554e-11                        0.622385
# ANXA13                          3.451407e-01                        0.111051
# ARC                             2.735011e-01                        0.126616
# ARFGEF1                         2.889885e-17                        0.753026
# ARHGAP39                                 NaN                             NaN
# ARMC1                           1.529553e-14                        0.697588
# ASAP1-IT2                                NaN                             NaN
# ASPH                            2.098468e-07                        0.509054
# ASPH                            2.098468e-07                        0.509054
# ASPH                            2.098468e-07                        0.509054
# ATAD2                           3.174326e-09                        0.568972
# ATP6V0D2                        4.027338e-01                        0.099721
# ATP6V1C1                        1.682344e-08                        0.547441
# ATP6V1H                         1.293536e-14                        0.699968
# AZIN1                           2.748226e-09                        0.570879
# AZIN1-AS1                                NaN                             NaN
# BAALC                           8.560237e-01                       -0.023347
# BAALC-AS1                                NaN                             NaN
# BAALC-AS2                                NaN                             NaN
# BHLHE22                         4.517794e-01                       -0.090164
# BOP1                                     NaN                             NaN
# ...                                      ...                             ...
# ZBTB10                          8.751235e-12                        0.637873
# ZC2HC1A                         1.533599e-03                        0.330547
# ZC2HC1A                         1.533599e-03                        0.330547
# ZC2HC1A                         1.533599e-03                        0.330547
# ZC2HC1A                         1.533599e-03                        0.330547
# ZC3H3                           6.969031e-04                        0.351288
# ZFAND1                                   NaN                             NaN
# ZFAT                            1.548507e-04                        0.386745
# ZFAT-AS1                                 NaN                             NaN
# ZFHX4                           1.658500e-01                        0.157405
# ZFHX4-AS1                                NaN                             NaN
# ZFP41                                    NaN                             NaN
# ZFPM2-AS1                                NaN                             NaN
# ZHX1                                     NaN                             NaN
# ZHX1-C8orf76                             NaN                             NaN
# ZHX2                            3.080351e-01                        0.118561
# ZNF16                           3.378403e-07                        0.501597
# ZNF250                                   NaN                             NaN
# ZNF251                          1.197410e-14                        0.701173
# ZNF252P                                  NaN                             NaN
# ZNF252P-AS1                              NaN                             NaN
# ZNF34                           1.293425e-11                        0.633199
# ZNF517                          7.156618e-06                        0.449179
# ZNF572                                   NaN                             NaN
# ZNF623                                   NaN                             NaN
# ZNF696                          6.514544e-11                        0.615532
# ZNF7                            2.889885e-17                        0.746397
# ZNF704                          5.984369e-07                        0.492041
# ZNF706                          1.868057e-08                        0.545905
# ZNF707                                   NaN                             NaN
#
#               colon_pvalue_transcriptomics  colon_rvalue_transcriptomics  \
# Name
# AARD                                   NaN                           NaN
# ABRA                                   NaN                           NaN
# ADCK5                         1.963035e-11                      0.610827
# ADCY8                                  NaN                           NaN
# ADGRB1                                 NaN                           NaN
# ADHFE1                                 NaN                           NaN
# AGO2                          1.747359e-06                      0.457059
# ALKAL1                                 NaN                           NaN
# ANGPT1                        9.546013e-01                     -0.006114
# ANKRD46                       7.509411e-11                      0.595736
# ANXA13                        1.219547e-02                      0.250526
# ARC                                    NaN                           NaN
# ARFGEF1                       3.379111e-25                      0.825209
# ARHGAP39                      5.071031e-05                      0.393166
# ARMC1                         5.042108e-07                      0.477659
# ASAP1-IT2                              NaN                           NaN
# ASPH                          1.158237e-02                      0.252353
# ASPH                          1.158237e-02                      0.252353
# ASPH                          1.158237e-02                      0.252353
# ATAD2                         4.737264e-06                      0.439456
# ATP6V0D2                               NaN                           NaN
# ATP6V1C1                      6.734144e-20                      0.765005
# ATP6V1H                       2.182956e-17                      0.728913
# AZIN1                         5.877524e-18                      0.737812
# AZIN1-AS1                              NaN                           NaN
# BAALC                                  NaN                           NaN
# BAALC-AS1                              NaN                           NaN
# BAALC-AS2                              NaN                           NaN
# BHLHE22                                NaN                           NaN
# BOP1                          1.991151e-11                      0.610522
# ...                                    ...                           ...
# ZBTB10                        1.309891e-04                      0.372788
# ZC2HC1A                       4.026856e-03                      0.285760
# ZC2HC1A                       4.026856e-03                      0.285760
# ZC2HC1A                       4.026856e-03                      0.285760
# ZC2HC1A                       4.026856e-03                      0.285760
# ZC3H3                         4.837609e-03                      0.280321
# ZFAND1                        3.556803e-10                      0.577712
# ZFAT                          3.588217e-01                      0.095029
# ZFAT-AS1                               NaN                           NaN
# ZFHX4                                  NaN                           NaN
# ZFHX4-AS1                              NaN                           NaN
# ZFP41                         2.800037e-10                      0.580469
# ZFPM2-AS1                              NaN                           NaN
# ZHX1                          9.780201e-05                      0.379184
# ZHX1-C8orf76                           NaN                           NaN
# ZHX2                          6.169776e-01                      0.052443
# ZNF16                         3.374604e-09                      0.549671
# ZNF250                        2.644688e-17                      0.726913
# ZNF251                        1.602964e-11                      0.612974
# ZNF252P                       3.792259e-11                      0.603633
# ZNF252P-AS1                            NaN                           NaN
# ZNF34                         2.011667e-14                      0.677610
# ZNF517                        1.334951e-15                      0.700175
# ZNF572                        2.045896e-06                      0.454020
# ZNF623                        4.817278e-20                      0.768235
# ZNF696                        3.594275e-15                      0.692380
# ZNF7                          5.466603e-23                      0.801751
# ZNF704                        9.895385e-08                      0.502647
# ZNF706                        6.776579e-14                      0.666225
# ZNF707                        1.785476e-15                      0.697748
#
#               brca_pvalue_transcriptomics  brca_rvalue_transcriptomics  ...  \
# Name                                                                    ...
# AARD                         7.860418e-03                     0.260587  ...
# ABRA                         7.895485e-01                    -0.086423  ...
# ADCK5                        1.582929e-08                     0.756367  ...
# ADCY8                        3.813367e-01                     0.138662  ...
# ADGRB1                                NaN                          NaN  ...
# ADHFE1                       4.240621e-02                     0.203409  ...
# AGO2                         3.870560e-13                     0.623225  ...
# ALKAL1                                NaN                          NaN  ...
# ANGPT1                       3.813367e-01                     0.094477  ...
# ANKRD46                      2.233242e-07                     0.469283  ...
# ANXA13                       1.595117e-02                    -0.246441  ...
# ARC                          2.038249e-01                     0.139299  ...
# ARFGEF1                      3.675766e-08                     0.493962  ...
# ARHGAP39                     9.680762e-04                     0.316522  ...
# ARMC1                        8.767803e-10                     0.541874  ...
# ASAP1-IT2                             NaN                          NaN  ...
# ASPH                         7.513628e-01                    -0.036859  ...
# ASPH                         7.513628e-01                    -0.036859  ...
# ASPH                         7.513628e-01                    -0.036859  ...
# ATAD2                        2.890351e-09                     0.527397  ...
# ATP6V0D2                     2.083701e-01                    -0.131386  ...
# ATP6V1C1                     1.418093e-07                     0.475996  ...
# ATP6V1H                      7.048933e-11                     0.570097  ...
# AZIN1                        1.017587e-07                     0.482444  ...
# AZIN1-AS1                             NaN                          NaN  ...
# BAALC                        2.549573e-01                     0.119820  ...
# BAALC-AS1                             NaN                          NaN  ...
# BAALC-AS2                             NaN                          NaN  ...
# BHLHE22                      6.433136e-01                    -0.052262  ...
# BOP1                         3.538234e-08                     0.494603  ...
# ...                                   ...                          ...  ...
# ZBTB10                       1.845534e-06                     0.436673  ...
# ZC2HC1A                      2.671324e-01                     0.117065  ...
# ZC2HC1A                      2.671324e-01                     0.117065  ...
# ZC2HC1A                      2.671324e-01                     0.117065  ...
# ZC2HC1A                      2.671324e-01                     0.117065  ...
# ZC3H3                        1.062808e-03                     0.312871  ...
# ZFAND1                       5.875196e-12                     0.595695  ...
# ZFAT                         1.375910e-03                     0.305204  ...
# ZFAT-AS1                              NaN                          NaN  ...
# ZFHX4                        1.532897e-01                    -0.148528  ...
# ZFHX4-AS1                             NaN                          NaN  ...
# ZFP41                        6.312716e-04                     0.323965  ...
# ZFPM2-AS1                             NaN                          NaN  ...
# ZHX1                         7.466687e-15                     0.658012  ...
# ZHX1-C8orf76                          NaN                          NaN  ...
# ZHX2                         7.734289e-02                     0.179369  ...
# ZNF16                        9.310669e-13                     0.614337  ...
# ZNF250                       4.292656e-05                     0.380988  ...
# ZNF251                       4.756454e-14                     0.644384  ...
# ZNF252P                      1.897367e-11                     0.583334  ...
# ZNF252P-AS1                           NaN                          NaN  ...
# ZNF34                        2.500438e-02                     0.222708  ...
# ZNF517                       2.348092e-06                     0.435750  ...
# ZNF572                       8.262188e-03                     0.256436  ...
# ZNF623                       1.944453e-14                     0.650334  ...
# ZNF696                       2.627149e-15                     0.667046  ...
# ZNF7                         5.788307e-18                     0.715206  ...
# ZNF704                       1.622224e-02                     0.235563  ...
# ZNF706                       4.529419e-06                     0.421599  ...
# ZNF707                       6.666527e-12                     0.596259  ...
#
#               hnscc_pvalue_proteomics  hnscc_rvalue_proteomics  \
# Name
# AARD                              NaN                      NaN
# ABRA                              NaN                      NaN
# ADCK5                    4.025665e-02                 0.255199
# ADCY8                             NaN                      NaN
# ADGRB1                            NaN                      NaN
# ADHFE1                   8.827123e-01                -0.024365
# AGO2                     6.060852e-09                 0.561954
# ALKAL1                            NaN                      NaN
# ANGPT1                            NaN                      NaN
# ANKRD46                  8.958845e-02                 0.353214
# ANXA13                   4.717983e-01                 0.128624
# ARC                               NaN                      NaN
# ARFGEF1                  2.335016e-09                 0.577159
# ARHGAP39                 9.788467e-01                -0.010658
# ARMC1                    6.725564e-04                 0.357050
# ASAP1-IT2                         NaN                      NaN
# ASPH                     1.425976e-05                 0.439936
# ASPH                     1.425976e-05                 0.439936
# ASPH                     1.425976e-05                 0.439936
# ATAD2                    5.970395e-07                 0.493030
# ATP6V0D2                 8.880074e-01                 0.089318
# ATP6V1C1                 3.803748e-05                 0.420475
# ATP6V1H                  4.882596e-03                 0.298945
# AZIN1                             NaN                      NaN
# AZIN1-AS1                         NaN                      NaN
# BAALC                             NaN                      NaN
# BAALC-AS1                         NaN                      NaN
# BAALC-AS2                         NaN                      NaN
# BHLHE22                           NaN                      NaN
# BOP1                     6.668027e-04                 0.357622
# ...                               ...                      ...
# ZBTB10                   9.101386e-01                 0.043030
# ZC2HC1A                  8.184638e-01                 0.034025
# ZC2HC1A                  8.184638e-01                 0.034025
# ZC2HC1A                  8.184638e-01                 0.034025
# ZC2HC1A                  8.184638e-01                 0.034025
# ZC3H3                    2.350062e-01                 0.152503
# ZFAND1                   7.327914e-02                 0.201677
# ZFAT                              NaN                      NaN
# ZFAT-AS1                          NaN                      NaN
# ZFHX4                             NaN                      NaN
# ZFHX4-AS1                         NaN                      NaN
# ZFP41                    8.802390e-01                 0.145576
# ZFPM2-AS1                         NaN                      NaN
# ZHX1                     1.370969e-01                 0.170440
# ZHX1-C8orf76                      NaN                      NaN
# ZHX2                     7.921279e-04                 0.350881
# ZNF16                             NaN                      NaN
# ZNF250                   7.167297e-01                -0.286790
# ZNF251                            NaN                      NaN
# ZNF252P                           NaN                      NaN
# ZNF252P-AS1                       NaN                      NaN
# ZNF34                             NaN                      NaN
# ZNF517                            NaN                      NaN
# ZNF572                            NaN                      NaN
# ZNF623                            NaN                      NaN
# ZNF696                            NaN                      NaN
# ZNF7                     3.020032e-02                 0.419626
# ZNF704                            NaN                      NaN
# ZNF706                   3.353363e-03                 0.312277
# ZNF707                            NaN                      NaN
#
#               ovarian_pvalue_proteomics  ovarian_rvalue_proteomics  \
# Name
# AARD                                NaN                        NaN
# ABRA                                NaN                        NaN
# ADCK5                               NaN                        NaN
# ADCY8                               NaN                        NaN
# ADGRB1                              NaN                        NaN
# ADHFE1                     1.310936e-01                   0.208438
# AGO2                       7.274694e-06                   0.506962
# ALKAL1                              NaN                        NaN
# ANGPT1                              NaN                        NaN
# ANKRD46                    2.371684e-01                   0.205632
# ANXA13                     4.243211e-01                  -0.105472
# ARC                                 NaN                        NaN
# ARFGEF1                    6.427898e-12                   0.703011
# ARHGAP39                            NaN                        NaN
# ARMC1                      4.914812e-04                   0.404516
# ASAP1-IT2                           NaN                        NaN
# ASPH                       1.006683e-02                   0.307809
# ASPH                       1.006683e-02                   0.307809
# ASPH                       1.006683e-02                   0.307809
# ATAD2                      2.301674e-04                   0.424062
# ATP6V0D2                            NaN                        NaN
# ATP6V1C1                   5.884772e-10                   0.655231
# ATP6V1H                    9.370194e-03                   0.311541
# AZIN1                               NaN                        NaN
# AZIN1-AS1                           NaN                        NaN
# BAALC                               NaN                        NaN
# BAALC-AS1                           NaN                        NaN
# BAALC-AS2                           NaN                        NaN
# BHLHE22                             NaN                        NaN
# BOP1                       8.209227e-02                   0.217419
# ...                                 ...                        ...
# ZBTB10                     4.646611e-08                   0.592807
# ZC2HC1A                    5.430876e-04                   0.401041
# ZC2HC1A                    5.430876e-04                   0.401041
# ZC2HC1A                    5.430876e-04                   0.401041
# ZC2HC1A                    5.430876e-04                   0.401041
# ZC3H3                      8.669868e-01                  -0.038181
# ZFAND1                     1.865537e-05                   0.486798
# ZFAT                                NaN                        NaN
# ZFAT-AS1                            NaN                        NaN
# ZFHX4                               NaN                        NaN
# ZFHX4-AS1                           NaN                        NaN
# ZFP41                               NaN                        NaN
# ZFPM2-AS1                           NaN                        NaN
# ZHX1                       1.244336e-02                   0.299886
# ZHX1-C8orf76                        NaN                        NaN
# ZHX2                       5.504591e-02                   0.236516
# ZNF16                      5.182945e-01                   0.087225
# ZNF250                     8.066706e-01                  -0.037648
# ZNF251                              NaN                        NaN
# ZNF252P                             NaN                        NaN
# ZNF252P-AS1                         NaN                        NaN
# ZNF34                      7.667676e-01                  -0.041977
# ZNF517                              NaN                        NaN
# ZNF572                              NaN                        NaN
# ZNF623                              NaN                        NaN
# ZNF696                              NaN                        NaN
# ZNF7                                NaN                        NaN
# ZNF704                              NaN                        NaN
# ZNF706                     1.786632e-08                   0.609190
# ZNF707                              NaN                        NaN
#
#               colon_pvalue_proteomics  colon_rvalue_proteomics  \
# Name
# AARD                              NaN                      NaN
# ABRA                              NaN                      NaN
# ADCK5                    5.200657e-01                 0.137726
# ADCY8                             NaN                      NaN
# ADGRB1                            NaN                      NaN
# ADHFE1                            NaN                      NaN
# AGO2                     2.228620e-08                 0.567648
# ALKAL1                            NaN                      NaN
# ANGPT1                            NaN                      NaN
# ANKRD46                           NaN                      NaN
# ANXA13                   9.026626e-02                 0.202179
# ARC                               NaN                      NaN
# ARFGEF1                  2.089487e-14                 0.718423
# ARHGAP39                          NaN                      NaN
# ARMC1                    2.447415e-01                 0.145229
# ASAP1-IT2                         NaN                      NaN
# ASPH                     6.762253e-03                 0.304077
# ASPH                     6.762253e-03                 0.304077
# ASPH                     6.762253e-03                 0.304077
# ATAD2                    2.198129e-01                 0.188646
# ATP6V0D2                          NaN                      NaN
# ATP6V1C1                 2.515183e-01                 0.142718
# ATP6V1H                  1.539431e-01                -0.174047
# AZIN1                             NaN                      NaN
# AZIN1-AS1                         NaN                      NaN
# BAALC                             NaN                      NaN
# BAALC-AS1                         NaN                      NaN
# BAALC-AS2                         NaN                      NaN
# BHLHE22                           NaN                      NaN
# BOP1                     1.478072e-07                 0.539634
# ...                               ...                      ...
# ZBTB10                            NaN                      NaN
# ZC2HC1A                  4.333514e-01                 0.107787
# ZC2HC1A                  4.333514e-01                 0.107787
# ZC2HC1A                  4.333514e-01                 0.107787
# ZC2HC1A                  4.333514e-01                 0.107787
# ZC3H3                             NaN                      NaN
# ZFAND1                   2.636920e-02                 0.278643
# ZFAT                              NaN                      NaN
# ZFAT-AS1                          NaN                      NaN
# ZFHX4                             NaN                      NaN
# ZFHX4-AS1                         NaN                      NaN
# ZFP41                             NaN                      NaN
# ZFPM2-AS1                         NaN                      NaN
# ZHX1                              NaN                      NaN
# ZHX1-C8orf76                      NaN                      NaN
# ZHX2                     7.040135e-01                -0.105419
# ZNF16                             NaN                      NaN
# ZNF250                            NaN                      NaN
# ZNF251                            NaN                      NaN
# ZNF252P                           NaN                      NaN
# ZNF252P-AS1                       NaN                      NaN
# ZNF34                             NaN                      NaN
# ZNF517                            NaN                      NaN
# ZNF572                            NaN                      NaN
# ZNF623                            NaN                      NaN
# ZNF696                            NaN                      NaN
# ZNF7                              NaN                      NaN
# ZNF704                            NaN                      NaN
# ZNF706                   4.952520e-06                 0.493256
# ZNF707                            NaN                      NaN
#
#               brca_pvalue_proteomics  brca_rvalue_proteomics  \
# Name
# AARD                             NaN                     NaN
# ABRA                             NaN                     NaN
# ADCK5                   1.203762e-03                0.343326
# ADCY8                            NaN                     NaN
# ADGRB1                           NaN                     NaN
# ADHFE1                  8.381515e-01               -0.025818
# AGO2                    3.099972e-08                0.496262
# ALKAL1                           NaN                     NaN
# ANGPT1                           NaN                     NaN
# ANKRD46                 2.706443e-01                0.187764
# ANXA13                           NaN                     NaN
# ARC                              NaN                     NaN
# ARFGEF1                 2.731893e-10                0.553758
# ARHGAP39                6.145594e-04                0.325121
# ARMC1                   5.312909e-11                0.570808
# ASAP1-IT2                        NaN                     NaN
# ASPH                    5.759412e-01                0.057590
# ASPH                    5.759412e-01                0.057590
# ASPH                    5.759412e-01                0.057590
# ATAD2                   4.439736e-14                0.639058
# ATP6V0D2                         NaN                     NaN
# ATP6V1C1                1.320907e-07                0.476015
# ATP6V1H                 5.958937e-01               -0.054270
# AZIN1                            NaN                     NaN
# AZIN1-AS1                        NaN                     NaN
# BAALC                            NaN                     NaN
# BAALC-AS1                        NaN                     NaN
# BAALC-AS2                        NaN                     NaN
# BHLHE22                          NaN                     NaN
# BOP1                    2.770784e-08                0.497951
# ...                              ...                     ...
# ZBTB10                  1.333593e-15                0.669952
# ZC2HC1A                 1.266935e-01                0.152297
# ZC2HC1A                 1.266935e-01                0.152297
# ZC2HC1A                 1.266935e-01                0.152297
# ZC2HC1A                 1.266935e-01                0.152297
# ZC3H3                   9.948952e-01                0.000851
# ZFAND1                  3.433537e-07                0.462582
# ZFAT                             NaN                     NaN
# ZFAT-AS1                         NaN                     NaN
# ZFHX4                            NaN                     NaN
# ZFHX4-AS1                        NaN                     NaN
# ZFP41                            NaN                     NaN
# ZFPM2-AS1                        NaN                     NaN
# ZHX1                    5.829476e-06                0.416715
# ZHX1-C8orf76                     NaN                     NaN
# ZHX2                    9.093600e-05                0.366517
# ZNF16                            NaN                     NaN
# ZNF250                  4.749091e-02                0.215570
# ZNF251                           NaN                     NaN
# ZNF252P                          NaN                     NaN
# ZNF252P-AS1                      NaN                     NaN
# ZNF34                            NaN                     NaN
# ZNF517                           NaN                     NaN
# ZNF572                           NaN                     NaN
# ZNF623                  1.746068e-03                0.329596
# ZNF696                           NaN                     NaN
# ZNF7                             NaN                     NaN
# ZNF704                           NaN                     NaN
# ZNF706                  1.272094e-14                0.650938
# ZNF707                           NaN                     NaN
#
#               lscc_pvalue_proteomics  lscc_rvalue_proteomics
# Name
# AARD                             NaN                     NaN
# ABRA                             NaN                     NaN
# ADCK5                   1.493486e-02                0.278639
# ADCY8                            NaN                     NaN
# ADGRB1                           NaN                     NaN
# ADHFE1                  7.173051e-01                0.062784
# AGO2                    2.811529e-10                0.596681
# ALKAL1                           NaN                     NaN
# ANGPT1                  8.980819e-01                0.020585
# ANKRD46                 5.442768e-02                0.259457
# ANXA13                  8.019923e-01                0.034743
# ARC                              NaN                     NaN
# ARFGEF1                 1.549559e-08                0.545353
# ARHGAP39                2.970148e-01                0.131405
# ARMC1                   6.392303e-06                0.452071
# ASAP1-IT2                        NaN                     NaN
# ASPH                    3.636042e-01                0.105645
# ASPH                    3.636042e-01                0.105645
# ASPH                    3.636042e-01                0.105645
# ATAD2                   5.820937e-09                0.560070
# ATP6V0D2                3.602213e-01               -0.114979
# ATP6V1C1                6.991512e-01                0.050713
# ATP6V1H                 6.044741e-01                0.064771
# AZIN1                            NaN                     NaN
# AZIN1-AS1                        NaN                     NaN
# BAALC                            NaN                     NaN
# BAALC-AS1                        NaN                     NaN
# BAALC-AS2                        NaN                     NaN
# BHLHE22                          NaN                     NaN
# BOP1                    2.940811e-07                0.503240
# ...                              ...                     ...
# ZBTB10                  3.048978e-01                0.117277
# ZC2HC1A                 1.824489e-01                0.159917
# ZC2HC1A                 1.824489e-01                0.159917
# ZC2HC1A                 1.824489e-01                0.159917
# ZC2HC1A                 1.824489e-01                0.159917
# ZC3H3                   1.600571e-02                0.281800
# ZFAND1                  3.828586e-03                0.305516
# ZFAT                             NaN                     NaN
# ZFAT-AS1                         NaN                     NaN
# ZFHX4                   1.904854e-01                0.165329
# ZFHX4-AS1                        NaN                     NaN
# ZFP41                            NaN                     NaN
# ZFPM2-AS1                        NaN                     NaN
# ZHX1                    9.642532e-07                0.484833
# ZHX1-C8orf76                     NaN                     NaN
# ZHX2                    7.156977e-06                0.448477
# ZNF16                            NaN                     NaN
# ZNF250                           NaN                     NaN
# ZNF251                  8.309866e-01                0.037579
# ZNF252P                          NaN                     NaN
# ZNF252P-AS1                      NaN                     NaN
# ZNF34                            NaN                     NaN
# ZNF517                           NaN                     NaN
# ZNF572                           NaN                     NaN
# ZNF623                  2.394204e-01                0.155132
# ZNF696                           NaN                     NaN
# ZNF7                    2.471900e-02                0.258191
# ZNF704                           NaN                     NaN
# ZNF706                  3.205112e-03                0.311057
# ZNF707                           NaN                     NaN
#
# [1152 rows x 24 columns]

# %%
fig, axs = plt.subplots(nrows=3, ncols=2, sharex=False, sharey=False, figsize=(10,11))
fig.suptitle("Chromosome 8q Cis-Effects")
count = 0
for cancer_type in proteomics.keys():
    sns.scatterplot(x=f'{cancer_type}_rvalue_transcriptomics', y=f'{cancer_type}_rvalue_proteomics', data=all_results, ax=axs[count//2][count%2])
    axs[count//2][count%2].set_title(cancer_type.upper())
    axs[count//2][count%2].set_xlabel("Transcriptomics R Value")
    axs[count//2][count%2].set_ylabel("Proteomics R Value")
    min_val = np.min(all_results[f'{cancer_type}_rvalue_transcriptomics'])
    max_val = np.max(all_results[f'{cancer_type}_rvalue_transcriptomics'])
    axs[count//2][count%2].plot([min_val,max_val], [min_val,max_val])
    count += 1
plt.subplots_adjust(hspace=0.4, wspace=0.3)
