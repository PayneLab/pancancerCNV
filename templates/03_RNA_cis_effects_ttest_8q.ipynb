# %% [markdown]
# # RNA cis-effects with t tests for 8q
#
# Here we look for genes IN the event discussed that are affected by the arm-level event. We will find these effects by performing a series of t-tests comparing the transcriptomics values of the patients with the event against those without the event.

# %% [markdown]
# ## Setup (Install necessary packages)
#
# We will start by importing necessary packages and collecting all of the transcriptomics data we will need to run the tests. The cancer types analyzed should have been determined in 01_event_basic_info where we determine which types of cancer seem to have the event we are looking at.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cptac
from scipy import stats
import cnvutils
import cptac.utils

# %%
# These variables specify which chromosome and arm we're working on, and whether to do cis or trans
CHROMOSOME = '8'
ARM = 'q'
CIS_OR_TRANS = "cis"

# %%
if ARM == "p":
    EVENT_COLUMN = "loss_event"
    EXCLUDE_COLUMN = "gain_event"
    EVENT_START = 0
    EVENT_END = 30794385
    
elif ARM == "q":
    EVENT_COLUMN = "gain_event"
    EXCLUDE_COLUMN = "loss_event"
    EVENT_START = 80794385
    EVENT_END = 130794385

else:
    raise ValueError("Invalid value for ARM variable.")

# %%
cancer_types = {
    "brca": cptac.Brca,
    "colon": cptac.Colon,
    "hnscc": cptac.Hnscc,
    "lscc": cptac.Lscc,
    "luad": cptac.Luad,
    "ovarian": cptac.Ovarian
}

# %% [markdown]
# ## Select the RNAs we're interested in
#
# If we're looking at cis effects, we select RNAs within the event. If we're looking at trans effects, we select RNAs outside of the event.

# %%
selected_genes = cnvutils.\
get_event_genes(
    chrm=CHROMOSOME,
    event_start=EVENT_START,
    event_end=EVENT_END,
    cis_or_trans=CIS_OR_TRANS
)["Name"].\
drop_duplicates(keep="first")

def load_transcriptomics_tumor(dataset_func):
    return dataset_func().get_transcriptomics(tissue_type="tumor")

transcriptomics = {}

for cancer_type in cancer_types.keys():
    df = load_transcriptomics_tumor(cancer_types[cancer_type]).transpose()

    if df.index.nlevels == 1:
        df = df[df.index.isin(selected_genes)]
    else:
        df = df[df.index.isin(selected_genes, level="Name")]

    transcriptomics[cancer_type] = df
# Out:
# Checking that luad index is up-to-date...
# cptac warning: The LSCC data is currently strictly reserved for CPTAC investigators. Otherwise, you are not authorized to access these data. Additionally, even after these data become publicly available, they will be subject to a publication embargo (see https://proteomics.cancer.gov/data-portal/about/data-use-agreement or enter cptac.embargo() to open the webpage for more details). (/home/caleb/anaconda3/envs/dev/lib/python3.7/site-packages/ipykernel_launcher.py, line 11)

# %% [markdown]
# ## Append Event Data
#
# We now append the data from the event table that should have been created in a previous notebook.

# %%
has_event = dict()
for cancer_type in transcriptomics.keys():
    df = transcriptomics[cancer_type]
    df = df.transpose()
    event = pd.read_csv(f'{cancer_type}_has_event.tsv', sep='\t', index_col=0)
    if EXCLUDE_COLUMN:
        event.drop(EXCLUDE_COLUMN, axis=1, inplace=True)
    event.index.rename('Name')
    df = df.join(event)
    df = df.dropna(subset=[EVENT_COLUMN])
    has_event[cancer_type] = df[EVENT_COLUMN]
    transcriptomics[cancer_type] = df

# %% [markdown]
# ## Run T-Tests

# %%
results_df = None
for cancer_type in transcriptomics.keys():
    prot_df = transcriptomics[cancer_type]
    results = cptac.utils.wrap_ttest(
        df=prot_df, 
        label_column=EVENT_COLUMN,
        correction_method="fdr_bh",
        return_all=True,
        quiet=True
    )   
    results.set_index('Comparison', inplace=True)
    if isinstance(results.index[0], tuple):
        results[['Name', f'{cancer_type}_Database_ID']] = pd.DataFrame(
            results.index.values.tolist(),
            index=results.index
        )
        results.set_index(['Name', f'{cancer_type}_Database_ID'], inplace=True)
    else:
        results.index.name='Name'
    results.rename(columns={'P_Value': f'{cancer_type}_pvalue'}, inplace=True)
    if results_df is None:
        results_df = results
    else:
        results_df = results_df.join(results)

# %% [markdown]
# ## Append Difference Data
#
# We want to collect one more piece of information about the data. We want to find the difference between the averages of the two groups. This will tell us if there is a positive or negative coorelation between the event and the proteomic data and can give us some indication of the strength of the coorelation.

# %%
def get_diff(col, event):
    has_event = col[event]
    invert_list = [not x for x in event]
    no_event = col[invert_list]
    event_avg = has_event.mean()
    no_event_avg = no_event.mean()
    return event_avg - no_event_avg

# %%
diff_df = None
for cancer_type in transcriptomics.keys():
    df = transcriptomics[cancer_type]
    df = df.drop(EVENT_COLUMN, axis=1)
    results = df.apply(lambda x: get_diff(x, has_event[cancer_type]))
    df = pd.DataFrame(results)
    if isinstance(df.index[0], tuple):
        df[['Name', f'{cancer_type}_Database_ID']] = pd.DataFrame(df.index.values.tolist(), index=df.index)
        df.set_index(['Name', f'{cancer_type}_Database_ID'], inplace=True)
    else:
        df.index.name='Name'
    df.rename(columns={0: f'{cancer_type}_diff'}, inplace=True)
    if diff_df is None:
        diff_df = df
    else:
        diff_df = diff_df.join(df)

# %% [markdown]
# ## Join the tables and save
#
# We now join the difference table and the results table together. We also save the table to a tsv for use in future analyses.

# %%
results_df = results_df.join(diff_df)

# %%
results_df
# Out:
#               brca_pvalue  colon_pvalue  hnscc_pvalue   lscc_pvalue  \
# Name
# MIR7705      7.020736e-11           NaN           NaN           NaN
# PABPC1       7.020736e-11  1.972736e-09  1.460832e-02  8.253546e-04
# RPL30        1.416907e-08  4.067977e-06  4.628068e-07  3.417095e-03
# YWHAZ        1.825122e-08  2.512327e-05  3.463188e-04  9.965026e-06
# DCAF13       2.554904e-08  1.286945e-06  7.027431e-08  3.393859e-07
# PTDSS1       1.006822e-07  1.476374e-09  6.140054e-06  5.786716e-03
# UBR5         1.884289e-07  5.007370e-06  1.894506e-07  9.820648e-09
# EMC2         6.327708e-07  2.224229e-06  2.420456e-07  8.154749e-06
# LAPTM4B      6.327708e-07  3.645197e-05  3.685183e-04  1.453619e-05
# SLC25A32     6.327708e-07  8.036730e-06  2.531341e-06  8.991207e-04
# POLR2K       6.327708e-07  1.123123e-04  2.311475e-05  2.877038e-06
# RAD21        6.420062e-07  3.640761e-06  1.570729e-04  1.571310e-05
# MIR3610      6.420062e-07           NaN           NaN           NaN
# AZIN1        6.652440e-07  1.228407e-07  6.140054e-06  1.122671e-05
# MTDH         8.024858e-07  4.067977e-06  2.846235e-05  1.958974e-04
# INTS8        8.024858e-07  2.548775e-06  2.094170e-05  3.116004e-07
# WDYHV1       9.084428e-07  7.961564e-04  6.210063e-05  5.060646e-06
# OTUD6B       1.188693e-06  7.709402e-07  3.224968e-06  2.257250e-07
# ZNF706       2.150910e-06  1.457558e-07  1.141219e-06  4.452424e-03
# NUDCD1       3.942116e-06  3.191689e-06  8.043722e-04  1.091965e-04
# POP1         4.930790e-06  1.552062e-02  5.698470e-04  2.797191e-05
# NDUFB9       5.621547e-06  3.227124e-03  3.545160e-07  3.415921e-05
# FSBP         7.284968e-06           NaN  9.339793e-01           NaN
# RAD54B       7.284968e-06  1.191324e-02  5.062351e-03  1.779122e-05
# DSCC1        1.148688e-05  8.841049e-04  2.106812e-03  4.477154e-04
# STK3         1.192062e-05  3.191689e-06  3.457115e-05  9.820648e-09
# UTP23        1.329455e-05  1.056099e-09  2.420456e-07  2.797191e-05
# MED30        1.750709e-05  1.121642e-06  2.102427e-07  1.011796e-02
# E2F5         1.750709e-05  3.823898e-05  4.402439e-01  3.793693e-01
# ANKRD46      2.093949e-05  6.756625e-06  4.700947e-05  1.210747e-04
# ...                   ...           ...           ...           ...
# KCNV1        7.071236e-01           NaN  8.061763e-01  2.680772e-01
# GRHL2        7.071236e-01  3.423482e-06  2.019560e-03  1.938655e-02
# SAMD12       7.715476e-01  1.618474e-08  1.379676e-01  2.325339e-01
# DPYS         7.881488e-01           NaN  3.046030e-01  4.411728e-02
# CNBD1        7.885444e-01           NaN  1.239574e-01  4.304647e-02
# NCALD        7.903817e-01  3.515029e-01  4.116733e-01  5.043270e-01
# REXO1L2P     7.903817e-01           NaN  6.152585e-01           NaN
# PRNCR1       7.903817e-01           NaN  7.229468e-03           NaN
# COLEC10      7.903817e-01           NaN  1.329021e-01  9.970932e-01
# CA2          7.903817e-01  2.246799e-02  2.529853e-01  7.926503e-01
# CALB1        7.903817e-01           NaN  4.279413e-03  9.446007e-01
# C8orf37-AS1  7.903817e-01           NaN  9.279026e-01  5.710455e-01
# CCAT2        8.039800e-01           NaN  3.153169e-03  5.132833e-02
# TRIQK        8.045483e-01  1.107539e-01  1.578530e-05  4.019817e-02
# RALYL        8.068088e-01           NaN  7.064595e-01  4.168856e-01
# CNGB3        8.068088e-01           NaN  2.019560e-03  2.160965e-01
# TNFRSF11B    8.068088e-01  4.742876e-01  8.758738e-01  5.025996e-01
# C8orf87      8.184730e-01           NaN  9.857172e-01  8.516236e-01
# DCAF4L2      8.274196e-01           NaN  6.515388e-01           NaN
# GSDMC        8.274196e-01           NaN  9.881855e-01  9.980798e-01
# PKHD1L1      8.538179e-01           NaN  5.309044e-01  2.949941e-02
# ZNF572       8.757935e-01  4.620686e-05  2.544679e-02  4.908590e-05
# ASAP1-IT2    8.842811e-01           NaN  5.309044e-01  5.649502e-01
# TP53INP1     9.191877e-01  9.315430e-01  4.408421e-01  2.312988e-01
# GDF6         9.407698e-01           NaN  2.254050e-02  9.799026e-01
# NECAB1       9.407698e-01           NaN  4.031691e-01  9.980798e-01
# SNORA72      9.529330e-01           NaN  3.624673e-02  7.385308e-03
# ANGPT1       9.744243e-01  9.795371e-01  2.661184e-01  3.903896e-01
# SLC10A5      9.744243e-01           NaN  1.307995e-02  2.347616e-02
# CDH17        9.959540e-01  2.623140e-04  8.179474e-01  9.680825e-01
#
#               luad_pvalue  ovarian_pvalue  brca_diff  colon_diff  hnscc_diff  \
# Name
# MIR7705               NaN             NaN   1.215883         NaN    0.000000
# PABPC1       6.230831e-05             NaN   1.215883    0.701779    0.290728
# RPL30        6.348469e-04        0.043776   0.945084    0.576439    0.405452
# YWHAZ        1.193697e-03        0.013890   1.053275    0.367394    0.436486
# DCAF13       5.708224e-05        0.028446   1.239230    0.593220    0.540716
# PTDSS1       1.247156e-05        0.000051   1.013563    0.532508    0.462051
# UBR5         1.193697e-03        0.061988   0.927482    0.559859    0.373194
# EMC2         6.601363e-05        0.007477   0.794761    0.475144    0.428597
# LAPTM4B      7.010932e-02        0.001166   1.734389    0.976726    0.494540
# SLC25A32     6.794965e-05        0.006284   0.875555    0.438432    0.367432
# POLR2K       2.225758e-04        0.006468   0.852125    0.482646    0.355901
# RAD21        6.450789e-07             NaN   1.176424    0.436919    0.359770
# MIR3610               NaN             NaN   1.176424         NaN    0.000000
# AZIN1        3.038441e-04        0.013890   0.878940    0.438354    0.348107
# MTDH         3.702261e-04        0.000105   1.016098    0.405865    0.299118
# INTS8        2.623116e-07        0.000258   0.895060    0.523939    0.286508
# WDYHV1       6.450789e-07        0.048393   0.925437    0.314997    0.358152
# OTUD6B       1.389410e-05             NaN   0.929470    0.551946    0.409585
# ZNF706       5.542625e-02        0.115715   1.304963    0.478950    0.481863
# NUDCD1       1.445071e-07        0.109803   0.999945    0.564880    0.314431
# POP1         1.164062e-04        0.032473   0.915108    0.290499    0.359740
# NDUFB9       6.450789e-07        0.017517   0.993717    0.349955    0.546109
# FSBP         2.985495e-02             NaN   1.253703         NaN   -0.024525
# RAD54B       1.192715e-04             NaN   1.253703    0.361801    0.355298
# DSCC1        1.999158e-05        0.050635   1.498295    0.468021    0.455856
# STK3         1.192715e-04        0.000620   0.711964    0.457728    0.358254
# UTP23        1.445071e-07        0.113361   0.832828    0.588210    0.362391
# MED30        6.450789e-07        0.003554   0.873162    0.603220    0.536380
# E2F5         8.917150e-07        0.001403   1.342153    0.547046    0.183054
# ANKRD46      1.771612e-05        0.001149   0.880641    0.540857    0.387802
# ...                   ...             ...        ...         ...         ...
# KCNV1        4.899778e-01        0.690335  -0.394372         NaN    0.040675
# GRHL2        2.721821e-02        0.000258   0.100752    0.502189    0.352085
# SAMD12       4.802989e-02        0.002590  -0.131914    0.726583    0.533978
# DPYS         3.431855e-01        0.440225  -0.186654         NaN    0.298039
# CNBD1        5.076705e-01        0.686509  -0.356953         NaN    0.515449
# NCALD        1.682397e-01        0.886528   0.115037    0.145884    0.201493
# REXO1L2P              NaN        0.109803   0.291863         NaN    0.110407
# PRNCR1                NaN             NaN  -0.050688         NaN    0.244717
# COLEC10      2.169377e-01        0.770369   0.170383         NaN    0.466731
# CA2          6.949738e-01        0.573575  -0.217555   -0.882695    0.492376
# CALB1        7.573308e-01        0.886528   0.364856         NaN    1.848394
# C8orf37-AS1           NaN        0.801015  -0.140130         NaN    0.029438
# CCAT2                 NaN        0.844774  -0.122162         NaN    0.532749
# TRIQK        5.939588e-05        0.006098   0.081000    0.248643    0.532870
# RALYL        3.533231e-01        0.549952   0.417744         NaN    0.147115
# CNGB3        1.064253e-02        0.638409  -0.422894         NaN    0.772032
# TNFRSF11B    2.911355e-01        0.092427  -0.146756    0.194302   -0.064355
# C8orf87               NaN        0.770369   0.402355         NaN   -0.001452
# DCAF4L2               NaN        0.503597   0.375255         NaN   -0.232334
# GSDMC        3.226228e-01        0.257743   0.183254         NaN   -0.004276
# PKHD1L1      8.502595e-01        0.127436  -0.155251         NaN   -0.200554
# ZNF572       3.329341e-04             NaN   0.104086    0.682368    0.358477
# ASAP1-IT2             NaN        0.028446  -0.057326         NaN   -0.070113
# TP53INP1     8.502595e-01        0.134749  -0.034019    0.013435    0.143729
# GDF6         5.382583e-01        0.655966   0.048086         NaN    0.760502
# NECAB1       4.213047e-01        0.853436   0.074760         NaN    0.207040
# SNORA72               NaN        0.853436  -0.022621         NaN    0.417775
# ANGPT1       6.238192e-01        0.602094   0.013517    0.004363   -0.168503
# SLC10A5      2.217660e-03             NaN   0.028256         NaN    0.510140
# CDH17        8.070026e-01        0.971882  -0.001995    0.649293    0.081395
#
#              lscc_diff  luad_diff  ovarian_diff
# Name
# MIR7705            NaN        NaN           NaN
# PABPC1        0.463542   0.661256           NaN
# RPL30         0.331225   0.428509    943.968018
# YWHAZ         0.481283   0.400134     91.237246
# DCAF13        0.521040   0.564146      8.818968
# PTDSS1        0.427965   0.444150     19.412090
# UBR5          0.485821   0.345186      5.678937
# EMC2          0.395411   0.413738     20.622266
# LAPTM4B       0.695947   0.479058    264.133367
# SLC25A32      0.265882   0.395868      2.923498
# POLR2K        0.493811   0.481635     42.047347
# RAD21         0.429971   0.559400           NaN
# MIR3610            NaN        NaN           NaN
# AZIN1         0.393328   0.405446     14.367922
# MTDH          0.261151   0.346371     20.562490
# INTS8         0.464864   0.537655      9.214611
# WDYHV1        0.449742   0.623642      2.567472
# OTUD6B        0.552933   0.431165           NaN
# ZNF706        0.333819   0.204234      5.772408
# NUDCD1        0.375807   0.612522      4.692151
# POP1          0.463696   0.438225      0.580602
# NDUFB9        0.515549   0.656658    139.004098
# FSBP               NaN   0.400549           NaN
# RAD54B        0.699608   0.667190           NaN
# DSCC1         0.587490   0.970777      2.655638
# STK3          0.480156   0.472204      7.286948
# UTP23         0.397918   0.603892      1.771877
# MED30         0.295761   0.516875      6.641269
# E2F5          0.190344   0.760534      9.819193
# ANKRD46       0.486514   0.599972      4.266400
# ...                ...        ...           ...
# KCNV1         0.855970   0.528112     -0.141968
# GRHL2         0.371547   0.468481      3.171014
# SAMD12        0.329858   0.388515      1.904189
# DPYS         -0.676240  -0.354212     -0.135321
# CNBD1         1.088467  -0.402070     -0.003977
# NCALD         0.153507   0.378064     -0.497409
# REXO1L2P           NaN        NaN      0.014589
# PRNCR1             NaN        NaN           NaN
# COLEC10       0.015980   0.312082     -0.034105
# CA2           0.100962  -0.164168      2.100059
# CALB1        -0.124732   0.139530     -0.592664
# C8orf37-AS1  -0.163847        NaN     -0.165339
# CCAT2         0.517261        NaN      0.003342
# TRIQK         0.356179   0.601757      5.598206
# RALYL         0.672432  -1.024734      0.093955
# CNGB3         0.544368   0.897841      0.048366
# TNFRSF11B    -0.214112   0.272569      5.987203
# C8orf87       0.111706        NaN      0.011144
# DCAF4L2            NaN        NaN      0.010664
# GSDMC        -0.004869   0.431630      0.673081
# PKHD1L1      -0.870958  -0.098384      3.359615
# ZNF572        0.556883   0.712863           NaN
# ASAP1-IT2    -0.097111        NaN      0.019495
# TP53INP1     -0.260378  -0.043529      2.245180
# GDF6         -0.034766   0.250737      0.045283
# NECAB1        0.002370   0.261871      0.068399
# SNORA72       0.478778        NaN     -0.158801
# ANGPT1       -0.236949  -0.154534      0.383878
# SLC10A5       0.444028   0.605337           NaN
# CDH17        -0.036768  -0.151441      0.000306
#
# [191 rows x 12 columns]

# %%
# This will save the resulting table in the same directory as this notebook.
# Modify if you would like to save to a different location.
results_df.to_csv(f"{CHROMOSOME}{ARM}_{CIS_OR_TRANS}RNAeffects_ttest.tsv", sep='\t')
